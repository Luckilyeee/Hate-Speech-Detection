# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import torchvision
import torch.optim as optim

import numpy as np
from sklearn.manifold import TSNE

import argparse, sys, os

import torch
from torchtext import data, datasets
import random
torch.backends.cudnn.deterministic = True

import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import time
from collections import Counter
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bcb82d7d-2b1b-4498-b0db-0418b14b2eee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcb82d7d-2b1b-4498-b0db-0418b14b2eee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Wiki.csv to Wiki.csv

# %%
import pandas as pd

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('stopwords')


twitter = pd.read_csv("twitter.csv")
forum = pd.read_csv("Forum.csv")
wiki = pd.read_csv("Wiki.csv")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# remove puctunations, https
import re
def  clean_text(df, text_field):
    df[text_field] = df[text_field].str.lower()
    df[text_field] = df[text_field].apply(lambda elem: re.sub(r"(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    return df

twitter = clean_text(twitter, 'text')
forum = clean_text(forum, 'text')
wiki = clean_text(wiki, 'text')

stopwords = nltk.corpus.stopwords.words('english')
twitter['text'] = twitter['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
forum['text'] = forum['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
wiki['text'] = wiki['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %% [markdown]
# #Wordcloud

# %%
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(50, 25))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(background_color='white', width = 600, height = 400, collocations=False, stopwords = STOPWORDS).generate(" ".join(data1))
# Plot
plot_cloud(wordcloud)

# %%
from wordcloud import WordCloud

data1 = twitter[twitter['label']==1]['text']
data2 = forum[forum['label']==1]['text']
data3 = wiki[wiki['label']==1]['text']


fig, axs = plt.subplots(3, figsize=[50, 25])

wordcloud1 = WordCloud( background_color='white',
                        width=600,
                        height=400,
                        collocations = False).generate(" ".join(data1))

wordcloud2 = WordCloud( background_color='white',
                        width=600,
                        height=400,
                        collocations = False).generate(" ".join(data2))
                                      
wordcloud3 = WordCloud( background_color='white',
                        width=600,
                        height=400,
                        collocations = False).generate(" ".join(data3))
axs[0].imshow(wordcloud1)
axs[0].axis('off')
axs[0].set_title('Twitter',fontsize=30);


axs[1].imshow(wordcloud2)
axs[1].axis('off')
axs[1].set_title('Forum',fontsize=30);

axs[2].imshow(wordcloud3)
axs[2].axis('off')
axs[2].set_title('Wiki',fontsize=30);

# %%
twitter['domain'] = 0
forum['domain'] = 0
wiki['domain'] = 1

# %%
twitter = twitter[['text', 'label', 'domain']]
forum = forum[['text', 'label', 'domain']]
wiki = wiki[['text', 'label', 'domain']]

# %%
forum.to_csv('F.csv', index=False)
twitter.to_csv('T.csv', index=False)
wiki.to_csv('W.csv', index=False)

# %% [markdown]
# #tokenize

# %%
SEED = 1234
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
TEXT = data.Field(tokenize = 'spacy', batch_first=True)
LABEL = data.LabelField(dtype=torch.float)
DOMAIN = data.LabelField(dtype=torch.float)

# %%
#loading custom dataset
T =data.TabularDataset(path = 'T.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(T.examples[0]))
# Out:
# {'text': ['paid', 'hold', 'monkey', 'look', 'monkey', 'real', 'af'], 'label': '0.0', 'domain': '0'}

# %%
#loading custom dataset
W =data.TabularDataset(path = 'W.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(W.examples[0]))
# Out:
# {'text': ['right', 'fine', 'did', 'nt', 'even', 'start', 'discussion', 'joined', 'every', 'time', 'someone', 'tries', 'get', 'article', 'neutral', 'bullheaded', 'evolutionist', 'jumps', 'throat', 'stupid', 'evolution', 'proven', 'you', 're', 'idiot'], 'label': '1.0', 'domain': '1'}

# %%
#loading custom dataset
forum =data.TabularDataset(path = 'F.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(forum.examples[0]))
# Out:
# {'text': ['watch', 'video', 'minutes', 'see', 'eventually', 'biracial', 'minority', 'butchered'], 'label': '1.0', 'domain': '0'}

# %% [markdown]
# split train, test, val

# %%
def split(train_size, dataset):
  train, test = dataset.split([6000, 2000], random_state = random.seed(SEED))
  train, other = train.split([train_size, 6000-train_size], random_state = random.seed(SEED))
  # train, val = train.split(random_state = random.seed(SEED))
  return train, test

train_size = 2000
T_train_data, T_test_data = split(train_size, T)
F_train_data, F_test_data = split(train_size, forum)
W_train_data, W_test_data = split(train_size, W)

# %% [markdown]
# #convert texts into integer sequences.

# %% [markdown]
# build vocabulary

# %%
#initialize glove embeddings
MAX_VOCAB_SIZE = 25_000

TEXT.build_vocab(T_train_data, F_train_data, W_train_data, 
                 max_size = MAX_VOCAB_SIZE, 
                 vectors = "glove.6B.100d", 
                 unk_init = torch.Tensor.normal_) 
LABEL.build_vocab(T_train_data, F_train_data, W_train_data)
DOMAIN.build_vocab(T_train_data, F_train_data, W_train_data)

# %% [markdown]
# creat iterators

# %%
#set batch size
BATCH_SIZE = 64

#check whether cuda is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  

#Load an iterator
T_train_iterator, T_test_iterator = data.BucketIterator.splits(
    (T_train_data, T_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

F_train_iterator, F_test_iterator = data.BucketIterator.splits(
    (F_train_data, F_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

W_train_iterator, W_test_iterator = data.BucketIterator.splits(
    (W_train_data, W_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

# %%
class GradReverse(torch.autograd.Function):
    """
    Extension of grad reverse layer
    """
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        grad_output = grad_output.neg() * ctx.constant
        return grad_output, None

    def grad_reverse(x, constant):
        return GradReverse.apply(x, constant)

class Extractor(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, 
                 dropout, pad_idx, pretrained_embeddings):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        self.embedding.weight.data.copy_(pretrained_embeddings)
        self.conv_0 = nn.Conv2d(in_channels = 1, 
                                out_channels = n_filters, 
                                kernel_size = (filter_sizes, embedding_dim))
        
        
        
        self.fc = nn.Linear(n_filters, output_dim)
        
        self.dropout = nn.Dropout(dropout)

        # self.relu = nn.ReLU(inplace=True)
        # self.max_pool1d = nn.MaxPool1d(2,2)
        
    def forward(self, text):
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)
                
        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved_0 = F.relu(self.conv_0(embedded).squeeze(3))
            
        #conved_n = [batch size, n_filters, sent len - filter_sizes[n] + 1]
        
        pooled_0 = F.max_pool1d(conved_0, conved_0.shape[2]).squeeze(2)
        
        #pooled_n = [batch size, n_filters]
        x = self.dropout(pooled_0)
        #x = [batch size, n_filters * len(filter_sizes)]
            
        return x

class Class_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Class_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input):
        x = self.fc(input)
        return x

class Domain_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Domain_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input, constant):
        input = GradReverse.grad_reverse(input, constant)
        return self.fc(input)

# %%
def optimizer_scheduler(optimizer, p):
    """
    Adjust the learning rate of optimizer
    :param optimizer: optimizer for updating parameters
    :param p: a variable for adjusting learning rate
    :return: optimizer
    """
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75

    return optimizer

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 100
FILTER_SIZES = 1
OUTPUT_DIM = 1
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]
pretrained_embeddings = TEXT.vocab.vectors

extractor = Extractor(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT, PAD_IDX,pretrained_embeddings )
class_classifier = Class_classifier(N_FILTERS, OUTPUT_DIM)
domain_classifier = Domain_classifier(N_FILTERS, OUTPUT_DIM)

# %% [markdown]
# check the number of parameters

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(extractor) + count_parameters(class_classifier) + count_parameters(domain_classifier):,} trainable parameters')
# Out:
# The model has 1,841,403 trainable parameters

# %% [markdown]
# zero the initial weights of the unknown and padding tokens

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]

extractor.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
extractor.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

# %%
criterion = nn.BCEWithLogitsLoss()

extractor = extractor.to(device)
class_classifier = class_classifier.to(device)
domain_classifier = domain_classifier.to(device)

criterion = criterion.to(device)

# %% [markdown]
# define function to calculate the correct predictions

# %%
def train(training_mode, extractor, class_classifier, domain_classifier, criterion,
          source_data1, source_data2, target_data, optimizer, epoch):
  
    epoch_loss = 0
    epoch_acc = 0

    # setup models
    extractor.train()
    class_classifier.train()
    domain_classifier.train()

    # steps
    start_steps = epoch * len(source_data1)
    total_steps = 10 * len(source_data1)

    for batch_idx,(sdata1, sdata2, tdata) in enumerate(zip(source_data1, source_data2, target_data)):
        if training_mode == 'dann':
            # setup hyperparameters
            p = float(batch_idx + start_steps) / total_steps
            constant = 2. / (1. + np.exp(-gamma * p)) - 1

            # prepare the data
            input1, label1, domain1 = sdata1.text, sdata1.label, sdata1.domain
            input2, label2, domain2 = sdata2.text, sdata2.label, sdata2.domain
            input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
    
            # setup optimizer
            optimizer = optimizer_scheduler(optimizer, p)
            optimizer.zero_grad()

            # compute the output of source domain and target domain
            src_feature1 = extractor(input1)
            src_feature2 = extractor(input2)
            tgt_feature  = extractor(input3)

            # compute the class loss of src_feature
            class_pred1 = class_classifier(src_feature1).squeeze(1)
            class_pred2 = class_classifier(src_feature2).squeeze(1)
            
            class_loss1 = criterion(class_pred1, label1)
            class_loss2 = criterion(class_pred2, label2)

            # compute the domain loss of src_feature and target_feature
            tgt_preds = domain_classifier(tgt_feature, constant).squeeze(1)
            src_pred1 = domain_classifier(src_feature1, constant).squeeze(1)
            src_pred2 = domain_classifier(src_feature2, constant).squeeze(1)
            
            tgt_loss = criterion(tgt_preds, domain3)
            src_loss1 = criterion(src_pred1, domain1)
            src_loss2 = criterion(src_pred2, domain2)
            
            domain_loss = tgt_loss + src_loss1 + src_loss2
            class_loss = class_loss1 + class_loss2

            loss = class_loss + theta * domain_loss

            loss.backward()
            optimizer.step()

            # print loss
            
            if (batch_idx + 1) % 10 == 0:
                print('[{}/{} ({:.0f}%)]\tLoss: {:.6f}\tClass Loss: {:.6f}\tDomain Loss: {:.6f}'.format(
                    batch_idx * len(input2), len(F_train_data),
                    100. * batch_idx / len(source_data2), loss.item(), class_loss.item(),
                    domain_loss.item()
                ))
                
            total_loss.append(loss.item())
            c_loss.append( class_loss.item())
            d_loss.append(domain_loss.item())

# %%
def test(extractor, class_classifier, domain_classifier, source_data1, source_data2, target_data):
 
    # setup the network
    extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()
    source_correct1 = 0.0
    source_correct2 = 0.0
    target_correct = 0.0
    domain_correct = 0.0
    tgt_correct = 0.0
    src_correct1 = 0.0
    src_correct2 = 0.0

    for batch_idx, sdata in enumerate(source_data1):
        # setup hyperparameters
        p = float(batch_idx) / len(source_data1)
        constant = 2. / (1. + np.exp(-10 * p)) - 1.

        input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
        
        output1 = class_classifier(extractor(input1)).squeeze(1)
        output1 = torch.round(torch.sigmoid(output1))
        source_correct1 += (output1 == label1).cpu().sum()

        src_preds = domain_classifier(extractor(input1), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        src_correct1 += (src_preds == domain1).cpu().sum()

    for batch_idx, sdata in enumerate(source_data2):
        # setup hyperparameters
        p = float(batch_idx) / len(source_data2)
        constant = 2. / (1. + np.exp(-10 * p)) - 1.

        input2, label2, domain2 = sdata.text, sdata.label, sdata.domain
       
        output2 = class_classifier(extractor(input2)).squeeze(1)
        output2 = torch.round(torch.sigmoid(output2))
        source_correct2 += (output2 == label2).cpu().sum()

        src_preds = domain_classifier(extractor(input2), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        src_correct2 += (src_preds == domain2).cpu().sum()

    for batch_idx, tdata in enumerate(target_data):
        # setup hyperparameters
        p = float(batch_idx) / len(target_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1

        input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
        
        output3 = class_classifier(extractor(input3)).squeeze(1)
        output3 = torch.round(torch.sigmoid(output3))
        target_correct += (output3 == label3).cpu().sum()

        src_preds = domain_classifier(extractor(input3), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        tgt_correct += (src_preds == domain3).cpu().sum()


    domain_correct = tgt_correct + src_correct1 + src_correct2

    print('\nSource1 Accuracy(classification): {}/{} ({:.4f}%)\nSource2 Accuracy(classification): {}/{} ({:.4f}%)\nTarget Accuracy(classification): {}/{} ({:.4f}%)\n'
          'Domain Accuracy: {}/{} ({:.4f}%)\n'.
        format(
        source_correct1, len(T_test_data), 100. * float(source_correct1) / len(T_test_data),
        source_correct2, len(F_test_data), 100. * float(source_correct2) / len(F_test_data),
        target_correct, len(W_test_data), 100. * float(target_correct) / len(W_test_data),
        domain_correct, len(T_test_data) + len(F_test_data) + len(W_test_data),
        100. * float(domain_correct) / (len(T_test_data) + len(F_test_data) 
                                        + len(W_test_data))
    ))
    acc_list1.append(100. * float(source_correct1) / len(T_test_data))
    acc_list2.append(100. * float(source_correct2) / len(F_test_data))
    acc_list3.append(100. * float(target_correct) / len(W_test_data))
    acc_list4.append(100. * float(domain_correct) / (len(T_test_data) + len(F_test_data) 
                                        + len(W_test_data)))

# %%
def main():

    # prepare the source data and target data
    src_train_data1 = T_train_iterator
    src_test_data1 = T_test_iterator
    src_train_data2 = F_train_iterator
    src_test_data2 = F_test_iterator
    
    tgt_train_data = W_train_iterator
    tgt_test_data = W_test_iterator

    optimizer = optim.SGD([
            {'params': extractor.parameters()},
                            {'params': class_classifier.parameters()},
                            {'params': domain_classifier.parameters()}
    ], lr= 0.01, momentum= 0.9)


    for epoch in range(100):
    
        print('Epoch: {}'.format(epoch))
        train('dann', extractor, class_classifier, domain_classifier, criterion,
                    src_train_data1, src_train_data2, tgt_train_data, optimizer, epoch)
        test(extractor, class_classifier, domain_classifier, src_test_data1, src_test_data2, tgt_test_data)
        
total_loss, d_loss, c_loss = [],[],[]
acc_list1, acc_list2, acc_list3, acc_list4 = [],[],[],[]
if __name__ == '__main__':
    gamma = 10
    theta = 1
    time_start=time.time()
    main()
    time_end=time.time()
    print('total run time: (min)',(time_end-time_start)/60.)
# Out:
# Epoch: 0
# [576/2000 (28%)]	Loss: 3.396958	Class Loss: 1.391236	Domain Loss: 2.005722
# [1216/2000 (59%)]	Loss: 3.260975	Class Loss: 1.350230	Domain Loss: 1.910745
# [1856/2000 (91%)]	Loss: 3.150207	Class Loss: 1.344426	Domain Loss: 1.805781
#
# Source1 Accuracy(classification): 1611.0/2000 (80.5500%)
# Source2 Accuracy(classification): 1276.0/2000 (63.8000%)
# Target Accuracy(classification): 1426.0/2000 (71.3000%)
# Domain Accuracy: 3983.0/6000 (66.3833%)
#
# Epoch: 1
# [576/2000 (28%)]	Loss: 3.112725	Class Loss: 1.258377	Domain Loss: 1.854347
# [1216/2000 (59%)]	Loss: 3.146773	Class Loss: 1.301240	Domain Loss: 1.845533
# [1856/2000 (91%)]	Loss: 3.228595	Class Loss: 1.306965	Domain Loss: 1.921630
#
# Source1 Accuracy(classification): 1714.0/2000 (85.7000%)
# Source2 Accuracy(classification): 1261.0/2000 (63.0500%)
# Target Accuracy(classification): 1537.0/2000 (76.8500%)
# Domain Accuracy: 4004.0/6000 (66.7333%)
#
# Epoch: 2
# [576/2000 (28%)]	Loss: 3.131815	Class Loss: 1.160516	Domain Loss: 1.971299
# [1216/2000 (59%)]	Loss: 3.176390	Class Loss: 1.279507	Domain Loss: 1.896883
# [1856/2000 (91%)]	Loss: 3.096266	Class Loss: 1.160625	Domain Loss: 1.935641
#
# Source1 Accuracy(classification): 1679.0/2000 (83.9500%)
# Source2 Accuracy(classification): 1399.0/2000 (69.9500%)
# Target Accuracy(classification): 1599.0/2000 (79.9500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 3
# [576/2000 (28%)]	Loss: 3.166744	Class Loss: 1.174558	Domain Loss: 1.992186
# [1216/2000 (59%)]	Loss: 3.198269	Class Loss: 1.239438	Domain Loss: 1.958831
# [1856/2000 (91%)]	Loss: 3.431254	Class Loss: 1.334501	Domain Loss: 2.096753
#
# Source1 Accuracy(classification): 1678.0/2000 (83.9000%)
# Source2 Accuracy(classification): 1419.0/2000 (70.9500%)
# Target Accuracy(classification): 1606.0/2000 (80.3000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 4
# [576/2000 (28%)]	Loss: 3.130742	Class Loss: 1.179536	Domain Loss: 1.951206
# [1216/2000 (59%)]	Loss: 3.035015	Class Loss: 1.171929	Domain Loss: 1.863086
# [1856/2000 (91%)]	Loss: 2.879874	Class Loss: 0.980445	Domain Loss: 1.899429
#
# Source1 Accuracy(classification): 1680.0/2000 (84.0000%)
# Source2 Accuracy(classification): 1443.0/2000 (72.1500%)
# Target Accuracy(classification): 1602.0/2000 (80.1000%)
# Domain Accuracy: 3997.0/6000 (66.6167%)
#
# Epoch: 5
# [576/2000 (28%)]	Loss: 2.977627	Class Loss: 1.117777	Domain Loss: 1.859851
# [1216/2000 (59%)]	Loss: 2.969490	Class Loss: 1.116107	Domain Loss: 1.853382
# [1856/2000 (91%)]	Loss: 2.958697	Class Loss: 1.162548	Domain Loss: 1.796149
#
# Source1 Accuracy(classification): 1699.0/2000 (84.9500%)
# Source2 Accuracy(classification): 1444.0/2000 (72.2000%)
# Target Accuracy(classification): 1594.0/2000 (79.7000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 6
# [576/2000 (28%)]	Loss: 2.978286	Class Loss: 1.093322	Domain Loss: 1.884964
# [1216/2000 (59%)]	Loss: 2.853460	Class Loss: 1.035005	Domain Loss: 1.818455
# [1856/2000 (91%)]	Loss: 2.891725	Class Loss: 1.097528	Domain Loss: 1.794197
#
# Source1 Accuracy(classification): 1713.0/2000 (85.6500%)
# Source2 Accuracy(classification): 1452.0/2000 (72.6000%)
# Target Accuracy(classification): 1593.0/2000 (79.6500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 7
# [576/2000 (28%)]	Loss: 2.976065	Class Loss: 1.150223	Domain Loss: 1.825842
# [1216/2000 (59%)]	Loss: 2.806543	Class Loss: 0.948143	Domain Loss: 1.858400
# [1856/2000 (91%)]	Loss: 2.840258	Class Loss: 0.972854	Domain Loss: 1.867404
#
# Source1 Accuracy(classification): 1711.0/2000 (85.5500%)
# Source2 Accuracy(classification): 1467.0/2000 (73.3500%)
# Target Accuracy(classification): 1590.0/2000 (79.5000%)
# Domain Accuracy: 4003.0/6000 (66.7167%)
#
# Epoch: 8
# [576/2000 (28%)]	Loss: 2.842754	Class Loss: 1.018698	Domain Loss: 1.824057
# [304/2000 (59%)]	Loss: 3.244023	Class Loss: 1.171721	Domain Loss: 2.072302
# [1856/2000 (91%)]	Loss: 2.749088	Class Loss: 0.867353	Domain Loss: 1.881735
#
# Source1 Accuracy(classification): 1734.0/2000 (86.7000%)
# Source2 Accuracy(classification): 1454.0/2000 (72.7000%)
# Target Accuracy(classification): 1590.0/2000 (79.5000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 9
# [576/2000 (28%)]	Loss: 2.996930	Class Loss: 1.122463	Domain Loss: 1.874468
# [1216/2000 (59%)]	Loss: 3.025867	Class Loss: 1.150082	Domain Loss: 1.875786
# [1856/2000 (91%)]	Loss: 2.765359	Class Loss: 0.869511	Domain Loss: 1.895848
#
# Source1 Accuracy(classification): 1732.0/2000 (86.6000%)
# Source2 Accuracy(classification): 1467.0/2000 (73.3500%)
# Target Accuracy(classification): 1589.0/2000 (79.4500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 10
# [576/2000 (28%)]	Loss: 2.770779	Class Loss: 0.949162	Domain Loss: 1.821618
# [1216/2000 (59%)]	Loss: 2.658880	Class Loss: 0.887727	Domain Loss: 1.771152
# [1856/2000 (91%)]	Loss: 2.696150	Class Loss: 0.790127	Domain Loss: 1.906023
#
# Source1 Accuracy(classification): 1753.0/2000 (87.6500%)
# Source2 Accuracy(classification): 1453.0/2000 (72.6500%)
# Target Accuracy(classification): 1584.0/2000 (79.2000%)
# Domain Accuracy: 4015.0/6000 (66.9167%)
#
# Epoch: 11
# [576/2000 (28%)]	Loss: 2.853141	Class Loss: 0.959534	Domain Loss: 1.893607
# [1216/2000 (59%)]	Loss: 2.997666	Class Loss: 1.121747	Domain Loss: 1.875918
# [1856/2000 (91%)]	Loss: 2.773321	Class Loss: 0.953835	Domain Loss: 1.819486
#
# Source1 Accuracy(classification): 1739.0/2000 (86.9500%)
# Source2 Accuracy(classification): 1478.0/2000 (73.9000%)
# Target Accuracy(classification): 1567.0/2000 (78.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 12
# [576/2000 (28%)]	Loss: 2.844827	Class Loss: 0.983557	Domain Loss: 1.861271
# [1216/2000 (59%)]	Loss: 2.831797	Class Loss: 1.014419	Domain Loss: 1.817378
# [1856/2000 (91%)]	Loss: 3.003572	Class Loss: 1.160891	Domain Loss: 1.842680
#
# Source1 Accuracy(classification): 1756.0/2000 (87.8000%)
# Source2 Accuracy(classification): 1460.0/2000 (73.0000%)
# Target Accuracy(classification): 1574.0/2000 (78.7000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 13
# [576/2000 (28%)]	Loss: 2.802173	Class Loss: 1.052964	Domain Loss: 1.749210
# [1216/2000 (59%)]	Loss: 2.745970	Class Loss: 0.910862	Domain Loss: 1.835108
# [1856/2000 (91%)]	Loss: 2.716940	Class Loss: 0.990651	Domain Loss: 1.726289
#
# Source1 Accuracy(classification): 1745.0/2000 (87.2500%)
# Source2 Accuracy(classification): 1496.0/2000 (74.8000%)
# Target Accuracy(classification): 1570.0/2000 (78.5000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 14
# [576/2000 (28%)]	Loss: 2.894464	Class Loss: 1.042794	Domain Loss: 1.851670
# [1216/2000 (59%)]	Loss: 3.008718	Class Loss: 1.162752	Domain Loss: 1.845967
# [1856/2000 (91%)]	Loss: 2.655040	Class Loss: 0.884965	Domain Loss: 1.770075
#
# Source1 Accuracy(classification): 1751.0/2000 (87.5500%)
# Source2 Accuracy(classification): 1472.0/2000 (73.6000%)
# Target Accuracy(classification): 1573.0/2000 (78.6500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 15
# [576/2000 (28%)]	Loss: 2.706126	Class Loss: 0.898395	Domain Loss: 1.807731
# [1216/2000 (59%)]	Loss: 2.758653	Class Loss: 0.835919	Domain Loss: 1.922734
# [1856/2000 (91%)]	Loss: 2.832925	Class Loss: 0.974545	Domain Loss: 1.858381
#
# Source1 Accuracy(classification): 1763.0/2000 (88.1500%)
# Source2 Accuracy(classification): 1471.0/2000 (73.5500%)
# Target Accuracy(classification): 1564.0/2000 (78.2000%)
# Domain Accuracy: 4031.0/6000 (67.1833%)
#
# Epoch: 16
# [576/2000 (28%)]	Loss: 2.777256	Class Loss: 0.939835	Domain Loss: 1.837421
# [1216/2000 (59%)]	Loss: 2.821354	Class Loss: 0.934178	Domain Loss: 1.887177
# [1856/2000 (91%)]	Loss: 2.921467	Class Loss: 1.012438	Domain Loss: 1.909029
#
# Source1 Accuracy(classification): 1755.0/2000 (87.7500%)
# Source2 Accuracy(classification): 1491.0/2000 (74.5500%)
# Target Accuracy(classification): 1567.0/2000 (78.3500%)
# Domain Accuracy: 4004.0/6000 (66.7333%)
#
# Epoch: 17
# [576/2000 (28%)]	Loss: 2.704684	Class Loss: 0.809878	Domain Loss: 1.894807
# [1216/2000 (59%)]	Loss: 2.882818	Class Loss: 1.011581	Domain Loss: 1.871237
# [1856/2000 (91%)]	Loss: 2.846366	Class Loss: 0.954903	Domain Loss: 1.891463
#
# Source1 Accuracy(classification): 1753.0/2000 (87.6500%)
# Source2 Accuracy(classification): 1491.0/2000 (74.5500%)
# Target Accuracy(classification): 1565.0/2000 (78.2500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 18
# [576/2000 (28%)]	Loss: 2.813371	Class Loss: 0.972936	Domain Loss: 1.840435
# [1216/2000 (59%)]	Loss: 2.851737	Class Loss: 0.990055	Domain Loss: 1.861682
# [1856/2000 (91%)]	Loss: 2.808679	Class Loss: 1.017699	Domain Loss: 1.790980
#
# Source1 Accuracy(classification): 1769.0/2000 (88.4500%)
# Source2 Accuracy(classification): 1483.0/2000 (74.1500%)
# Target Accuracy(classification): 1558.0/2000 (77.9000%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 19
# [576/2000 (28%)]	Loss: 2.760122	Class Loss: 0.934710	Domain Loss: 1.825412
# [1216/2000 (59%)]	Loss: 2.588045	Class Loss: 0.720968	Domain Loss: 1.867077
# [1856/2000 (91%)]	Loss: 2.757414	Class Loss: 0.882878	Domain Loss: 1.874535
#
# Source1 Accuracy(classification): 1771.0/2000 (88.5500%)
# Source2 Accuracy(classification): 1483.0/2000 (74.1500%)
# Target Accuracy(classification): 1557.0/2000 (77.8500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 20
# [576/2000 (28%)]	Loss: 2.725794	Class Loss: 1.016624	Domain Loss: 1.709171
# [1216/2000 (59%)]	Loss: 2.873046	Class Loss: 1.078141	Domain Loss: 1.794905
# [1856/2000 (91%)]	Loss: 2.778365	Class Loss: 0.880839	Domain Loss: 1.897527
#
# Source1 Accuracy(classification): 1760.0/2000 (88.0000%)
# Source2 Accuracy(classification): 1493.0/2000 (74.6500%)
# Target Accuracy(classification): 1567.0/2000 (78.3500%)
# Domain Accuracy: 4004.0/6000 (66.7333%)
#
# Epoch: 21
# [576/2000 (28%)]	Loss: 2.883937	Class Loss: 1.008569	Domain Loss: 1.875367
# [1216/2000 (59%)]	Loss: 2.816145	Class Loss: 0.945152	Domain Loss: 1.870993
# [1856/2000 (91%)]	Loss: 2.952088	Class Loss: 1.079365	Domain Loss: 1.872723
#
# Source1 Accuracy(classification): 1774.0/2000 (88.7000%)
# Source2 Accuracy(classification): 1481.0/2000 (74.0500%)
# Target Accuracy(classification): 1556.0/2000 (77.8000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 22
# [576/2000 (28%)]	Loss: 2.838130	Class Loss: 0.961879	Domain Loss: 1.876251
# [1216/2000 (59%)]	Loss: 2.842832	Class Loss: 0.969773	Domain Loss: 1.873060
# [1856/2000 (91%)]	Loss: 2.829060	Class Loss: 0.980276	Domain Loss: 1.848784
#
# Source1 Accuracy(classification): 1764.0/2000 (88.2000%)
# Source2 Accuracy(classification): 1494.0/2000 (74.7000%)
# Target Accuracy(classification): 1561.0/2000 (78.0500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 23
# [576/2000 (28%)]	Loss: 2.922908	Class Loss: 1.057661	Domain Loss: 1.865247
# [1216/2000 (59%)]	Loss: 3.004795	Class Loss: 1.187483	Domain Loss: 1.817312
# [1856/2000 (91%)]	Loss: 2.816379	Class Loss: 0.976139	Domain Loss: 1.840240
#
# Source1 Accuracy(classification): 1774.0/2000 (88.7000%)
# Source2 Accuracy(classification): 1492.0/2000 (74.6000%)
# Target Accuracy(classification): 1557.0/2000 (77.8500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 24
# [576/2000 (28%)]	Loss: 2.665249	Class Loss: 0.847213	Domain Loss: 1.818036
# [1216/2000 (59%)]	Loss: 2.988795	Class Loss: 1.147740	Domain Loss: 1.841055
# [1856/2000 (91%)]	Loss: 2.958160	Class Loss: 1.107507	Domain Loss: 1.850653
#
# Source1 Accuracy(classification): 1777.0/2000 (88.8500%)
# Source2 Accuracy(classification): 1486.0/2000 (74.3000%)
# Target Accuracy(classification): 1549.0/2000 (77.4500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 25
# [576/2000 (28%)]	Loss: 2.908957	Class Loss: 1.043693	Domain Loss: 1.865263
# [1216/2000 (59%)]	Loss: 2.648647	Class Loss: 0.743457	Domain Loss: 1.905190
# [1856/2000 (91%)]	Loss: 2.762323	Class Loss: 0.898747	Domain Loss: 1.863576
#
# Source1 Accuracy(classification): 1777.0/2000 (88.8500%)
# Source2 Accuracy(classification): 1490.0/2000 (74.5000%)
# Target Accuracy(classification): 1548.0/2000 (77.4000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 26
# [576/2000 (28%)]	Loss: 2.874424	Class Loss: 1.031618	Domain Loss: 1.842806
# [1216/2000 (59%)]	Loss: 2.609096	Class Loss: 0.686461	Domain Loss: 1.922634
# [1856/2000 (91%)]	Loss: 2.863218	Class Loss: 0.980905	Domain Loss: 1.882313
#
# Source1 Accuracy(classification): 1777.0/2000 (88.8500%)
# Source2 Accuracy(classification): 1491.0/2000 (74.5500%)
# Target Accuracy(classification): 1543.0/2000 (77.1500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 27
# [576/2000 (28%)]	Loss: 2.782216	Class Loss: 0.911312	Domain Loss: 1.870904
# [1216/2000 (59%)]	Loss: 2.778870	Class Loss: 0.990252	Domain Loss: 1.788618
# [464/2000 (91%)]	Loss: 2.883873	Class Loss: 0.819558	Domain Loss: 2.064315
#
# Source1 Accuracy(classification): 1770.0/2000 (88.5000%)
# Source2 Accuracy(classification): 1502.0/2000 (75.1000%)
# Target Accuracy(classification): 1552.0/2000 (77.6000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 28
# [576/2000 (28%)]	Loss: 2.575920	Class Loss: 0.647460	Domain Loss: 1.928459
# [1216/2000 (59%)]	Loss: 2.777067	Class Loss: 0.988823	Domain Loss: 1.788244
# [1856/2000 (91%)]	Loss: 3.047315	Class Loss: 1.217121	Domain Loss: 1.830194
#
# Source1 Accuracy(classification): 1771.0/2000 (88.5500%)
# Source2 Accuracy(classification): 1503.0/2000 (75.1500%)
# Target Accuracy(classification): 1555.0/2000 (77.7500%)
# Domain Accuracy: 4002.0/6000 (66.7000%)
#
# Epoch: 29
# [576/2000 (28%)]	Loss: 2.697107	Class Loss: 0.799961	Domain Loss: 1.897146
# [1216/2000 (59%)]	Loss: 2.809947	Class Loss: 0.948547	Domain Loss: 1.861400
# [1856/2000 (91%)]	Loss: 2.663471	Class Loss: 0.844672	Domain Loss: 1.818799
#
# Source1 Accuracy(classification): 1775.0/2000 (88.7500%)
# Source2 Accuracy(classification): 1504.0/2000 (75.2000%)
# Target Accuracy(classification): 1557.0/2000 (77.8500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 30
# [576/2000 (28%)]	Loss: 2.705759	Class Loss: 0.809412	Domain Loss: 1.896347
# [304/2000 (59%)]	Loss: 2.910083	Class Loss: 0.991275	Domain Loss: 1.918808
# [1856/2000 (91%)]	Loss: 2.797833	Class Loss: 0.978321	Domain Loss: 1.819512
#
# Source1 Accuracy(classification): 1777.0/2000 (88.8500%)
# Source2 Accuracy(classification): 1504.0/2000 (75.2000%)
# Target Accuracy(classification): 1553.0/2000 (77.6500%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 31
# [576/2000 (28%)]	Loss: 2.545250	Class Loss: 0.715067	Domain Loss: 1.830183
# [1216/2000 (59%)]	Loss: 2.550012	Class Loss: 0.647454	Domain Loss: 1.902558
# [1856/2000 (91%)]	Loss: 2.710769	Class Loss: 0.929140	Domain Loss: 1.781629
#
# Source1 Accuracy(classification): 1777.0/2000 (88.8500%)
# Source2 Accuracy(classification): 1502.0/2000 (75.1000%)
# Target Accuracy(classification): 1556.0/2000 (77.8000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 32
# [576/2000 (28%)]	Loss: 2.563586	Class Loss: 0.661954	Domain Loss: 1.901632
# [1216/2000 (59%)]	Loss: 2.709537	Class Loss: 0.882253	Domain Loss: 1.827285
# [1856/2000 (91%)]	Loss: 3.020594	Class Loss: 1.194800	Domain Loss: 1.825794
#
# Source1 Accuracy(classification): 1778.0/2000 (88.9000%)
# Source2 Accuracy(classification): 1502.0/2000 (75.1000%)
# Target Accuracy(classification): 1551.0/2000 (77.5500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 33
# [576/2000 (28%)]	Loss: 2.684895	Class Loss: 0.783604	Domain Loss: 1.901292
# [1216/2000 (59%)]	Loss: 2.792651	Class Loss: 0.904903	Domain Loss: 1.887748
# [1856/2000 (91%)]	Loss: 2.558034	Class Loss: 0.667989	Domain Loss: 1.890045
#
# Source1 Accuracy(classification): 1779.0/2000 (88.9500%)
# Source2 Accuracy(classification): 1503.0/2000 (75.1500%)
# Target Accuracy(classification): 1553.0/2000 (77.6500%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 34
# [576/2000 (28%)]	Loss: 2.752198	Class Loss: 0.975776	Domain Loss: 1.776421
# [1216/2000 (59%)]	Loss: 2.732134	Class Loss: 0.876244	Domain Loss: 1.855890
# [1856/2000 (91%)]	Loss: 2.796408	Class Loss: 0.892007	Domain Loss: 1.904401
#
# Source1 Accuracy(classification): 1781.0/2000 (89.0500%)
# Source2 Accuracy(classification): 1502.0/2000 (75.1000%)
# Target Accuracy(classification): 1548.0/2000 (77.4000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 35
# [576/2000 (28%)]	Loss: 2.636467	Class Loss: 0.752991	Domain Loss: 1.883476
# [304/2000 (59%)]	Loss: 2.553925	Class Loss: 0.660439	Domain Loss: 1.893486
# [1856/2000 (91%)]	Loss: 2.712001	Class Loss: 0.938809	Domain Loss: 1.773192
#
# Source1 Accuracy(classification): 1778.0/2000 (88.9000%)
# Source2 Accuracy(classification): 1509.0/2000 (75.4500%)
# Target Accuracy(classification): 1551.0/2000 (77.5500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 36
# [576/2000 (28%)]	Loss: 2.873884	Class Loss: 1.022095	Domain Loss: 1.851790
# [1216/2000 (59%)]	Loss: 2.849298	Class Loss: 1.031792	Domain Loss: 1.817505
# [1856/2000 (91%)]	Loss: 2.987901	Class Loss: 1.136609	Domain Loss: 1.851293
#
# Source1 Accuracy(classification): 1781.0/2000 (89.0500%)
# Source2 Accuracy(classification): 1499.0/2000 (74.9500%)
# Target Accuracy(classification): 1539.0/2000 (76.9500%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 37
# [576/2000 (28%)]	Loss: 2.735802	Class Loss: 1.005541	Domain Loss: 1.730261
# [1216/2000 (59%)]	Loss: 2.857870	Class Loss: 1.004052	Domain Loss: 1.853818
# [1856/2000 (91%)]	Loss: 2.735282	Class Loss: 0.854933	Domain Loss: 1.880349
#
# Source1 Accuracy(classification): 1782.0/2000 (89.1000%)
# Source2 Accuracy(classification): 1510.0/2000 (75.5000%)
# Target Accuracy(classification): 1547.0/2000 (77.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 38
# [576/2000 (28%)]	Loss: 2.735867	Class Loss: 0.899766	Domain Loss: 1.836101
# [1216/2000 (59%)]	Loss: 2.969056	Class Loss: 1.115328	Domain Loss: 1.853728
# [1856/2000 (91%)]	Loss: 2.889436	Class Loss: 1.023394	Domain Loss: 1.866043
#
# Source1 Accuracy(classification): 1781.0/2000 (89.0500%)
# Source2 Accuracy(classification): 1511.0/2000 (75.5500%)
# Target Accuracy(classification): 1546.0/2000 (77.3000%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 39
# [576/2000 (28%)]	Loss: 2.928242	Class Loss: 1.090738	Domain Loss: 1.837504
# [1216/2000 (59%)]	Loss: 2.729870	Class Loss: 0.937070	Domain Loss: 1.792801
# [1856/2000 (91%)]	Loss: 2.926125	Class Loss: 1.021524	Domain Loss: 1.904601
#
# Source1 Accuracy(classification): 1787.0/2000 (89.3500%)
# Source2 Accuracy(classification): 1503.0/2000 (75.1500%)
# Target Accuracy(classification): 1536.0/2000 (76.8000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 40
# [576/2000 (28%)]	Loss: 2.695158	Class Loss: 0.800392	Domain Loss: 1.894766
# [1216/2000 (59%)]	Loss: 2.847326	Class Loss: 1.005009	Domain Loss: 1.842316
# [1856/2000 (91%)]	Loss: 2.822439	Class Loss: 0.980386	Domain Loss: 1.842052
#
# Source1 Accuracy(classification): 1781.0/2000 (89.0500%)
# Source2 Accuracy(classification): 1508.0/2000 (75.4000%)
# Target Accuracy(classification): 1544.0/2000 (77.2000%)
# Domain Accuracy: 4003.0/6000 (66.7167%)
#
# Epoch: 41
# [576/2000 (28%)]	Loss: 2.711102	Class Loss: 0.874754	Domain Loss: 1.836348
# [1216/2000 (59%)]	Loss: 2.912476	Class Loss: 1.030534	Domain Loss: 1.881942
# [1856/2000 (91%)]	Loss: 2.739068	Class Loss: 0.871616	Domain Loss: 1.867452
#
# Source1 Accuracy(classification): 1784.0/2000 (89.2000%)
# Source2 Accuracy(classification): 1508.0/2000 (75.4000%)
# Target Accuracy(classification): 1543.0/2000 (77.1500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 42
# [576/2000 (28%)]	Loss: 2.636139	Class Loss: 0.722014	Domain Loss: 1.914125
# [1216/2000 (59%)]	Loss: 2.708626	Class Loss: 0.883398	Domain Loss: 1.825228
# [1856/2000 (91%)]	Loss: 2.769535	Class Loss: 0.908317	Domain Loss: 1.861218
#
# Source1 Accuracy(classification): 1786.0/2000 (89.3000%)
# Source2 Accuracy(classification): 1509.0/2000 (75.4500%)
# Target Accuracy(classification): 1541.0/2000 (77.0500%)
# Domain Accuracy: 4008.0/6000 (66.8000%)
#
# Epoch: 43
# [576/2000 (28%)]	Loss: 2.755907	Class Loss: 0.936793	Domain Loss: 1.819114
# [1216/2000 (59%)]	Loss: 2.856478	Class Loss: 0.989363	Domain Loss: 1.867114
# [1856/2000 (91%)]	Loss: 2.782354	Class Loss: 0.941791	Domain Loss: 1.840563
#
# Source1 Accuracy(classification): 1783.0/2000 (89.1500%)
# Source2 Accuracy(classification): 1513.0/2000 (75.6500%)
# Target Accuracy(classification): 1541.0/2000 (77.0500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 44
# [576/2000 (28%)]	Loss: 2.605375	Class Loss: 0.668663	Domain Loss: 1.936712
# [1216/2000 (59%)]	Loss: 2.580049	Class Loss: 0.692431	Domain Loss: 1.887618
# [1856/2000 (91%)]	Loss: 2.657500	Class Loss: 0.742853	Domain Loss: 1.914647
#
# Source1 Accuracy(classification): 1789.0/2000 (89.4500%)
# Source2 Accuracy(classification): 1511.0/2000 (75.5500%)
# Target Accuracy(classification): 1538.0/2000 (76.9000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 45
# [576/2000 (28%)]	Loss: 2.633486	Class Loss: 0.709185	Domain Loss: 1.924301
# [1216/2000 (59%)]	Loss: 2.794258	Class Loss: 0.923752	Domain Loss: 1.870506
# [1856/2000 (91%)]	Loss: 2.752728	Class Loss: 0.868420	Domain Loss: 1.884308
#
# Source1 Accuracy(classification): 1790.0/2000 (89.5000%)
# Source2 Accuracy(classification): 1511.0/2000 (75.5500%)
# Target Accuracy(classification): 1537.0/2000 (76.8500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 46
# [576/2000 (28%)]	Loss: 2.586908	Class Loss: 0.763658	Domain Loss: 1.823250
# [1216/2000 (59%)]	Loss: 2.904111	Class Loss: 1.018979	Domain Loss: 1.885132
# [1856/2000 (91%)]	Loss: 2.674140	Class Loss: 0.819090	Domain Loss: 1.855050
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1515.0/2000 (75.7500%)
# Target Accuracy(classification): 1541.0/2000 (77.0500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 47
# [576/2000 (28%)]	Loss: 2.815440	Class Loss: 0.907195	Domain Loss: 1.908246
# [1216/2000 (59%)]	Loss: 2.718578	Class Loss: 0.820239	Domain Loss: 1.898340
# [1856/2000 (91%)]	Loss: 2.910903	Class Loss: 1.101912	Domain Loss: 1.808991
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1516.0/2000 (75.8000%)
# Target Accuracy(classification): 1535.0/2000 (76.7500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 48
# [576/2000 (28%)]	Loss: 2.972055	Class Loss: 1.096011	Domain Loss: 1.876044
# [1216/2000 (59%)]	Loss: 2.898936	Class Loss: 1.090415	Domain Loss: 1.808522
# [1856/2000 (91%)]	Loss: 2.569611	Class Loss: 0.680678	Domain Loss: 1.888934
#
# Source1 Accuracy(classification): 1787.0/2000 (89.3500%)
# Source2 Accuracy(classification): 1516.0/2000 (75.8000%)
# Target Accuracy(classification): 1537.0/2000 (76.8500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 49
# [576/2000 (28%)]	Loss: 2.816353	Class Loss: 0.932990	Domain Loss: 1.883363
# [1216/2000 (59%)]	Loss: 2.760883	Class Loss: 0.910567	Domain Loss: 1.850317
# [1856/2000 (91%)]	Loss: 2.613958	Class Loss: 0.706901	Domain Loss: 1.907057
#
# Source1 Accuracy(classification): 1785.0/2000 (89.2500%)
# Source2 Accuracy(classification): 1520.0/2000 (76.0000%)
# Target Accuracy(classification): 1540.0/2000 (77.0000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 50
# [576/2000 (28%)]	Loss: 2.744709	Class Loss: 0.891994	Domain Loss: 1.852715
# [1216/2000 (59%)]	Loss: 2.927628	Class Loss: 1.091175	Domain Loss: 1.836452
# [1856/2000 (91%)]	Loss: 2.584407	Class Loss: 0.645150	Domain Loss: 1.939257
#
# Source1 Accuracy(classification): 1790.0/2000 (89.5000%)
# Source2 Accuracy(classification): 1513.0/2000 (75.6500%)
# Target Accuracy(classification): 1536.0/2000 (76.8000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 51
# [576/2000 (28%)]	Loss: 2.590616	Class Loss: 0.794898	Domain Loss: 1.795718
# [1216/2000 (59%)]	Loss: 2.798506	Class Loss: 0.879195	Domain Loss: 1.919310
# [1856/2000 (91%)]	Loss: 2.647997	Class Loss: 0.831032	Domain Loss: 1.816965
#
# Source1 Accuracy(classification): 1790.0/2000 (89.5000%)
# Source2 Accuracy(classification): 1520.0/2000 (76.0000%)
# Target Accuracy(classification): 1534.0/2000 (76.7000%)
# Domain Accuracy: 4001.0/6000 (66.6833%)
#
# Epoch: 52
# [576/2000 (28%)]	Loss: 2.733143	Class Loss: 0.913594	Domain Loss: 1.819549
# [1216/2000 (59%)]	Loss: 2.749170	Class Loss: 0.927526	Domain Loss: 1.821643
# [1856/2000 (91%)]	Loss: 2.899970	Class Loss: 1.039024	Domain Loss: 1.860945
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1518.0/2000 (75.9000%)
# Target Accuracy(classification): 1533.0/2000 (76.6500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 53
# [576/2000 (28%)]	Loss: 2.686161	Class Loss: 0.855782	Domain Loss: 1.830379
# [1216/2000 (59%)]	Loss: 2.926052	Class Loss: 1.078682	Domain Loss: 1.847371
# [1856/2000 (91%)]	Loss: 2.668719	Class Loss: 0.826882	Domain Loss: 1.841837
#
# Source1 Accuracy(classification): 1787.0/2000 (89.3500%)
# Source2 Accuracy(classification): 1520.0/2000 (76.0000%)
# Target Accuracy(classification): 1533.0/2000 (76.6500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 54
# [576/2000 (28%)]	Loss: 2.764128	Class Loss: 0.987072	Domain Loss: 1.777056
# [1216/2000 (59%)]	Loss: 2.766119	Class Loss: 0.955301	Domain Loss: 1.810817
# [1856/2000 (91%)]	Loss: 2.647545	Class Loss: 0.702898	Domain Loss: 1.944647
#
# Source1 Accuracy(classification): 1786.0/2000 (89.3000%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1539.0/2000 (76.9500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 55
# [576/2000 (28%)]	Loss: 2.548602	Class Loss: 0.610570	Domain Loss: 1.938033
# [1216/2000 (59%)]	Loss: 2.768358	Class Loss: 0.949821	Domain Loss: 1.818537
# [1856/2000 (91%)]	Loss: 2.798685	Class Loss: 0.953637	Domain Loss: 1.845048
#
# Source1 Accuracy(classification): 1791.0/2000 (89.5500%)
# Source2 Accuracy(classification): 1517.0/2000 (75.8500%)
# Target Accuracy(classification): 1532.0/2000 (76.6000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 56
# [576/2000 (28%)]	Loss: 2.765937	Class Loss: 0.988092	Domain Loss: 1.777845
# [1216/2000 (59%)]	Loss: 2.778614	Class Loss: 0.954369	Domain Loss: 1.824244
# [1856/2000 (91%)]	Loss: 2.870240	Class Loss: 1.045884	Domain Loss: 1.824356
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1522.0/2000 (76.1000%)
# Target Accuracy(classification): 1535.0/2000 (76.7500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 57
# [576/2000 (28%)]	Loss: 2.683369	Class Loss: 0.822749	Domain Loss: 1.860620
# [1216/2000 (59%)]	Loss: 2.774720	Class Loss: 0.888458	Domain Loss: 1.886261
# [1856/2000 (91%)]	Loss: 2.811251	Class Loss: 0.918919	Domain Loss: 1.892332
#
# Source1 Accuracy(classification): 1791.0/2000 (89.5500%)
# Source2 Accuracy(classification): 1521.0/2000 (76.0500%)
# Target Accuracy(classification): 1534.0/2000 (76.7000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 58
# [576/2000 (28%)]	Loss: 2.767070	Class Loss: 0.911730	Domain Loss: 1.855340
# [1216/2000 (59%)]	Loss: 2.710031	Class Loss: 0.863920	Domain Loss: 1.846111
# [464/2000 (91%)]	Loss: 2.703603	Class Loss: 0.760861	Domain Loss: 1.942743
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1527.0/2000 (76.3500%)
# Target Accuracy(classification): 1535.0/2000 (76.7500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 59
# [576/2000 (28%)]	Loss: 2.619571	Class Loss: 0.784201	Domain Loss: 1.835371
# [1216/2000 (59%)]	Loss: 2.681942	Class Loss: 0.852792	Domain Loss: 1.829149
# [1856/2000 (91%)]	Loss: 2.492782	Class Loss: 0.665294	Domain Loss: 1.827488
#
# Source1 Accuracy(classification): 1793.0/2000 (89.6500%)
# Source2 Accuracy(classification): 1518.0/2000 (75.9000%)
# Target Accuracy(classification): 1528.0/2000 (76.4000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 60
# [576/2000 (28%)]	Loss: 2.748741	Class Loss: 0.925075	Domain Loss: 1.823666
# [1216/2000 (59%)]	Loss: 2.728264	Class Loss: 0.791748	Domain Loss: 1.936516
# [1856/2000 (91%)]	Loss: 2.671597	Class Loss: 0.758188	Domain Loss: 1.913409
#
# Source1 Accuracy(classification): 1792.0/2000 (89.6000%)
# Source2 Accuracy(classification): 1518.0/2000 (75.9000%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 61
# [576/2000 (28%)]	Loss: 2.626026	Class Loss: 0.765151	Domain Loss: 1.860875
# [1216/2000 (59%)]	Loss: 2.638470	Class Loss: 0.703754	Domain Loss: 1.934716
# [1856/2000 (91%)]	Loss: 2.683954	Class Loss: 0.748719	Domain Loss: 1.935235
#
# Source1 Accuracy(classification): 1792.0/2000 (89.6000%)
# Source2 Accuracy(classification): 1518.0/2000 (75.9000%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 62
# [576/2000 (28%)]	Loss: 2.821307	Class Loss: 0.935744	Domain Loss: 1.885563
# [1216/2000 (59%)]	Loss: 2.782563	Class Loss: 0.969727	Domain Loss: 1.812836
# [1856/2000 (91%)]	Loss: 2.866021	Class Loss: 0.951955	Domain Loss: 1.914066
#
# Source1 Accuracy(classification): 1791.0/2000 (89.5500%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 63
# [576/2000 (28%)]	Loss: 2.712672	Class Loss: 0.823849	Domain Loss: 1.888823
# [1216/2000 (59%)]	Loss: 2.506729	Class Loss: 0.648730	Domain Loss: 1.857999
# [1856/2000 (91%)]	Loss: 2.816885	Class Loss: 0.958775	Domain Loss: 1.858111
#
# Source1 Accuracy(classification): 1795.0/2000 (89.7500%)
# Source2 Accuracy(classification): 1515.0/2000 (75.7500%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 64
# [576/2000 (28%)]	Loss: 2.918441	Class Loss: 1.053107	Domain Loss: 1.865335
# [1216/2000 (59%)]	Loss: 2.945036	Class Loss: 1.154950	Domain Loss: 1.790086
# [1856/2000 (91%)]	Loss: 2.506473	Class Loss: 0.548276	Domain Loss: 1.958196
#
# Source1 Accuracy(classification): 1788.0/2000 (89.4000%)
# Source2 Accuracy(classification): 1532.0/2000 (76.6000%)
# Target Accuracy(classification): 1532.0/2000 (76.6000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 65
# [576/2000 (28%)]	Loss: 2.777711	Class Loss: 0.917806	Domain Loss: 1.859905
# [1216/2000 (59%)]	Loss: 2.554765	Class Loss: 0.642360	Domain Loss: 1.912405
# [1856/2000 (91%)]	Loss: 2.736686	Class Loss: 0.860885	Domain Loss: 1.875801
#
# Source1 Accuracy(classification): 1792.0/2000 (89.6000%)
# Source2 Accuracy(classification): 1523.0/2000 (76.1500%)
# Target Accuracy(classification): 1528.0/2000 (76.4000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 66
# [576/2000 (28%)]	Loss: 2.714655	Class Loss: 0.824602	Domain Loss: 1.890053
# [1216/2000 (59%)]	Loss: 2.779729	Class Loss: 0.945911	Domain Loss: 1.833819
# [1856/2000 (91%)]	Loss: 2.527234	Class Loss: 0.646959	Domain Loss: 1.880275
#
# Source1 Accuracy(classification): 1790.0/2000 (89.5000%)
# Source2 Accuracy(classification): 1533.0/2000 (76.6500%)
# Target Accuracy(classification): 1531.0/2000 (76.5500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 67
# [576/2000 (28%)]	Loss: 2.608624	Class Loss: 0.660827	Domain Loss: 1.947798
# [1216/2000 (59%)]	Loss: 2.593213	Class Loss: 0.653307	Domain Loss: 1.939906
# [1856/2000 (91%)]	Loss: 2.518490	Class Loss: 0.577071	Domain Loss: 1.941418
#
# Source1 Accuracy(classification): 1792.0/2000 (89.6000%)
# Source2 Accuracy(classification): 1524.0/2000 (76.2000%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 68
# [576/2000 (28%)]	Loss: 2.790468	Class Loss: 0.938398	Domain Loss: 1.852070
# [1216/2000 (59%)]	Loss: 2.772293	Class Loss: 0.966818	Domain Loss: 1.805475
# [1856/2000 (91%)]	Loss: 2.668535	Class Loss: 0.860628	Domain Loss: 1.807907
#
# Source1 Accuracy(classification): 1791.0/2000 (89.5500%)
# Source2 Accuracy(classification): 1534.0/2000 (76.7000%)
# Target Accuracy(classification): 1532.0/2000 (76.6000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 69
# [576/2000 (28%)]	Loss: 2.783331	Class Loss: 0.956995	Domain Loss: 1.826336
# [1216/2000 (59%)]	Loss: 2.706324	Class Loss: 0.813436	Domain Loss: 1.892888
# [1856/2000 (91%)]	Loss: 2.684699	Class Loss: 0.865933	Domain Loss: 1.818766
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1513.0/2000 (75.6500%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 70
# [576/2000 (28%)]	Loss: 2.752171	Class Loss: 0.917226	Domain Loss: 1.834945
# [1216/2000 (59%)]	Loss: 2.758367	Class Loss: 0.904360	Domain Loss: 1.854006
# [1856/2000 (91%)]	Loss: 2.793521	Class Loss: 0.953282	Domain Loss: 1.840240
#
# Source1 Accuracy(classification): 1794.0/2000 (89.7000%)
# Source2 Accuracy(classification): 1522.0/2000 (76.1000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 71
# [576/2000 (28%)]	Loss: 2.579313	Class Loss: 0.787618	Domain Loss: 1.791695
# [1216/2000 (59%)]	Loss: 2.822945	Class Loss: 0.998261	Domain Loss: 1.824684
# [1856/2000 (91%)]	Loss: 2.569468	Class Loss: 0.630411	Domain Loss: 1.939057
#
# Source1 Accuracy(classification): 1790.0/2000 (89.5000%)
# Source2 Accuracy(classification): 1531.0/2000 (76.5500%)
# Target Accuracy(classification): 1530.0/2000 (76.5000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 72
# [576/2000 (28%)]	Loss: 2.638465	Class Loss: 0.748238	Domain Loss: 1.890227
# [1216/2000 (59%)]	Loss: 2.663595	Class Loss: 0.848348	Domain Loss: 1.815247
# [1856/2000 (91%)]	Loss: 2.823083	Class Loss: 0.947366	Domain Loss: 1.875718
#
# Source1 Accuracy(classification): 1798.0/2000 (89.9000%)
# Source2 Accuracy(classification): 1520.0/2000 (76.0000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 73
# [576/2000 (28%)]	Loss: 2.816410	Class Loss: 0.911069	Domain Loss: 1.905341
# [1216/2000 (59%)]	Loss: 2.871233	Class Loss: 0.946873	Domain Loss: 1.924361
# [1856/2000 (91%)]	Loss: 2.716326	Class Loss: 0.898341	Domain Loss: 1.817986
#
# Source1 Accuracy(classification): 1789.0/2000 (89.4500%)
# Source2 Accuracy(classification): 1534.0/2000 (76.7000%)
# Target Accuracy(classification): 1532.0/2000 (76.6000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 74
# [576/2000 (28%)]	Loss: 2.833012	Class Loss: 0.999392	Domain Loss: 1.833620
# [1216/2000 (59%)]	Loss: 2.726598	Class Loss: 0.855496	Domain Loss: 1.871102
# [1856/2000 (91%)]	Loss: 2.596212	Class Loss: 0.742311	Domain Loss: 1.853901
#
# Source1 Accuracy(classification): 1795.0/2000 (89.7500%)
# Source2 Accuracy(classification): 1522.0/2000 (76.1000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 75
# [576/2000 (28%)]	Loss: 2.570062	Class Loss: 0.641171	Domain Loss: 1.928891
# [1216/2000 (59%)]	Loss: 2.638789	Class Loss: 0.841356	Domain Loss: 1.797432
# [1856/2000 (91%)]	Loss: 2.854069	Class Loss: 0.973351	Domain Loss: 1.880718
#
# Source1 Accuracy(classification): 1794.0/2000 (89.7000%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 76
# [576/2000 (28%)]	Loss: 2.849756	Class Loss: 0.939356	Domain Loss: 1.910400
# [1216/2000 (59%)]	Loss: 2.831010	Class Loss: 0.976615	Domain Loss: 1.854395
# [1856/2000 (91%)]	Loss: 2.666225	Class Loss: 0.775318	Domain Loss: 1.890908
#
# Source1 Accuracy(classification): 1791.0/2000 (89.5500%)
# Source2 Accuracy(classification): 1529.0/2000 (76.4500%)
# Target Accuracy(classification): 1530.0/2000 (76.5000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 77
# [576/2000 (28%)]	Loss: 2.722196	Class Loss: 0.817634	Domain Loss: 1.904562
# [1216/2000 (59%)]	Loss: 2.736834	Class Loss: 0.869831	Domain Loss: 1.867003
# [1856/2000 (91%)]	Loss: 2.707107	Class Loss: 0.790013	Domain Loss: 1.917094
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1523.0/2000 (76.1500%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 78
# [576/2000 (28%)]	Loss: 2.752584	Class Loss: 0.827120	Domain Loss: 1.925464
# [1216/2000 (59%)]	Loss: 2.570192	Class Loss: 0.788205	Domain Loss: 1.781987
# [1856/2000 (91%)]	Loss: 2.569397	Class Loss: 0.642132	Domain Loss: 1.927265
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1523.0/2000 (76.1500%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 79
# [576/2000 (28%)]	Loss: 2.840848	Class Loss: 0.997371	Domain Loss: 1.843477
# [1216/2000 (59%)]	Loss: 2.726714	Class Loss: 0.881563	Domain Loss: 1.845151
# [1856/2000 (91%)]	Loss: 2.584635	Class Loss: 0.752784	Domain Loss: 1.831851
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1523.0/2000 (76.1500%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 80
# [576/2000 (28%)]	Loss: 2.884303	Class Loss: 1.050128	Domain Loss: 1.834175
# [1216/2000 (59%)]	Loss: 2.634708	Class Loss: 0.777299	Domain Loss: 1.857409
# [1856/2000 (91%)]	Loss: 2.570786	Class Loss: 0.692038	Domain Loss: 1.878747
#
# Source1 Accuracy(classification): 1798.0/2000 (89.9000%)
# Source2 Accuracy(classification): 1524.0/2000 (76.2000%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 81
# [576/2000 (28%)]	Loss: 2.616651	Class Loss: 0.707329	Domain Loss: 1.909322
# [1216/2000 (59%)]	Loss: 2.920045	Class Loss: 1.047097	Domain Loss: 1.872948
# [1856/2000 (91%)]	Loss: 2.661093	Class Loss: 0.905734	Domain Loss: 1.755359
#
# Source1 Accuracy(classification): 1800.0/2000 (90.0000%)
# Source2 Accuracy(classification): 1522.0/2000 (76.1000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 82
# [576/2000 (28%)]	Loss: 2.705567	Class Loss: 0.882207	Domain Loss: 1.823360
# [1216/2000 (59%)]	Loss: 2.710638	Class Loss: 0.877807	Domain Loss: 1.832831
# [1856/2000 (91%)]	Loss: 2.501301	Class Loss: 0.723686	Domain Loss: 1.777615
#
# Source1 Accuracy(classification): 1792.0/2000 (89.6000%)
# Source2 Accuracy(classification): 1527.0/2000 (76.3500%)
# Target Accuracy(classification): 1532.0/2000 (76.6000%)
# Domain Accuracy: 4000.0/6000 (66.6667%)
#
# Epoch: 83
# [576/2000 (28%)]	Loss: 2.972227	Class Loss: 1.106672	Domain Loss: 1.865556
# [1216/2000 (59%)]	Loss: 2.756000	Class Loss: 0.871181	Domain Loss: 1.884819
# [1856/2000 (91%)]	Loss: 2.617249	Class Loss: 0.670072	Domain Loss: 1.947177
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1524.0/2000 (76.2000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 84
# [576/2000 (28%)]	Loss: 2.722588	Class Loss: 0.840762	Domain Loss: 1.881826
# [1216/2000 (59%)]	Loss: 2.716264	Class Loss: 0.894139	Domain Loss: 1.822125
# [1856/2000 (91%)]	Loss: 2.632350	Class Loss: 0.797583	Domain Loss: 1.834768
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1521.0/2000 (76.0500%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 85
# [576/2000 (28%)]	Loss: 2.734601	Class Loss: 0.825903	Domain Loss: 1.908698
# [304/2000 (59%)]	Loss: 2.600901	Class Loss: 0.739720	Domain Loss: 1.861181
# [1856/2000 (91%)]	Loss: 2.604335	Class Loss: 0.646667	Domain Loss: 1.957669
#
# Source1 Accuracy(classification): 1798.0/2000 (89.9000%)
# Source2 Accuracy(classification): 1519.0/2000 (75.9500%)
# Target Accuracy(classification): 1522.0/2000 (76.1000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 86
# [576/2000 (28%)]	Loss: 2.585028	Class Loss: 0.702175	Domain Loss: 1.882853
# [1216/2000 (59%)]	Loss: 2.648721	Class Loss: 0.791115	Domain Loss: 1.857606
# [1856/2000 (91%)]	Loss: 2.657591	Class Loss: 0.709627	Domain Loss: 1.947965
#
# Source1 Accuracy(classification): 1793.0/2000 (89.6500%)
# Source2 Accuracy(classification): 1532.0/2000 (76.6000%)
# Target Accuracy(classification): 1529.0/2000 (76.4500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 87
# [576/2000 (28%)]	Loss: 2.747293	Class Loss: 0.919911	Domain Loss: 1.827383
# [1216/2000 (59%)]	Loss: 2.673892	Class Loss: 0.762027	Domain Loss: 1.911865
# [1856/2000 (91%)]	Loss: 2.675623	Class Loss: 0.807526	Domain Loss: 1.868097
#
# Source1 Accuracy(classification): 1796.0/2000 (89.8000%)
# Source2 Accuracy(classification): 1527.0/2000 (76.3500%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 88
# [576/2000 (28%)]	Loss: 2.547967	Class Loss: 0.732644	Domain Loss: 1.815323
# [1216/2000 (59%)]	Loss: 2.647720	Class Loss: 0.760445	Domain Loss: 1.887275
# [1856/2000 (91%)]	Loss: 2.817456	Class Loss: 1.004316	Domain Loss: 1.813140
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1521.0/2000 (76.0500%)
# Target Accuracy(classification): 1523.0/2000 (76.1500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 89
# [576/2000 (28%)]	Loss: 2.616771	Class Loss: 0.830465	Domain Loss: 1.786306
# [304/2000 (59%)]	Loss: 2.535216	Class Loss: 0.574342	Domain Loss: 1.960874
# [1856/2000 (91%)]	Loss: 2.885463	Class Loss: 0.980899	Domain Loss: 1.904564
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 90
# [576/2000 (28%)]	Loss: 2.902778	Class Loss: 0.989078	Domain Loss: 1.913700
# [1216/2000 (59%)]	Loss: 2.692120	Class Loss: 0.862391	Domain Loss: 1.829728
# [1856/2000 (91%)]	Loss: 2.761815	Class Loss: 0.861174	Domain Loss: 1.900641
#
# Source1 Accuracy(classification): 1795.0/2000 (89.7500%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 91
# [576/2000 (28%)]	Loss: 2.805841	Class Loss: 0.938856	Domain Loss: 1.866985
# [1216/2000 (59%)]	Loss: 2.621124	Class Loss: 0.741030	Domain Loss: 1.880094
# [1856/2000 (91%)]	Loss: 2.654611	Class Loss: 0.795508	Domain Loss: 1.859103
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1520.0/2000 (76.0000%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 92
# [576/2000 (28%)]	Loss: 2.666701	Class Loss: 0.737580	Domain Loss: 1.929122
# [1216/2000 (59%)]	Loss: 2.451257	Class Loss: 0.553308	Domain Loss: 1.897948
# [1856/2000 (91%)]	Loss: 2.772525	Class Loss: 0.934698	Domain Loss: 1.837828
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1521.0/2000 (76.0500%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 93
# [576/2000 (28%)]	Loss: 2.711716	Class Loss: 0.791740	Domain Loss: 1.919976
# [1216/2000 (59%)]	Loss: 2.576774	Class Loss: 0.755967	Domain Loss: 1.820807
# [1856/2000 (91%)]	Loss: 2.752023	Class Loss: 0.833993	Domain Loss: 1.918030
#
# Source1 Accuracy(classification): 1799.0/2000 (89.9500%)
# Source2 Accuracy(classification): 1521.0/2000 (76.0500%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 94
# [576/2000 (28%)]	Loss: 2.752431	Class Loss: 0.899462	Domain Loss: 1.852969
# [1216/2000 (59%)]	Loss: 2.707888	Class Loss: 0.802852	Domain Loss: 1.905036
# [1856/2000 (91%)]	Loss: 2.689167	Class Loss: 0.803236	Domain Loss: 1.885931
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1526.0/2000 (76.3000%)
# Target Accuracy(classification): 1525.0/2000 (76.2500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 95
# [576/2000 (28%)]	Loss: 2.692737	Class Loss: 0.817178	Domain Loss: 1.875559
# [1216/2000 (59%)]	Loss: 2.538201	Class Loss: 0.740167	Domain Loss: 1.798034
# [1856/2000 (91%)]	Loss: 2.557742	Class Loss: 0.754339	Domain Loss: 1.803403
#
# Source1 Accuracy(classification): 1797.0/2000 (89.8500%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1523.0/2000 (76.1500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 96
# [576/2000 (28%)]	Loss: 2.646970	Class Loss: 0.704419	Domain Loss: 1.942551
# [1216/2000 (59%)]	Loss: 2.673972	Class Loss: 0.884042	Domain Loss: 1.789930
# [1856/2000 (91%)]	Loss: 2.669633	Class Loss: 0.875999	Domain Loss: 1.793634
#
# Source1 Accuracy(classification): 1798.0/2000 (89.9000%)
# Source2 Accuracy(classification): 1525.0/2000 (76.2500%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 97
# [576/2000 (28%)]	Loss: 2.543297	Class Loss: 0.711946	Domain Loss: 1.831351
# [1216/2000 (59%)]	Loss: 2.683952	Class Loss: 0.814525	Domain Loss: 1.869427
# [1856/2000 (91%)]	Loss: 2.710270	Class Loss: 0.879342	Domain Loss: 1.830928
#
# Source1 Accuracy(classification): 1795.0/2000 (89.7500%)
# Source2 Accuracy(classification): 1528.0/2000 (76.4000%)
# Target Accuracy(classification): 1527.0/2000 (76.3500%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 98
# [576/2000 (28%)]	Loss: 2.630189	Class Loss: 0.684479	Domain Loss: 1.945710
# [1216/2000 (59%)]	Loss: 2.799713	Class Loss: 0.869675	Domain Loss: 1.930038
# [1856/2000 (91%)]	Loss: 2.653842	Class Loss: 0.753093	Domain Loss: 1.900749
#
# Source1 Accuracy(classification): 1798.0/2000 (89.9000%)
# Source2 Accuracy(classification): 1524.0/2000 (76.2000%)
# Target Accuracy(classification): 1528.0/2000 (76.4000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# Epoch: 99
# [576/2000 (28%)]	Loss: 2.565650	Class Loss: 0.804847	Domain Loss: 1.760802
# [1216/2000 (59%)]	Loss: 2.715390	Class Loss: 0.869719	Domain Loss: 1.845671
# [1856/2000 (91%)]	Loss: 2.782574	Class Loss: 0.952273	Domain Loss: 1.830302
#
# Source1 Accuracy(classification): 1800.0/2000 (90.0000%)
# Source2 Accuracy(classification): 1524.0/2000 (76.2000%)
# Target Accuracy(classification): 1526.0/2000 (76.3000%)
# Domain Accuracy: 3999.0/6000 (66.6500%)
#
# total run time: (min) 0.7477355480194092

# %%
plt.plot(range(len(total_loss)),total_loss,c='r',label='total_loss')
plt.plot(d_loss,c='b',label='domain_loss')
plt.plot(c_loss,c='y',label='clf_loss')
plt.title('traing')
plt.legend(loc='best')
plt.show()

# %%
print('max target accuracy: ',max(acc_list3))
plt.plot(range(len(acc_list1)),acc_list1,c='r',label='source1(Twitter)_acc')
plt.plot(acc_list2,c='b',label='source2(Forum)_acc')
plt.plot(acc_list3,c='g',label='target(Wiki)_acc')
plt.plot(acc_list4,c='y',label='domain_acc')
plt.axhline(max(acc_list3),c='b',linestyle='--')
plt.title('testing')
plt.legend(loc='best')
plt.show()
# Out:
# max target accuracy:  80.3

# %% [markdown]
# 100 epoches
# 51.9, 100data
# 66.4, 200data
# 79.6, 400data
# 80.35, 600
# 82.85, 800
# 82.05,  1000
# 80.3, 2000

# %% [markdown]
# 1.   62.6 500. epoch = 10
# 2.   78.05 1000. epoch = 20
# 3.   80.6  2000. epoch = 40
# 4.   79.85 4000  epoch = 80
# 5.   79.4  6000. epoch = 100
