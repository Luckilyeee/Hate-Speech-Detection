# %%
# W+F / T
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



plt.plot([200, 400, 600, 800, 1000], [56.55*0.01, 73.85*0.01, 75.00*0.01, 74.30*0.01, 75.30*0.01],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='W+F->T')
plt.plot([200, 400, 600, 800, 1000], [68.85*0.01, 74.50*0.01, 74.40*0.01, 74.15*0.01, 74.95*0.01],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='source only')
# plt.plot([200, 400, 600, 800, 1000], [77.30*0.01, 87.15, 87.90, 88.55, 88.85],marker='v', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='Pure Classification')
# plt.plot([200, 400, 600, 800, 1000], [51.45*0.01, 70.85*0.01, 76.95*0.01, 76.65*0.01, 76.80*0.01],marker='*', markerfacecolor='red', markersize=10, color='red', linewidth=1, label='W->T')
# plt.plot([200, 400, 600, 800, 1000], [56.35*0.01, 64.25*0.01, 61.35*0.01, 63.0*0.01, 64.1*0.01],marker='*', markerfacecolor='blue', markersize=10, color='blue', linewidth=1, label='F->T')



#plt.xticks(np.arange(500, 600, 100))
plt.xlabel('Training size')
plt.ylabel('Accuracy')
axes = plt.gca()
axes.set_ylim([0.4,0.85])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
#plt.savefig("W+F / T.png", dpi = 216)

# %%
# W+T / F
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot([200, 400, 600, 800, 1000], [52.30*0.01, 61.65*0.01, 68.85*0.01, 69.70*0.01, 67.65*0.01],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='W+T->F')
plt.plot([200, 400, 600, 800, 1000], [49.30*0.01, 53.70*0.01, 55.70*0.01, 56.30*0.01, 56.80*0.01],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='source only')
# plt.plot([200, 400, 600, 800, 1000], [56.75, 69.45, 74.10, 75.00, 76.30],marker='v', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='Pure Classification')
# plt.plot([200, 400, 600, 800, 1000], [53.75*0.01, 61.10*0.01, 57.80*0.01, 63.60*0.01, 65.70*0.01],marker='*', markerfacecolor='red', markersize=10, color='red', linewidth=1, label='W->F')
# plt.plot([200, 400, 600, 800, 1000], [49.80*0.01, 57.20*0.01, 63.75*0.01, 57.80*0.01, 65.80*0.01],marker='*', markerfacecolor='blue', markersize=10, color='blue', linewidth=1, label='T->F')

#plt.xticks(np.arange(500, 600, 100))
plt.xlabel('Training size')
plt.ylabel('Accuracy')
axes = plt.gca()
axes.set_ylim([0.4,0.85])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
#plt.savefig("W+F / T.png", dpi = 216)

# %%
# F+T / W
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot([200, 400, 600, 800, 1000], [66.40*0.01, 79.60*0.01, 80.35*0.01, 82.85*0.01, 82.05*0.01],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='F+T->W')
plt.plot([200, 400, 600, 800, 1000], [66.45*0.01, 76.00*0.01, 77.45*0.01, 79.45*0.01, 79.35*0.01],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='source only')
# plt.plot([200, 400, 600, 800, 1000], [68.10, 80.00, 82.40, 83.80, 84.55],marker='v', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='Pure Classification')
# plt.plot([200, 400, 600, 800, 1000], [58.60*0.01, 53.55*0.01, 58.40*0.01, 62.50*0.01, 59.55*0.01],marker='*', markerfacecolor='red', markersize=10, color='red', linewidth=1, label='F->W')
# plt.plot([200, 400, 600, 800, 1000], [55.60*0.01, 72.25*0.01, 77.10*0.01, 77.35*0.01, 77.80*0.01],marker='*', markerfacecolor='blue', markersize=10, color='blue', linewidth=1, label='T->W')

#plt.xticks(np.arange(500, 600, 100))
plt.xlabel('Training size')
plt.ylabel('Accuracy')
axes = plt.gca()
axes.set_ylim([0.4,0.85])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
#plt.savefig("W+F / T.png", dpi = 216)

# %%
# Single Source  
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot([200, 400, 600, 800, 1000], [58.60, 53.55, 58.40, 62.50, 59.55],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='F->W')
plt.plot([200, 400, 600, 800, 1000], [53.75, 61.10, 57.80, 63.60, 65.70],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='W->F')
plt.plot([200, 400, 600, 800, 1000], [56.35, 64.25, 61.35, 63.0, 64.1],marker='*', markerfacecolor='red', markersize=10, color='red', linewidth=1, label='F->T')
plt.plot([200, 400, 600, 800, 1000], [49.8, 57.2, 63.75, 57.8, 65.8],marker='o', markerfacecolor='red', markersize=10, color='red', linewidth=1, label='T->F')
plt.plot([200, 400, 600, 800, 1000], [51.45, 70.85, 76.95, 76.65, 76.80],marker='*', markerfacecolor='blue', markersize=10, color='blue', linewidth=1, label='W->T')
plt.plot([200, 400, 600, 800, 1000], [55.60, 72.25, 77.10, 77.35, 77.80],marker='o', markerfacecolor='blue', markersize=10, color='blue', linewidth=1, label='T->W')

#plt.xticks(np.arange(500, 600, 100))
plt.xlabel('Dataset size')
plt.ylabel('Accuracy')
plt.legend()
