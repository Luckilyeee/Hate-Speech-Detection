# %% [markdown]
# combine two soureces into one big source and then use DANN

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import torchvision
import torch.optim as optim

import numpy as np
from sklearn.manifold import TSNE

import argparse, sys, os

import torch
from torchtext import data, datasets
import random
torch.backends.cudnn.deterministic = True

import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import time
from collections import Counter
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-826dd459-a41e-4cfd-bad3-6b74b79e7f3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-826dd459-a41e-4cfd-bad3-6b74b79e7f3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('stopwords')


twitter = pd.read_csv("twitter.csv")
forum = pd.read_csv("Forum.csv")
wiki = pd.read_csv("Wiki.csv")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# remove puctunations, https
import re
def  clean_text(df, text_field):
    df[text_field] = df[text_field].str.lower()
    df[text_field] = df[text_field].apply(lambda elem: re.sub(r"(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    return df

twitter = clean_text(twitter, 'text')
forum = clean_text(forum, 'text')
wiki = clean_text(wiki, 'text')

stopwords = nltk.corpus.stopwords.words('english')
twitter['text'] = twitter['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
forum['text'] = forum['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
wiki['text'] = wiki['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
twitter['domain'] = 1
forum['domain'] = 0
wiki['domain'] = 0

# %%
twitter = twitter[['text', 'label', 'domain']]
forum = forum[['text', 'label', 'domain']]
wiki = wiki[['text', 'label', 'domain']]

# %%
train_data = pd.concat([forum, wiki])
test_data = twitter

# %%
train_data.to_csv('train.csv', index=False)
test_data.to_csv('test.csv', index=False)

# %% [markdown]
# #tokenize

# %%
SEED = 1234
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
TEXT = data.Field(tokenize = 'spacy', batch_first=True)
LABEL = data.LabelField(dtype=torch.float)
DOMAIN = data.LabelField(dtype=torch.float)

# %%
#loading custom dataset
train =data.TabularDataset(path = 'train.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(train.examples[0]))
# Out:
# {'text': ['watch', 'video', 'minutes', 'see', 'eventually', 'biracial', 'minority', 'butchered'], 'label': '1.0', 'domain': '0'}

# %%
#loading custom dataset
test =data.TabularDataset(path = 'test.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(test.examples[0]))
# Out:
# {'text': ['paid', 'hold', 'monkey', 'look', 'monkey', 'real', 'af'], 'label': '0.0', 'domain': '1'}

# %% [markdown]
# split train, test, val

# %%
S_train_data, S_test_data = train.split(split_ratio=0.8, random_state = random.seed(SEED))
T_train_data, T_test_data = test.split(split_ratio=0.8, random_state = random.seed(SEED))

# %% [markdown]
# #convert texts into integer sequences.

# %% [markdown]
# build vocabulary

# %%
#initialize glove embeddings
MAX_VOCAB_SIZE = 25_000

TEXT.build_vocab(S_train_data, T_train_data, 
                 max_size = MAX_VOCAB_SIZE, 
                 vectors = "glove.6B.100d", 
                 unk_init = torch.Tensor.normal_) 
LABEL.build_vocab(S_train_data, T_train_data)
DOMAIN.build_vocab(S_train_data, T_train_data)

# %% [markdown]
# creat iterators

# %%
#set batch size
BATCH_SIZE = 64

#check whether cuda is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  

#Load an iterator
S_train_iterator, S_test_iterator = data.BucketIterator.splits(
    (S_train_data,  S_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

T_train_iterator, T_test_iterator = data.BucketIterator.splits(
    (T_train_data, T_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

# %%
class GradReverse(torch.autograd.Function):
    """
    Extension of grad reverse layer
    """
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        grad_output = grad_output.neg() * ctx.constant
        return grad_output, None

    def grad_reverse(x, constant):
        return GradReverse.apply(x, constant)

class Extractor(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, 
                 dropout, pad_idx, pretrained_embeddings):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        self.embedding.weight.data.copy_(pretrained_embeddings)
        self.conv_0 = nn.Conv2d(in_channels = 1, 
                                out_channels = n_filters, 
                                kernel_size = (filter_sizes, embedding_dim))
        
        
        
        self.fc = nn.Linear(n_filters, output_dim)
        
        self.dropout = nn.Dropout(dropout)

        # self.relu = nn.ReLU(inplace=True)
        # self.max_pool1d = nn.MaxPool1d(2,2)
        
    def forward(self, text):
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)
                
        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved_0 = F.relu(self.conv_0(embedded).squeeze(3))
            
        #conved_n = [batch size, n_filters, sent len - filter_sizes[n] + 1]
        
        pooled_0 = F.max_pool1d(conved_0, conved_0.shape[2]).squeeze(2)
        
        #pooled_n = [batch size, n_filters]
        x = self.dropout(pooled_0)
        #x = [batch size, n_filters * len(filter_sizes)]
            
        return x

class Class_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Class_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input):
        x = self.fc(input)
        return x

class Domain_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Domain_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input, constant):
        input = GradReverse.grad_reverse(input, constant)
        return self.fc(input)

# %%
def optimizer_scheduler(optimizer, p):
    """
    Adjust the learning rate of optimizer
    :param optimizer: optimizer for updating parameters
    :param p: a variable for adjusting learning rate
    :return: optimizer
    """
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75

    return optimizer

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 100
FILTER_SIZES = 1
OUTPUT_DIM = 1
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]
pretrained_embeddings = TEXT.vocab.vectors

extractor = Extractor(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT, PAD_IDX,pretrained_embeddings )
class_classifier = Class_classifier(N_FILTERS, OUTPUT_DIM)
domain_classifier = Domain_classifier(N_FILTERS, OUTPUT_DIM)

# %% [markdown]
# check the number of parameters

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(extractor) + count_parameters(class_classifier) + count_parameters(domain_classifier):,} trainable parameters')
# Out:
# The model has 2,510,603 trainable parameters

# %% [markdown]
# zero the initial weights of the unknown and padding tokens

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]

extractor.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
extractor.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

# %%
criterion = nn.BCEWithLogitsLoss()

extractor = extractor.to(device)
class_classifier = class_classifier.to(device)
domain_classifier = domain_classifier.to(device)

criterion = criterion.to(device)

# %% [markdown]
# define function to calculate the correct predictions

# %%
def train(training_mode, extractor, class_classifier, domain_classifier, criterion,
          source_data, target_data, optimizer, epoch):
  
    epoch_loss = 0
    epoch_acc = 0

    # setup models
    extractor.train()
    class_classifier.train()
    domain_classifier.train()

    # steps
    start_steps = epoch * len(source_data)
    total_steps = 10 * len(source_data)

    for batch_idx,(sdata, tdata) in enumerate(zip(source_data, target_data)):
        if training_mode == 'dann':
            # setup hyperparameters
            p = float(batch_idx + start_steps) / total_steps
            constant = 2. / (1. + np.exp(-gamma * p)) - 1

            # prepare the data
            input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
            input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
    
            # setup optimizer
            optimizer = optimizer_scheduler(optimizer, p)
            optimizer.zero_grad()

            # compute the output of source domain and target domain
            src_feature = extractor(input1)
            tgt_feature = extractor(input3)

            # compute the class loss of src_feature
            class_pred = class_classifier(src_feature).squeeze(1)
            
            class_loss = criterion(class_pred, label1)
  

            # compute the domain loss of src_feature and target_feature
            tgt_preds = domain_classifier(tgt_feature, constant).squeeze(1)
            src_pred = domain_classifier(src_feature, constant).squeeze(1)
            
            tgt_loss = criterion(tgt_preds, domain3)
            src_loss = criterion(src_pred, domain1)
            
            
            domain_loss = tgt_loss + src_loss

            loss = class_loss + theta * domain_loss

            loss.backward()
            optimizer.step()

            # print loss

            if (batch_idx + 1) % 10 == 0:
                print('[{}/{} ({:.0f}%)]\tLoss: {:.6f}\tClass Loss: {:.6f}\tDomain Loss: {:.6f}'.format(
                    batch_idx * len(input1), len(S_train_data),
                    100. * batch_idx / len(source_data), loss.item(), class_loss.item(),
                    domain_loss.item()
                ))
                
                total_loss.append(loss.item())
                c_loss.append(class_loss.item())
                d_loss.append(domain_loss.item())

# %%
def test(extractor, class_classifier, domain_classifier, source_data, target_data):
 
    # setup the network
    extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()
    source_correct = 0.0
    target_correct = 0.0
    domain_correct = 0.0
    tgt_correct = 0.0
    src_correct = 0.0
    
    for batch_idx, sdata in enumerate(source_data):
        # setup hyperparameters
        p = float(batch_idx) / len(source_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1.

        input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
        
        output1 = class_classifier(extractor(input1)).squeeze(1)
        output1 = torch.round(torch.sigmoid(output1))
        source_correct += (output1 == label1).cpu().sum()

        src_preds = domain_classifier(extractor(input1), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        src_correct += (src_preds == domain1).cpu().sum()

    for batch_idx, tdata in enumerate(target_data):
        # setup hyperparameters
        p = float(batch_idx) / len(target_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1

        input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
        
        output3 = class_classifier(extractor(input3)).squeeze(1)
        output3 = torch.round(torch.sigmoid(output3))
        target_correct += (output3 == label3).cpu().sum()

        src_preds = domain_classifier(extractor(input3), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        tgt_correct += (src_preds == domain3).cpu().sum()


    domain_correct = tgt_correct + src_correct

    print('\nSource Accuracy: {}/{} ({:.4f}%)\nTarget Accuracy: {}/{} ({:.4f}%)\n'
          'Domain Accuracy: {}/{} ({:.4f}%)\n'.
        format(
        source_correct, len(S_test_data), 100. * float(source_correct) / len(S_test_data),
        target_correct, len(T_test_data), 100. * float(target_correct) / len(T_test_data),
        domain_correct, len(S_test_data) + len(T_test_data),
        100. * float(domain_correct) / (len(S_test_data) + len(T_test_data))
    ))
    acc_list1.append(100. * float(source_correct) / len(S_test_data))
    acc_list3.append(100. * float(target_correct) / len(T_test_data))
    acc_list4.append(100. * float(domain_correct) / (len(S_test_data) + len(T_test_data)))

# %%
def main():

    # prepare the source data and target data
    src_train_data = S_train_iterator
    src_test_data = S_test_iterator
    
    tgt_train_data = T_train_iterator
    tgt_test_data = T_test_iterator

    optimizer = optim.SGD([
            {'params': extractor.parameters()},
                            {'params': class_classifier.parameters()},
                            {'params': domain_classifier.parameters()}
    ], lr= 0.01, momentum= 0.9)


    for epoch in range(100):
    
        print('Epoch: {}'.format(epoch))
        train('dann', extractor, class_classifier, domain_classifier, criterion,
                    src_train_data, tgt_train_data, optimizer, epoch)
        test(extractor, class_classifier, domain_classifier, src_test_data, tgt_test_data)
        
total_loss, d_loss, c_loss = [],[],[]
acc_list1, acc_list3, acc_list4 = [],[],[]
if __name__ == '__main__':
    gamma = 10
    theta = 1
    time_start=time.time()
    main()
    time_end=time.time()
    print('total run time: (min)',(time_end-time_start)/60.)
# Out:
# Epoch: 0
# [576/12800 (4%)]	Loss: 2.072013	Class Loss: 0.688349	Domain Loss: 1.383664
# [1216/12800 (10%)]	Loss: 2.176297	Class Loss: 0.709491	Domain Loss: 1.466806
# [1856/12800 (14%)]	Loss: 2.053967	Class Loss: 0.712717	Domain Loss: 1.341250
# [2496/12800 (20%)]	Loss: 1.947467	Class Loss: 0.671366	Domain Loss: 1.276101
# [3136/12800 (24%)]	Loss: 2.004734	Class Loss: 0.682955	Domain Loss: 1.321779
# [3776/12800 (30%)]	Loss: 2.008600	Class Loss: 0.692294	Domain Loss: 1.316306
# [4416/12800 (34%)]	Loss: 2.106199	Class Loss: 0.719451	Domain Loss: 1.386747
# [5056/12800 (40%)]	Loss: 1.880142	Class Loss: 0.638406	Domain Loss: 1.241736
# [5696/12800 (44%)]	Loss: 2.032403	Class Loss: 0.632236	Domain Loss: 1.400167
# [6336/12800 (50%)]	Loss: 1.969460	Class Loss: 0.596962	Domain Loss: 1.372498
#
# Source Accuracy: 2400.0/3200 (75.0000%)
# Target Accuracy: 1059.0/1600 (66.1875%)
# Domain Accuracy: 2263.0/4800 (47.1458%)
#
# Epoch: 1
# [576/12800 (4%)]	Loss: 1.887386	Class Loss: 0.595778	Domain Loss: 1.291608
# [1216/12800 (10%)]	Loss: 2.003803	Class Loss: 0.632557	Domain Loss: 1.371246
# [1856/12800 (14%)]	Loss: 1.996554	Class Loss: 0.623791	Domain Loss: 1.372763
# [2496/12800 (20%)]	Loss: 1.905388	Class Loss: 0.678627	Domain Loss: 1.226761
# [3136/12800 (24%)]	Loss: 2.280736	Class Loss: 0.779601	Domain Loss: 1.501135
# [3776/12800 (30%)]	Loss: 1.912541	Class Loss: 0.592073	Domain Loss: 1.320468
# [4416/12800 (34%)]	Loss: 2.064959	Class Loss: 0.547892	Domain Loss: 1.517067
# [5056/12800 (40%)]	Loss: 1.973959	Class Loss: 0.559822	Domain Loss: 1.414137
# [5696/12800 (44%)]	Loss: 2.079559	Class Loss: 0.608763	Domain Loss: 1.470797
# [6336/12800 (50%)]	Loss: 2.085325	Class Loss: 0.609196	Domain Loss: 1.476129
#
# Source Accuracy: 2484.0/3200 (77.6250%)
# Target Accuracy: 1146.0/1600 (71.6250%)
# Domain Accuracy: 2399.0/4800 (49.9792%)
#
# Epoch: 2
# [576/12800 (4%)]	Loss: 2.113048	Class Loss: 0.688625	Domain Loss: 1.424423
# [1216/12800 (10%)]	Loss: 2.022449	Class Loss: 0.637256	Domain Loss: 1.385192
# [1856/12800 (14%)]	Loss: 1.997713	Class Loss: 0.608894	Domain Loss: 1.388819
# [2496/12800 (20%)]	Loss: 1.957792	Class Loss: 0.611287	Domain Loss: 1.346505
# [3136/12800 (24%)]	Loss: 2.029240	Class Loss: 0.590048	Domain Loss: 1.439192
# [3776/12800 (30%)]	Loss: 1.802500	Class Loss: 0.486753	Domain Loss: 1.315747
# [4416/12800 (34%)]	Loss: 2.073349	Class Loss: 0.797723	Domain Loss: 1.275625
# [5056/12800 (40%)]	Loss: 1.941928	Class Loss: 0.533802	Domain Loss: 1.408126
# [5696/12800 (44%)]	Loss: 1.870436	Class Loss: 0.566107	Domain Loss: 1.304329
# [6336/12800 (50%)]	Loss: 2.106080	Class Loss: 0.579444	Domain Loss: 1.526635
#
# Source Accuracy: 2373.0/3200 (74.1562%)
# Target Accuracy: 1194.0/1600 (74.6250%)
# Domain Accuracy: 3116.0/4800 (64.9167%)
#
# Epoch: 3
# [576/12800 (4%)]	Loss: 1.966976	Class Loss: 0.474301	Domain Loss: 1.492675
# [1216/12800 (10%)]	Loss: 1.848178	Class Loss: 0.541746	Domain Loss: 1.306432
# [1856/12800 (14%)]	Loss: 1.866204	Class Loss: 0.479088	Domain Loss: 1.387116
# [2496/12800 (20%)]	Loss: 2.081137	Class Loss: 0.596859	Domain Loss: 1.484278
# [3136/12800 (24%)]	Loss: 2.035378	Class Loss: 0.597827	Domain Loss: 1.437551
# [3776/12800 (30%)]	Loss: 1.824435	Class Loss: 0.562279	Domain Loss: 1.262156
# [4416/12800 (34%)]	Loss: 2.067118	Class Loss: 0.545363	Domain Loss: 1.521756
# [5056/12800 (40%)]	Loss: 1.850049	Class Loss: 0.466310	Domain Loss: 1.383739
# [5696/12800 (44%)]	Loss: 1.786845	Class Loss: 0.564136	Domain Loss: 1.222708
# [6336/12800 (50%)]	Loss: 1.878467	Class Loss: 0.555152	Domain Loss: 1.323314
#
# Source Accuracy: 2503.0/3200 (78.2188%)
# Target Accuracy: 1233.0/1600 (77.0625%)
# Domain Accuracy: 2433.0/4800 (50.6875%)
#
# Epoch: 4
# [576/12800 (4%)]	Loss: 2.112418	Class Loss: 0.764124	Domain Loss: 1.348294
# [1216/12800 (10%)]	Loss: 1.959572	Class Loss: 0.547582	Domain Loss: 1.411990
# [1856/12800 (14%)]	Loss: 1.838202	Class Loss: 0.450555	Domain Loss: 1.387646
# [2496/12800 (20%)]	Loss: 1.945251	Class Loss: 0.586169	Domain Loss: 1.359081
# [3136/12800 (24%)]	Loss: 1.861596	Class Loss: 0.479561	Domain Loss: 1.382035
# [3776/12800 (30%)]	Loss: 2.015661	Class Loss: 0.618202	Domain Loss: 1.397459
# [4416/12800 (34%)]	Loss: 2.034247	Class Loss: 0.602864	Domain Loss: 1.431383
# [5056/12800 (40%)]	Loss: 1.885486	Class Loss: 0.449003	Domain Loss: 1.436483
# [5696/12800 (44%)]	Loss: 1.812230	Class Loss: 0.509165	Domain Loss: 1.303065
# [6336/12800 (50%)]	Loss: 1.892038	Class Loss: 0.482281	Domain Loss: 1.409758
#
# Source Accuracy: 2588.0/3200 (80.8750%)
# Target Accuracy: 1207.0/1600 (75.4375%)
# Domain Accuracy: 1650.0/4800 (34.3750%)
#
# Epoch: 5
# [576/12800 (4%)]	Loss: 1.933410	Class Loss: 0.542942	Domain Loss: 1.390468
# [1216/12800 (10%)]	Loss: 1.913864	Class Loss: 0.703732	Domain Loss: 1.210132
# [1856/12800 (14%)]	Loss: 2.043110	Class Loss: 0.576226	Domain Loss: 1.466884
# [2496/12800 (20%)]	Loss: 2.018760	Class Loss: 0.607601	Domain Loss: 1.411159
# [3136/12800 (24%)]	Loss: 2.016772	Class Loss: 0.585602	Domain Loss: 1.431170
# [3776/12800 (30%)]	Loss: 1.932681	Class Loss: 0.573867	Domain Loss: 1.358814
# [4416/12800 (34%)]	Loss: 1.989475	Class Loss: 0.537393	Domain Loss: 1.452082
# [5056/12800 (40%)]	Loss: 1.986902	Class Loss: 0.618676	Domain Loss: 1.368225
# [5696/12800 (44%)]	Loss: 1.851488	Class Loss: 0.475784	Domain Loss: 1.375704
# [6336/12800 (50%)]	Loss: 1.870351	Class Loss: 0.592323	Domain Loss: 1.278028
#
# Source Accuracy: 2583.0/3200 (80.7188%)
# Target Accuracy: 1183.0/1600 (73.9375%)
# Domain Accuracy: 2899.0/4800 (60.3958%)
#
# Epoch: 6
# [576/12800 (4%)]	Loss: 2.021942	Class Loss: 0.574332	Domain Loss: 1.447610
# [1216/12800 (10%)]	Loss: 1.931144	Class Loss: 0.565173	Domain Loss: 1.365971
# [1856/12800 (14%)]	Loss: 1.911709	Class Loss: 0.506627	Domain Loss: 1.405082
# [2496/12800 (20%)]	Loss: 1.931869	Class Loss: 0.531421	Domain Loss: 1.400447
# [3136/12800 (24%)]	Loss: 2.275286	Class Loss: 0.852852	Domain Loss: 1.422434
# [3776/12800 (30%)]	Loss: 1.945108	Class Loss: 0.543960	Domain Loss: 1.401148
# [4416/12800 (34%)]	Loss: 1.847300	Class Loss: 0.575172	Domain Loss: 1.272128
# [5056/12800 (40%)]	Loss: 1.859612	Class Loss: 0.427566	Domain Loss: 1.432046
# [5696/12800 (44%)]	Loss: 1.936238	Class Loss: 0.610745	Domain Loss: 1.325493
# [6336/12800 (50%)]	Loss: 1.880574	Class Loss: 0.521101	Domain Loss: 1.359473
#
# Source Accuracy: 2608.0/3200 (81.5000%)
# Target Accuracy: 1195.0/1600 (74.6875%)
# Domain Accuracy: 2754.0/4800 (57.3750%)
#
# Epoch: 7
# [576/12800 (4%)]	Loss: 2.005339	Class Loss: 0.656813	Domain Loss: 1.348526
# [1216/12800 (10%)]	Loss: 1.928203	Class Loss: 0.492660	Domain Loss: 1.435543
# [1856/12800 (14%)]	Loss: 1.950622	Class Loss: 0.505593	Domain Loss: 1.445029
# [2496/12800 (20%)]	Loss: 1.899743	Class Loss: 0.493549	Domain Loss: 1.406193
# [3136/12800 (24%)]	Loss: 1.929952	Class Loss: 0.519871	Domain Loss: 1.410081
# [3776/12800 (30%)]	Loss: 1.925992	Class Loss: 0.525900	Domain Loss: 1.400092
# [4416/12800 (34%)]	Loss: 1.951903	Class Loss: 0.542547	Domain Loss: 1.409356
# [5056/12800 (40%)]	Loss: 1.958279	Class Loss: 0.603631	Domain Loss: 1.354648
# [5696/12800 (44%)]	Loss: 1.916468	Class Loss: 0.487961	Domain Loss: 1.428506
# [6336/12800 (50%)]	Loss: 1.907885	Class Loss: 0.495422	Domain Loss: 1.412463
#
# Source Accuracy: 2580.0/3200 (80.6250%)
# Target Accuracy: 1243.0/1600 (77.6875%)
# Domain Accuracy: 2699.0/4800 (56.2292%)
#
# Epoch: 8
# [576/12800 (4%)]	Loss: 2.048219	Class Loss: 0.642936	Domain Loss: 1.405283
# [1216/12800 (10%)]	Loss: 1.982187	Class Loss: 0.493553	Domain Loss: 1.488634
# [1856/12800 (14%)]	Loss: 1.932389	Class Loss: 0.536126	Domain Loss: 1.396264
# [2496/12800 (20%)]	Loss: 1.902373	Class Loss: 0.539230	Domain Loss: 1.363143
# [3136/12800 (24%)]	Loss: 1.883630	Class Loss: 0.489286	Domain Loss: 1.394344
# [3776/12800 (30%)]	Loss: 1.707940	Class Loss: 0.402020	Domain Loss: 1.305920
# [4416/12800 (34%)]	Loss: 1.847594	Class Loss: 0.506539	Domain Loss: 1.341055
# [5056/12800 (40%)]	Loss: 1.949810	Class Loss: 0.548122	Domain Loss: 1.401687
# [5696/12800 (44%)]	Loss: 1.899712	Class Loss: 0.501537	Domain Loss: 1.398176
# [6336/12800 (50%)]	Loss: 1.905970	Class Loss: 0.509404	Domain Loss: 1.396567
#
# Source Accuracy: 2604.0/3200 (81.3750%)
# Target Accuracy: 1240.0/1600 (77.5000%)
# Domain Accuracy: 2241.0/4800 (46.6875%)
#
# Epoch: 9
# [576/12800 (4%)]	Loss: 1.913668	Class Loss: 0.569102	Domain Loss: 1.344566
# [1216/12800 (10%)]	Loss: 1.793543	Class Loss: 0.451278	Domain Loss: 1.342266
# [1856/12800 (14%)]	Loss: 1.825856	Class Loss: 0.428763	Domain Loss: 1.397094
# [2496/12800 (20%)]	Loss: 1.964864	Class Loss: 0.563446	Domain Loss: 1.401418
# [3136/12800 (24%)]	Loss: 2.008188	Class Loss: 0.554792	Domain Loss: 1.453396
# [3776/12800 (30%)]	Loss: 1.843385	Class Loss: 0.545415	Domain Loss: 1.297970
# [4416/12800 (34%)]	Loss: 1.947976	Class Loss: 0.562264	Domain Loss: 1.385713
# [5056/12800 (40%)]	Loss: 1.868833	Class Loss: 0.509648	Domain Loss: 1.359185
# [5696/12800 (44%)]	Loss: 1.920830	Class Loss: 0.536491	Domain Loss: 1.384338
# [6336/12800 (50%)]	Loss: 1.815831	Class Loss: 0.449303	Domain Loss: 1.366529
#
# Source Accuracy: 2613.0/3200 (81.6562%)
# Target Accuracy: 1244.0/1600 (77.7500%)
# Domain Accuracy: 2320.0/4800 (48.3333%)
#
# Epoch: 10
# [576/12800 (4%)]	Loss: 1.756189	Class Loss: 0.433885	Domain Loss: 1.322305
# [1216/12800 (10%)]	Loss: 1.847598	Class Loss: 0.466174	Domain Loss: 1.381424
# [1856/12800 (14%)]	Loss: 1.853982	Class Loss: 0.474627	Domain Loss: 1.379355
# [2496/12800 (20%)]	Loss: 1.824975	Class Loss: 0.464383	Domain Loss: 1.360592
# [3136/12800 (24%)]	Loss: 1.864323	Class Loss: 0.499460	Domain Loss: 1.364863
# [3776/12800 (30%)]	Loss: 1.931456	Class Loss: 0.511957	Domain Loss: 1.419499
# [4416/12800 (34%)]	Loss: 1.919507	Class Loss: 0.548362	Domain Loss: 1.371145
# [5056/12800 (40%)]	Loss: 2.110458	Class Loss: 0.811433	Domain Loss: 1.299025
# [5696/12800 (44%)]	Loss: 1.957831	Class Loss: 0.564626	Domain Loss: 1.393205
# [6336/12800 (50%)]	Loss: 1.941673	Class Loss: 0.508849	Domain Loss: 1.432824
#
# Source Accuracy: 2570.0/3200 (80.3125%)
# Target Accuracy: 1257.0/1600 (78.5625%)
# Domain Accuracy: 2135.0/4800 (44.4792%)
#
# Epoch: 11
# [576/12800 (4%)]	Loss: 1.831160	Class Loss: 0.449541	Domain Loss: 1.381619
# [1216/12800 (10%)]	Loss: 1.940812	Class Loss: 0.517330	Domain Loss: 1.423482
# [1856/12800 (14%)]	Loss: 1.827021	Class Loss: 0.431763	Domain Loss: 1.395257
# [2496/12800 (20%)]	Loss: 2.052624	Class Loss: 0.645313	Domain Loss: 1.407310
# [3136/12800 (24%)]	Loss: 1.950410	Class Loss: 0.570786	Domain Loss: 1.379624
# [3776/12800 (30%)]	Loss: 1.846465	Class Loss: 0.451246	Domain Loss: 1.395219
# [4416/12800 (34%)]	Loss: 1.812909	Class Loss: 0.472745	Domain Loss: 1.340164
# [5056/12800 (40%)]	Loss: 1.736561	Class Loss: 0.344056	Domain Loss: 1.392505
# [5696/12800 (44%)]	Loss: 1.786287	Class Loss: 0.453704	Domain Loss: 1.332583
# [6336/12800 (50%)]	Loss: 1.927078	Class Loss: 0.525787	Domain Loss: 1.401291
#
# Source Accuracy: 2620.0/3200 (81.8750%)
# Target Accuracy: 1229.0/1600 (76.8125%)
# Domain Accuracy: 1684.0/4800 (35.0833%)
#
# Epoch: 12
# [576/12800 (4%)]	Loss: 1.818197	Class Loss: 0.378386	Domain Loss: 1.439812
# [1216/12800 (10%)]	Loss: 1.970835	Class Loss: 0.573468	Domain Loss: 1.397368
# [1856/12800 (14%)]	Loss: 1.911001	Class Loss: 0.508743	Domain Loss: 1.402258
# [2496/12800 (20%)]	Loss: 1.868526	Class Loss: 0.477473	Domain Loss: 1.391053
# [3136/12800 (24%)]	Loss: 1.768589	Class Loss: 0.419993	Domain Loss: 1.348595
# [3776/12800 (30%)]	Loss: 1.835843	Class Loss: 0.457364	Domain Loss: 1.378479
# [4416/12800 (34%)]	Loss: 1.930295	Class Loss: 0.548156	Domain Loss: 1.382140
# [5056/12800 (40%)]	Loss: 1.997415	Class Loss: 0.565926	Domain Loss: 1.431489
# [5696/12800 (44%)]	Loss: 1.785391	Class Loss: 0.405185	Domain Loss: 1.380205
# [6336/12800 (50%)]	Loss: 1.880278	Class Loss: 0.542406	Domain Loss: 1.337872
#
# Source Accuracy: 2618.0/3200 (81.8125%)
# Target Accuracy: 1242.0/1600 (77.6250%)
# Domain Accuracy: 1637.0/4800 (34.1042%)
#
# Epoch: 13
# [576/12800 (4%)]	Loss: 1.996060	Class Loss: 0.562976	Domain Loss: 1.433084
# [1216/12800 (10%)]	Loss: 1.965501	Class Loss: 0.539370	Domain Loss: 1.426131
# [1856/12800 (14%)]	Loss: 1.813569	Class Loss: 0.404210	Domain Loss: 1.409359
# [2496/12800 (20%)]	Loss: 1.875434	Class Loss: 0.466635	Domain Loss: 1.408798
# [3136/12800 (24%)]	Loss: 1.938127	Class Loss: 0.565637	Domain Loss: 1.372490
# [3776/12800 (30%)]	Loss: 1.870614	Class Loss: 0.449305	Domain Loss: 1.421310
# [4416/12800 (34%)]	Loss: 1.836637	Class Loss: 0.417911	Domain Loss: 1.418727
# [5056/12800 (40%)]	Loss: 1.862491	Class Loss: 0.484705	Domain Loss: 1.377786
# [5696/12800 (44%)]	Loss: 1.947482	Class Loss: 0.522284	Domain Loss: 1.425198
# [6336/12800 (50%)]	Loss: 1.924774	Class Loss: 0.499533	Domain Loss: 1.425241
#
# Source Accuracy: 2588.0/3200 (80.8750%)
# Target Accuracy: 1258.0/1600 (78.6250%)
# Domain Accuracy: 2513.0/4800 (52.3542%)
#
# Epoch: 14
# [576/12800 (4%)]	Loss: 1.954299	Class Loss: 0.574075	Domain Loss: 1.380224
# [1216/12800 (10%)]	Loss: 1.948499	Class Loss: 0.556580	Domain Loss: 1.391919
# [1856/12800 (14%)]	Loss: 1.918346	Class Loss: 0.506959	Domain Loss: 1.411387
# [2496/12800 (20%)]	Loss: 1.882722	Class Loss: 0.492011	Domain Loss: 1.390711
# [3136/12800 (24%)]	Loss: 1.899593	Class Loss: 0.496699	Domain Loss: 1.402894
# [3776/12800 (30%)]	Loss: 1.889985	Class Loss: 0.471187	Domain Loss: 1.418798
# [4416/12800 (34%)]	Loss: 2.013609	Class Loss: 0.642245	Domain Loss: 1.371364
# [5056/12800 (40%)]	Loss: 1.791321	Class Loss: 0.374106	Domain Loss: 1.417215
# [5696/12800 (44%)]	Loss: 1.939830	Class Loss: 0.537689	Domain Loss: 1.402141
# [6336/12800 (50%)]	Loss: 1.864391	Class Loss: 0.476195	Domain Loss: 1.388196
#
# Source Accuracy: 2619.0/3200 (81.8438%)
# Target Accuracy: 1249.0/1600 (78.0625%)
# Domain Accuracy: 2641.0/4800 (55.0208%)
#
# Epoch: 15
# [576/12800 (4%)]	Loss: 1.829999	Class Loss: 0.434025	Domain Loss: 1.395973
# [1216/12800 (10%)]	Loss: 1.965979	Class Loss: 0.597718	Domain Loss: 1.368261
# [1856/12800 (14%)]	Loss: 1.979576	Class Loss: 0.582105	Domain Loss: 1.397471
# [2496/12800 (20%)]	Loss: 1.959179	Class Loss: 0.583456	Domain Loss: 1.375723
# [3136/12800 (24%)]	Loss: 1.834341	Class Loss: 0.430362	Domain Loss: 1.403979
# [3776/12800 (30%)]	Loss: 1.826213	Class Loss: 0.439564	Domain Loss: 1.386649
# [4416/12800 (34%)]	Loss: 1.876716	Class Loss: 0.470814	Domain Loss: 1.405902
# [5056/12800 (40%)]	Loss: 1.805837	Class Loss: 0.396723	Domain Loss: 1.409114
# [5696/12800 (44%)]	Loss: 1.882965	Class Loss: 0.528677	Domain Loss: 1.354288
# [6336/12800 (50%)]	Loss: 1.777280	Class Loss: 0.420699	Domain Loss: 1.356581
#
# Source Accuracy: 2624.0/3200 (82.0000%)
# Target Accuracy: 1245.0/1600 (77.8125%)
# Domain Accuracy: 3025.0/4800 (63.0208%)
#
# Epoch: 16
# [576/12800 (4%)]	Loss: 2.110162	Class Loss: 0.726378	Domain Loss: 1.383783
# [1216/12800 (10%)]	Loss: 1.909937	Class Loss: 0.538524	Domain Loss: 1.371412
# [1856/12800 (14%)]	Loss: 1.833051	Class Loss: 0.466385	Domain Loss: 1.366666
# [2496/12800 (20%)]	Loss: 1.900962	Class Loss: 0.509683	Domain Loss: 1.391279
# [3136/12800 (24%)]	Loss: 1.846111	Class Loss: 0.451625	Domain Loss: 1.394487
# [3776/12800 (30%)]	Loss: 1.847296	Class Loss: 0.481155	Domain Loss: 1.366141
# [4416/12800 (34%)]	Loss: 1.763340	Class Loss: 0.405013	Domain Loss: 1.358326
# [5056/12800 (40%)]	Loss: 1.931450	Class Loss: 0.522700	Domain Loss: 1.408750
# [5696/12800 (44%)]	Loss: 1.781535	Class Loss: 0.409527	Domain Loss: 1.372008
# [6336/12800 (50%)]	Loss: 1.910086	Class Loss: 0.539383	Domain Loss: 1.370703
#
# Source Accuracy: 2628.0/3200 (82.1250%)
# Target Accuracy: 1239.0/1600 (77.4375%)
# Domain Accuracy: 2435.0/4800 (50.7292%)
#
# Epoch: 17
# [576/12800 (4%)]	Loss: 2.023927	Class Loss: 0.647531	Domain Loss: 1.376396
# [1216/12800 (10%)]	Loss: 1.969534	Class Loss: 0.593616	Domain Loss: 1.375918
# [1856/12800 (14%)]	Loss: 1.938612	Class Loss: 0.578040	Domain Loss: 1.360573
# [2496/12800 (20%)]	Loss: 1.771889	Class Loss: 0.409926	Domain Loss: 1.361963
# [3136/12800 (24%)]	Loss: 1.791101	Class Loss: 0.444580	Domain Loss: 1.346521
# [3776/12800 (30%)]	Loss: 1.994076	Class Loss: 0.612941	Domain Loss: 1.381135
# [4416/12800 (34%)]	Loss: 2.009340	Class Loss: 0.592216	Domain Loss: 1.417124
# [5056/12800 (40%)]	Loss: 1.876061	Class Loss: 0.482699	Domain Loss: 1.393363
# [5696/12800 (44%)]	Loss: 1.779601	Class Loss: 0.394611	Domain Loss: 1.384990
# [6336/12800 (50%)]	Loss: 2.059918	Class Loss: 0.702768	Domain Loss: 1.357150
#
# Source Accuracy: 2613.0/3200 (81.6562%)
# Target Accuracy: 1251.0/1600 (78.1875%)
# Domain Accuracy: 2781.0/4800 (57.9375%)
#
# Epoch: 18
# [576/12800 (4%)]	Loss: 1.908314	Class Loss: 0.516360	Domain Loss: 1.391954
# [1216/12800 (10%)]	Loss: 1.851840	Class Loss: 0.468583	Domain Loss: 1.383257
# [1856/12800 (14%)]	Loss: 1.862616	Class Loss: 0.468827	Domain Loss: 1.393789
# [2496/12800 (20%)]	Loss: 1.900146	Class Loss: 0.526743	Domain Loss: 1.373404
# [3136/12800 (24%)]	Loss: 1.855181	Class Loss: 0.476186	Domain Loss: 1.378995
# [3776/12800 (30%)]	Loss: 1.771145	Class Loss: 0.372952	Domain Loss: 1.398193
# [4416/12800 (34%)]	Loss: 1.925176	Class Loss: 0.545108	Domain Loss: 1.380068
# [5056/12800 (40%)]	Loss: 1.848034	Class Loss: 0.472860	Domain Loss: 1.375174
# [5696/12800 (44%)]	Loss: 2.021371	Class Loss: 0.612959	Domain Loss: 1.408412
# [6336/12800 (50%)]	Loss: 1.806387	Class Loss: 0.426800	Domain Loss: 1.379586
#
# Source Accuracy: 2615.0/3200 (81.7188%)
# Target Accuracy: 1252.0/1600 (78.2500%)
# Domain Accuracy: 2729.0/4800 (56.8542%)
#
# Epoch: 19
# [576/12800 (4%)]	Loss: 1.830811	Class Loss: 0.444666	Domain Loss: 1.386146
# [1216/12800 (10%)]	Loss: 1.938033	Class Loss: 0.505488	Domain Loss: 1.432545
# [1856/12800 (14%)]	Loss: 2.031782	Class Loss: 0.590635	Domain Loss: 1.441147
# [2496/12800 (20%)]	Loss: 2.002985	Class Loss: 0.609356	Domain Loss: 1.393629
# [3136/12800 (24%)]	Loss: 1.941475	Class Loss: 0.552636	Domain Loss: 1.388839
# [3776/12800 (30%)]	Loss: 1.891502	Class Loss: 0.506837	Domain Loss: 1.384665
# [4416/12800 (34%)]	Loss: 1.921004	Class Loss: 0.533659	Domain Loss: 1.387345
# [5056/12800 (40%)]	Loss: 1.708541	Class Loss: 0.334241	Domain Loss: 1.374300
# [5696/12800 (44%)]	Loss: 1.863661	Class Loss: 0.450164	Domain Loss: 1.413496
# [6336/12800 (50%)]	Loss: 1.840724	Class Loss: 0.444743	Domain Loss: 1.395982
#
# Source Accuracy: 2606.0/3200 (81.4375%)
# Target Accuracy: 1260.0/1600 (78.7500%)
# Domain Accuracy: 2807.0/4800 (58.4792%)
#
# Epoch: 20
# [576/12800 (4%)]	Loss: 1.885422	Class Loss: 0.517748	Domain Loss: 1.367674
# [1216/12800 (10%)]	Loss: 1.876489	Class Loss: 0.503386	Domain Loss: 1.373103
# [1856/12800 (14%)]	Loss: 1.708046	Class Loss: 0.343664	Domain Loss: 1.364381
# [2496/12800 (20%)]	Loss: 1.908027	Class Loss: 0.510715	Domain Loss: 1.397312
# [3136/12800 (24%)]	Loss: 2.006307	Class Loss: 0.607120	Domain Loss: 1.399186
# [3776/12800 (30%)]	Loss: 1.905750	Class Loss: 0.510852	Domain Loss: 1.394898
# [4416/12800 (34%)]	Loss: 1.764702	Class Loss: 0.371495	Domain Loss: 1.393207
# [5056/12800 (40%)]	Loss: 1.800261	Class Loss: 0.414678	Domain Loss: 1.385583
# [5696/12800 (44%)]	Loss: 1.969584	Class Loss: 0.598433	Domain Loss: 1.371152
# [6336/12800 (50%)]	Loss: 1.815790	Class Loss: 0.429708	Domain Loss: 1.386082
#
# Source Accuracy: 2617.0/3200 (81.7812%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2379.0/4800 (49.5625%)
#
# Epoch: 21
# [576/12800 (4%)]	Loss: 1.801714	Class Loss: 0.414164	Domain Loss: 1.387551
# [1216/12800 (10%)]	Loss: 1.823914	Class Loss: 0.432201	Domain Loss: 1.391713
# [1856/12800 (14%)]	Loss: 2.017912	Class Loss: 0.597627	Domain Loss: 1.420286
# [2496/12800 (20%)]	Loss: 2.067731	Class Loss: 0.673970	Domain Loss: 1.393761
# [3136/12800 (24%)]	Loss: 1.973523	Class Loss: 0.589591	Domain Loss: 1.383932
# [3776/12800 (30%)]	Loss: 1.852144	Class Loss: 0.461266	Domain Loss: 1.390878
# [4416/12800 (34%)]	Loss: 1.867060	Class Loss: 0.473087	Domain Loss: 1.393973
# [5056/12800 (40%)]	Loss: 1.832515	Class Loss: 0.421522	Domain Loss: 1.410993
# [5696/12800 (44%)]	Loss: 1.854274	Class Loss: 0.475041	Domain Loss: 1.379232
# [6336/12800 (50%)]	Loss: 1.791546	Class Loss: 0.412584	Domain Loss: 1.378962
#
# Source Accuracy: 2620.0/3200 (81.8750%)
# Target Accuracy: 1252.0/1600 (78.2500%)
# Domain Accuracy: 2263.0/4800 (47.1458%)
#
# Epoch: 22
# [576/12800 (4%)]	Loss: 1.994703	Class Loss: 0.622890	Domain Loss: 1.371814
# [1216/12800 (10%)]	Loss: 1.762689	Class Loss: 0.392341	Domain Loss: 1.370348
# [1856/12800 (14%)]	Loss: 1.918243	Class Loss: 0.496289	Domain Loss: 1.421954
# [2496/12800 (20%)]	Loss: 1.955177	Class Loss: 0.561210	Domain Loss: 1.393967
# [3136/12800 (24%)]	Loss: 1.905680	Class Loss: 0.491211	Domain Loss: 1.414469
# [3776/12800 (30%)]	Loss: 1.788504	Class Loss: 0.418220	Domain Loss: 1.370284
# [4416/12800 (34%)]	Loss: 1.874153	Class Loss: 0.497983	Domain Loss: 1.376170
# [5056/12800 (40%)]	Loss: 1.920175	Class Loss: 0.517902	Domain Loss: 1.402273
# [5696/12800 (44%)]	Loss: 1.753048	Class Loss: 0.343341	Domain Loss: 1.409707
# [6336/12800 (50%)]	Loss: 1.848506	Class Loss: 0.462252	Domain Loss: 1.386254
#
# Source Accuracy: 2628.0/3200 (82.1250%)
# Target Accuracy: 1251.0/1600 (78.1875%)
# Domain Accuracy: 3098.0/4800 (64.5417%)
#
# Epoch: 23
# [576/12800 (4%)]	Loss: 1.931889	Class Loss: 0.564191	Domain Loss: 1.367698
# [1216/12800 (10%)]	Loss: 1.771576	Class Loss: 0.420460	Domain Loss: 1.351116
# [1856/12800 (14%)]	Loss: 1.869726	Class Loss: 0.462691	Domain Loss: 1.407035
# [2496/12800 (20%)]	Loss: 1.862702	Class Loss: 0.477723	Domain Loss: 1.384979
# [3136/12800 (24%)]	Loss: 1.953002	Class Loss: 0.539844	Domain Loss: 1.413158
# [3776/12800 (30%)]	Loss: 1.903742	Class Loss: 0.504099	Domain Loss: 1.399643
# [4416/12800 (34%)]	Loss: 1.798003	Class Loss: 0.415884	Domain Loss: 1.382120
# [5056/12800 (40%)]	Loss: 1.829823	Class Loss: 0.450242	Domain Loss: 1.379581
# [5696/12800 (44%)]	Loss: 1.848922	Class Loss: 0.474575	Domain Loss: 1.374347
# [6336/12800 (50%)]	Loss: 1.902379	Class Loss: 0.590800	Domain Loss: 1.311579
#
# Source Accuracy: 2626.0/3200 (82.0625%)
# Target Accuracy: 1249.0/1600 (78.0625%)
# Domain Accuracy: 2189.0/4800 (45.6042%)
#
# Epoch: 24
# [576/12800 (4%)]	Loss: 1.915894	Class Loss: 0.554558	Domain Loss: 1.361336
# [1216/12800 (10%)]	Loss: 1.807584	Class Loss: 0.435924	Domain Loss: 1.371660
# [1856/12800 (14%)]	Loss: 1.807871	Class Loss: 0.418350	Domain Loss: 1.389521
# [2496/12800 (20%)]	Loss: 1.912105	Class Loss: 0.522947	Domain Loss: 1.389158
# [3136/12800 (24%)]	Loss: 1.912019	Class Loss: 0.529183	Domain Loss: 1.382837
# [3776/12800 (30%)]	Loss: 1.896567	Class Loss: 0.540150	Domain Loss: 1.356416
# [4416/12800 (34%)]	Loss: 1.920133	Class Loss: 0.519553	Domain Loss: 1.400581
# [5056/12800 (40%)]	Loss: 1.939712	Class Loss: 0.549596	Domain Loss: 1.390116
# [5696/12800 (44%)]	Loss: 1.848024	Class Loss: 0.465324	Domain Loss: 1.382700
# [6336/12800 (50%)]	Loss: 1.895095	Class Loss: 0.512052	Domain Loss: 1.383042
#
# Source Accuracy: 2638.0/3200 (82.4375%)
# Target Accuracy: 1247.0/1600 (77.9375%)
# Domain Accuracy: 2687.0/4800 (55.9792%)
#
# Epoch: 25
# [576/12800 (4%)]	Loss: 2.013458	Class Loss: 0.612420	Domain Loss: 1.401038
# [1216/12800 (10%)]	Loss: 1.899898	Class Loss: 0.498585	Domain Loss: 1.401313
# [1856/12800 (14%)]	Loss: 1.788458	Class Loss: 0.407018	Domain Loss: 1.381440
# [2496/12800 (20%)]	Loss: 1.869678	Class Loss: 0.495077	Domain Loss: 1.374601
# [3136/12800 (24%)]	Loss: 1.859044	Class Loss: 0.468450	Domain Loss: 1.390594
# [3776/12800 (30%)]	Loss: 1.834219	Class Loss: 0.444960	Domain Loss: 1.389259
# [4416/12800 (34%)]	Loss: 1.978460	Class Loss: 0.622040	Domain Loss: 1.356420
# [5056/12800 (40%)]	Loss: 1.898227	Class Loss: 0.520822	Domain Loss: 1.377405
# [5696/12800 (44%)]	Loss: 1.890329	Class Loss: 0.523386	Domain Loss: 1.366944
# [6336/12800 (50%)]	Loss: 1.906615	Class Loss: 0.482931	Domain Loss: 1.423684
#
# Source Accuracy: 2626.0/3200 (82.0625%)
# Target Accuracy: 1250.0/1600 (78.1250%)
# Domain Accuracy: 2349.0/4800 (48.9375%)
#
# Epoch: 26
# [576/12800 (4%)]	Loss: 1.958908	Class Loss: 0.541290	Domain Loss: 1.417617
# [1216/12800 (10%)]	Loss: 1.970692	Class Loss: 0.591824	Domain Loss: 1.378867
# [1856/12800 (14%)]	Loss: 1.947372	Class Loss: 0.518709	Domain Loss: 1.428663
# [2496/12800 (20%)]	Loss: 1.987631	Class Loss: 0.579313	Domain Loss: 1.408319
# [3136/12800 (24%)]	Loss: 1.820808	Class Loss: 0.452056	Domain Loss: 1.368753
# [3776/12800 (30%)]	Loss: 1.806866	Class Loss: 0.432290	Domain Loss: 1.374576
# [4416/12800 (34%)]	Loss: 1.846263	Class Loss: 0.467474	Domain Loss: 1.378790
# [5056/12800 (40%)]	Loss: 1.929437	Class Loss: 0.519203	Domain Loss: 1.410234
# [5696/12800 (44%)]	Loss: 1.863754	Class Loss: 0.473499	Domain Loss: 1.390256
# [6336/12800 (50%)]	Loss: 2.224943	Class Loss: 0.812245	Domain Loss: 1.412698
#
# Source Accuracy: 2641.0/3200 (82.5312%)
# Target Accuracy: 1247.0/1600 (77.9375%)
# Domain Accuracy: 2643.0/4800 (55.0625%)
#
# Epoch: 27
# [576/12800 (4%)]	Loss: 1.835575	Class Loss: 0.474697	Domain Loss: 1.360878
# [1216/12800 (10%)]	Loss: 1.828698	Class Loss: 0.442875	Domain Loss: 1.385823
# [1856/12800 (14%)]	Loss: 1.855134	Class Loss: 0.465477	Domain Loss: 1.389657
# [2496/12800 (20%)]	Loss: 1.770293	Class Loss: 0.374918	Domain Loss: 1.395375
# [3136/12800 (24%)]	Loss: 1.689861	Class Loss: 0.323466	Domain Loss: 1.366395
# [3776/12800 (30%)]	Loss: 1.853518	Class Loss: 0.461916	Domain Loss: 1.391602
# [4416/12800 (34%)]	Loss: 1.843332	Class Loss: 0.468798	Domain Loss: 1.374534
# [5056/12800 (40%)]	Loss: 1.855216	Class Loss: 0.467699	Domain Loss: 1.387516
# [5696/12800 (44%)]	Loss: 1.866088	Class Loss: 0.479097	Domain Loss: 1.386991
# [6336/12800 (50%)]	Loss: 1.780995	Class Loss: 0.384141	Domain Loss: 1.396854
#
# Source Accuracy: 2619.0/3200 (81.8438%)
# Target Accuracy: 1256.0/1600 (78.5000%)
# Domain Accuracy: 2477.0/4800 (51.6042%)
#
# Epoch: 28
# [576/12800 (4%)]	Loss: 1.855428	Class Loss: 0.446513	Domain Loss: 1.408916
# [1216/12800 (10%)]	Loss: 1.874308	Class Loss: 0.491772	Domain Loss: 1.382535
# [1856/12800 (14%)]	Loss: 1.866301	Class Loss: 0.461102	Domain Loss: 1.405199
# [2496/12800 (20%)]	Loss: 1.860933	Class Loss: 0.461094	Domain Loss: 1.399839
# [3136/12800 (24%)]	Loss: 1.855095	Class Loss: 0.467182	Domain Loss: 1.387913
# [3776/12800 (30%)]	Loss: 1.758570	Class Loss: 0.373440	Domain Loss: 1.385130
# [4416/12800 (34%)]	Loss: 2.042591	Class Loss: 0.653746	Domain Loss: 1.388845
# [5056/12800 (40%)]	Loss: 1.854890	Class Loss: 0.483988	Domain Loss: 1.370902
# [5696/12800 (44%)]	Loss: 1.976593	Class Loss: 0.582769	Domain Loss: 1.393824
# [6336/12800 (50%)]	Loss: 1.810771	Class Loss: 0.397618	Domain Loss: 1.413153
#
# Source Accuracy: 2627.0/3200 (82.0938%)
# Target Accuracy: 1247.0/1600 (77.9375%)
# Domain Accuracy: 2162.0/4800 (45.0417%)
#
# Epoch: 29
# [576/12800 (4%)]	Loss: 1.859622	Class Loss: 0.476130	Domain Loss: 1.383492
# [1216/12800 (10%)]	Loss: 1.775661	Class Loss: 0.406028	Domain Loss: 1.369633
# [1856/12800 (14%)]	Loss: 1.918409	Class Loss: 0.533294	Domain Loss: 1.385115
# [2496/12800 (20%)]	Loss: 1.828017	Class Loss: 0.433368	Domain Loss: 1.394649
# [3136/12800 (24%)]	Loss: 1.887188	Class Loss: 0.506848	Domain Loss: 1.380340
# [3776/12800 (30%)]	Loss: 1.799341	Class Loss: 0.390037	Domain Loss: 1.409303
# [4416/12800 (34%)]	Loss: 1.890991	Class Loss: 0.493360	Domain Loss: 1.397631
# [5056/12800 (40%)]	Loss: 1.802641	Class Loss: 0.421281	Domain Loss: 1.381360
# [5696/12800 (44%)]	Loss: 1.905507	Class Loss: 0.507571	Domain Loss: 1.397937
# [6336/12800 (50%)]	Loss: 1.880534	Class Loss: 0.485580	Domain Loss: 1.394954
#
# Source Accuracy: 2643.0/3200 (82.5938%)
# Target Accuracy: 1242.0/1600 (77.6250%)
# Domain Accuracy: 2187.0/4800 (45.5625%)
#
# Epoch: 30
# [576/12800 (4%)]	Loss: 1.882194	Class Loss: 0.490746	Domain Loss: 1.391449
# [1216/12800 (10%)]	Loss: 1.931395	Class Loss: 0.553357	Domain Loss: 1.378038
# [1856/12800 (14%)]	Loss: 1.940021	Class Loss: 0.535934	Domain Loss: 1.404088
# [2496/12800 (20%)]	Loss: 1.843150	Class Loss: 0.455599	Domain Loss: 1.387551
# [3136/12800 (24%)]	Loss: 1.833928	Class Loss: 0.448259	Domain Loss: 1.385669
# [3776/12800 (30%)]	Loss: 1.853636	Class Loss: 0.462338	Domain Loss: 1.391298
# [4416/12800 (34%)]	Loss: 1.864926	Class Loss: 0.507833	Domain Loss: 1.357093
# [5056/12800 (40%)]	Loss: 1.973405	Class Loss: 0.549508	Domain Loss: 1.423897
# [5696/12800 (44%)]	Loss: 1.878394	Class Loss: 0.502987	Domain Loss: 1.375407
# [6336/12800 (50%)]	Loss: 1.906341	Class Loss: 0.527465	Domain Loss: 1.378876
#
# Source Accuracy: 2624.0/3200 (82.0000%)
# Target Accuracy: 1255.0/1600 (78.4375%)
# Domain Accuracy: 2654.0/4800 (55.2917%)
#
# Epoch: 31
# [576/12800 (4%)]	Loss: 1.963799	Class Loss: 0.593339	Domain Loss: 1.370461
# [1216/12800 (10%)]	Loss: 1.792568	Class Loss: 0.424004	Domain Loss: 1.368564
# [1856/12800 (14%)]	Loss: 1.773475	Class Loss: 0.381502	Domain Loss: 1.391972
# [2496/12800 (20%)]	Loss: 1.966008	Class Loss: 0.573867	Domain Loss: 1.392141
# [3136/12800 (24%)]	Loss: 1.834992	Class Loss: 0.466306	Domain Loss: 1.368686
# [3776/12800 (30%)]	Loss: 1.906334	Class Loss: 0.487806	Domain Loss: 1.418528
# [4416/12800 (34%)]	Loss: 1.988354	Class Loss: 0.591479	Domain Loss: 1.396874
# [5056/12800 (40%)]	Loss: 1.839763	Class Loss: 0.457675	Domain Loss: 1.382088
# [5696/12800 (44%)]	Loss: 1.805995	Class Loss: 0.444444	Domain Loss: 1.361552
# [6336/12800 (50%)]	Loss: 1.890814	Class Loss: 0.498931	Domain Loss: 1.391883
#
# Source Accuracy: 2628.0/3200 (82.1250%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2456.0/4800 (51.1667%)
#
# Epoch: 32
# [576/12800 (4%)]	Loss: 1.881598	Class Loss: 0.506030	Domain Loss: 1.375568
# [1216/12800 (10%)]	Loss: 1.915301	Class Loss: 0.537657	Domain Loss: 1.377644
# [1856/12800 (14%)]	Loss: 1.853480	Class Loss: 0.458114	Domain Loss: 1.395366
# [2496/12800 (20%)]	Loss: 1.767655	Class Loss: 0.379449	Domain Loss: 1.388206
# [3136/12800 (24%)]	Loss: 1.815336	Class Loss: 0.432025	Domain Loss: 1.383311
# [3776/12800 (30%)]	Loss: 1.910519	Class Loss: 0.527433	Domain Loss: 1.383086
# [4416/12800 (34%)]	Loss: 1.887488	Class Loss: 0.467496	Domain Loss: 1.419992
# [5056/12800 (40%)]	Loss: 1.866365	Class Loss: 0.470965	Domain Loss: 1.395400
# [5696/12800 (44%)]	Loss: 1.804386	Class Loss: 0.421604	Domain Loss: 1.382783
# [6336/12800 (50%)]	Loss: 1.822755	Class Loss: 0.431118	Domain Loss: 1.391637
#
# Source Accuracy: 2627.0/3200 (82.0938%)
# Target Accuracy: 1255.0/1600 (78.4375%)
# Domain Accuracy: 2684.0/4800 (55.9167%)
#
# Epoch: 33
# [576/12800 (4%)]	Loss: 1.792620	Class Loss: 0.418465	Domain Loss: 1.374155
# [1216/12800 (10%)]	Loss: 1.847029	Class Loss: 0.473779	Domain Loss: 1.373250
# [1856/12800 (14%)]	Loss: 1.842635	Class Loss: 0.468078	Domain Loss: 1.374557
# [2496/12800 (20%)]	Loss: 1.893622	Class Loss: 0.507264	Domain Loss: 1.386358
# [3136/12800 (24%)]	Loss: 1.931071	Class Loss: 0.527778	Domain Loss: 1.403293
# [3776/12800 (30%)]	Loss: 1.763900	Class Loss: 0.406223	Domain Loss: 1.357677
# [4416/12800 (34%)]	Loss: 1.820580	Class Loss: 0.413864	Domain Loss: 1.406716
# [5056/12800 (40%)]	Loss: 1.886625	Class Loss: 0.505379	Domain Loss: 1.381246
# [5696/12800 (44%)]	Loss: 1.938616	Class Loss: 0.549021	Domain Loss: 1.389595
# [6336/12800 (50%)]	Loss: 2.052597	Class Loss: 0.652004	Domain Loss: 1.400593
#
# Source Accuracy: 2639.0/3200 (82.4688%)
# Target Accuracy: 1252.0/1600 (78.2500%)
# Domain Accuracy: 2481.0/4800 (51.6875%)
#
# Epoch: 34
# [576/12800 (4%)]	Loss: 1.703661	Class Loss: 0.315058	Domain Loss: 1.388603
# [1216/12800 (10%)]	Loss: 1.957790	Class Loss: 0.573065	Domain Loss: 1.384725
# [1856/12800 (14%)]	Loss: 1.949266	Class Loss: 0.524819	Domain Loss: 1.424447
# [2496/12800 (20%)]	Loss: 1.883645	Class Loss: 0.500574	Domain Loss: 1.383071
# [3136/12800 (24%)]	Loss: 1.824923	Class Loss: 0.443232	Domain Loss: 1.381691
# [3776/12800 (30%)]	Loss: 1.962714	Class Loss: 0.581598	Domain Loss: 1.381116
# [4416/12800 (34%)]	Loss: 1.863969	Class Loss: 0.478596	Domain Loss: 1.385373
# [5056/12800 (40%)]	Loss: 1.920636	Class Loss: 0.543390	Domain Loss: 1.377246
# [5696/12800 (44%)]	Loss: 1.867165	Class Loss: 0.482060	Domain Loss: 1.385105
# [6336/12800 (50%)]	Loss: 1.943501	Class Loss: 0.561045	Domain Loss: 1.382456
#
# Source Accuracy: 2636.0/3200 (82.3750%)
# Target Accuracy: 1244.0/1600 (77.7500%)
# Domain Accuracy: 2597.0/4800 (54.1042%)
#
# Epoch: 35
# [576/12800 (4%)]	Loss: 1.777880	Class Loss: 0.379742	Domain Loss: 1.398139
# [1216/12800 (10%)]	Loss: 1.890968	Class Loss: 0.519195	Domain Loss: 1.371773
# [1856/12800 (14%)]	Loss: 1.719227	Class Loss: 0.375825	Domain Loss: 1.343401
# [2496/12800 (20%)]	Loss: 1.831358	Class Loss: 0.490200	Domain Loss: 1.341159
# [3136/12800 (24%)]	Loss: 1.826311	Class Loss: 0.468043	Domain Loss: 1.358268
# [3776/12800 (30%)]	Loss: 1.895650	Class Loss: 0.509014	Domain Loss: 1.386636
# [4416/12800 (34%)]	Loss: 1.933968	Class Loss: 0.540848	Domain Loss: 1.393120
# [5056/12800 (40%)]	Loss: 1.805601	Class Loss: 0.419275	Domain Loss: 1.386326
# [5696/12800 (44%)]	Loss: 1.854010	Class Loss: 0.470649	Domain Loss: 1.383361
# [6336/12800 (50%)]	Loss: 1.869424	Class Loss: 0.477851	Domain Loss: 1.391573
#
# Source Accuracy: 2628.0/3200 (82.1250%)
# Target Accuracy: 1260.0/1600 (78.7500%)
# Domain Accuracy: 2690.0/4800 (56.0417%)
#
# Epoch: 36
# [576/12800 (4%)]	Loss: 1.820722	Class Loss: 0.437319	Domain Loss: 1.383403
# [1216/12800 (10%)]	Loss: 1.898270	Class Loss: 0.519206	Domain Loss: 1.379064
# [1856/12800 (14%)]	Loss: 1.764946	Class Loss: 0.379437	Domain Loss: 1.385510
# [2496/12800 (20%)]	Loss: 1.906356	Class Loss: 0.528441	Domain Loss: 1.377915
# [3136/12800 (24%)]	Loss: 1.931627	Class Loss: 0.568148	Domain Loss: 1.363479
# [3776/12800 (30%)]	Loss: 1.757999	Class Loss: 0.365788	Domain Loss: 1.392211
# [4416/12800 (34%)]	Loss: 1.953775	Class Loss: 0.559866	Domain Loss: 1.393909
# [5056/12800 (40%)]	Loss: 1.794328	Class Loss: 0.397373	Domain Loss: 1.396954
# [5696/12800 (44%)]	Loss: 1.952577	Class Loss: 0.558710	Domain Loss: 1.393867
# [6336/12800 (50%)]	Loss: 1.952846	Class Loss: 0.571002	Domain Loss: 1.381844
#
# Source Accuracy: 2630.0/3200 (82.1875%)
# Target Accuracy: 1257.0/1600 (78.5625%)
# Domain Accuracy: 2891.0/4800 (60.2292%)
#
# Epoch: 37
# [576/12800 (4%)]	Loss: 1.767047	Class Loss: 0.390200	Domain Loss: 1.376847
# [1216/12800 (10%)]	Loss: 1.891050	Class Loss: 0.516453	Domain Loss: 1.374597
# [1856/12800 (14%)]	Loss: 1.855175	Class Loss: 0.477356	Domain Loss: 1.377819
# [2496/12800 (20%)]	Loss: 1.772442	Class Loss: 0.366577	Domain Loss: 1.405865
# [3136/12800 (24%)]	Loss: 1.996931	Class Loss: 0.615224	Domain Loss: 1.381707
# [3776/12800 (30%)]	Loss: 1.789790	Class Loss: 0.394856	Domain Loss: 1.394935
# [4416/12800 (34%)]	Loss: 1.948628	Class Loss: 0.554564	Domain Loss: 1.394064
# [5056/12800 (40%)]	Loss: 1.972631	Class Loss: 0.572810	Domain Loss: 1.399821
# [5696/12800 (44%)]	Loss: 1.905861	Class Loss: 0.507767	Domain Loss: 1.398094
# [6336/12800 (50%)]	Loss: 1.938725	Class Loss: 0.541885	Domain Loss: 1.396840
#
# Source Accuracy: 2650.0/3200 (82.8125%)
# Target Accuracy: 1247.0/1600 (77.9375%)
# Domain Accuracy: 2803.0/4800 (58.3958%)
#
# Epoch: 38
# [576/12800 (4%)]	Loss: 1.806908	Class Loss: 0.433518	Domain Loss: 1.373390
# [1216/12800 (10%)]	Loss: 1.879792	Class Loss: 0.500961	Domain Loss: 1.378830
# [1856/12800 (14%)]	Loss: 1.834648	Class Loss: 0.423399	Domain Loss: 1.411249
# [2496/12800 (20%)]	Loss: 1.845945	Class Loss: 0.486127	Domain Loss: 1.359818
# [3136/12800 (24%)]	Loss: 1.868750	Class Loss: 0.502141	Domain Loss: 1.366609
# [3776/12800 (30%)]	Loss: 1.869963	Class Loss: 0.470283	Domain Loss: 1.399680
# [4416/12800 (34%)]	Loss: 1.828218	Class Loss: 0.423149	Domain Loss: 1.405069
# [5056/12800 (40%)]	Loss: 1.849094	Class Loss: 0.451769	Domain Loss: 1.397324
# [5696/12800 (44%)]	Loss: 1.810873	Class Loss: 0.456357	Domain Loss: 1.354516
# [6336/12800 (50%)]	Loss: 1.874751	Class Loss: 0.475805	Domain Loss: 1.398946
#
# Source Accuracy: 2637.0/3200 (82.4062%)
# Target Accuracy: 1250.0/1600 (78.1250%)
# Domain Accuracy: 2576.0/4800 (53.6667%)
#
# Epoch: 39
# [576/12800 (4%)]	Loss: 1.851256	Class Loss: 0.459208	Domain Loss: 1.392048
# [1216/12800 (10%)]	Loss: 1.838893	Class Loss: 0.457955	Domain Loss: 1.380938
# [1856/12800 (14%)]	Loss: 1.825933	Class Loss: 0.446589	Domain Loss: 1.379345
# [2496/12800 (20%)]	Loss: 1.920367	Class Loss: 0.524529	Domain Loss: 1.395837
# [3136/12800 (24%)]	Loss: 1.739564	Class Loss: 0.377616	Domain Loss: 1.361948
# [3776/12800 (30%)]	Loss: 1.910920	Class Loss: 0.518881	Domain Loss: 1.392040
# [4416/12800 (34%)]	Loss: 1.810541	Class Loss: 0.417892	Domain Loss: 1.392650
# [5056/12800 (40%)]	Loss: 1.822840	Class Loss: 0.431571	Domain Loss: 1.391269
# [5696/12800 (44%)]	Loss: 1.816377	Class Loss: 0.431379	Domain Loss: 1.384998
# [6336/12800 (50%)]	Loss: 1.891868	Class Loss: 0.487063	Domain Loss: 1.404806
#
# Source Accuracy: 2642.0/3200 (82.5625%)
# Target Accuracy: 1249.0/1600 (78.0625%)
# Domain Accuracy: 2557.0/4800 (53.2708%)
#
# Epoch: 40
# [576/12800 (4%)]	Loss: 1.930445	Class Loss: 0.554353	Domain Loss: 1.376092
# [1216/12800 (10%)]	Loss: 1.904424	Class Loss: 0.528470	Domain Loss: 1.375954
# [1856/12800 (14%)]	Loss: 1.833955	Class Loss: 0.439075	Domain Loss: 1.394880
# [2496/12800 (20%)]	Loss: 1.970972	Class Loss: 0.619476	Domain Loss: 1.351496
# [3136/12800 (24%)]	Loss: 1.969954	Class Loss: 0.583214	Domain Loss: 1.386740
# [3776/12800 (30%)]	Loss: 1.884763	Class Loss: 0.489502	Domain Loss: 1.395262
# [4416/12800 (34%)]	Loss: 1.840750	Class Loss: 0.456414	Domain Loss: 1.384336
# [5056/12800 (40%)]	Loss: 1.889209	Class Loss: 0.505693	Domain Loss: 1.383516
# [5696/12800 (44%)]	Loss: 1.949137	Class Loss: 0.568915	Domain Loss: 1.380222
# [6336/12800 (50%)]	Loss: 1.824556	Class Loss: 0.433019	Domain Loss: 1.391537
#
# Source Accuracy: 2633.0/3200 (82.2812%)
# Target Accuracy: 1251.0/1600 (78.1875%)
# Domain Accuracy: 2529.0/4800 (52.6875%)
#
# Epoch: 41
# [576/12800 (4%)]	Loss: 1.805340	Class Loss: 0.413398	Domain Loss: 1.391942
# [1216/12800 (10%)]	Loss: 1.972481	Class Loss: 0.597000	Domain Loss: 1.375480
# [1856/12800 (14%)]	Loss: 1.833025	Class Loss: 0.441400	Domain Loss: 1.391626
# [2496/12800 (20%)]	Loss: 1.923453	Class Loss: 0.524197	Domain Loss: 1.399256
# [3136/12800 (24%)]	Loss: 1.952302	Class Loss: 0.585459	Domain Loss: 1.366844
# [3776/12800 (30%)]	Loss: 1.923712	Class Loss: 0.503447	Domain Loss: 1.420265
# [4416/12800 (34%)]	Loss: 1.824479	Class Loss: 0.415822	Domain Loss: 1.408657
# [5056/12800 (40%)]	Loss: 1.863047	Class Loss: 0.485492	Domain Loss: 1.377555
# [5696/12800 (44%)]	Loss: 1.870146	Class Loss: 0.493025	Domain Loss: 1.377121
# [6336/12800 (50%)]	Loss: 1.937162	Class Loss: 0.543477	Domain Loss: 1.393685
#
# Source Accuracy: 2646.0/3200 (82.6875%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2680.0/4800 (55.8333%)
#
# Epoch: 42
# [576/12800 (4%)]	Loss: 1.846595	Class Loss: 0.474698	Domain Loss: 1.371898
# [1216/12800 (10%)]	Loss: 1.910995	Class Loss: 0.510210	Domain Loss: 1.400786
# [1856/12800 (14%)]	Loss: 1.835722	Class Loss: 0.427355	Domain Loss: 1.408367
# [2496/12800 (20%)]	Loss: 1.871970	Class Loss: 0.453969	Domain Loss: 1.418001
# [3136/12800 (24%)]	Loss: 1.819840	Class Loss: 0.411284	Domain Loss: 1.408556
# [3776/12800 (30%)]	Loss: 1.851047	Class Loss: 0.442830	Domain Loss: 1.408217
# [4416/12800 (34%)]	Loss: 1.929236	Class Loss: 0.541789	Domain Loss: 1.387447
# [5056/12800 (40%)]	Loss: 1.858608	Class Loss: 0.474963	Domain Loss: 1.383645
# [5696/12800 (44%)]	Loss: 1.934955	Class Loss: 0.519682	Domain Loss: 1.415272
# [6336/12800 (50%)]	Loss: 1.759167	Class Loss: 0.374986	Domain Loss: 1.384181
#
# Source Accuracy: 2635.0/3200 (82.3438%)
# Target Accuracy: 1251.0/1600 (78.1875%)
# Domain Accuracy: 2606.0/4800 (54.2917%)
#
# Epoch: 43
# [576/12800 (4%)]	Loss: 1.830124	Class Loss: 0.446112	Domain Loss: 1.384012
# [1216/12800 (10%)]	Loss: 1.911668	Class Loss: 0.534311	Domain Loss: 1.377357
# [1856/12800 (14%)]	Loss: 2.097988	Class Loss: 0.664001	Domain Loss: 1.433987
# [2496/12800 (20%)]	Loss: 1.827661	Class Loss: 0.423348	Domain Loss: 1.404313
# [3136/12800 (24%)]	Loss: 1.930114	Class Loss: 0.535876	Domain Loss: 1.394238
# [3776/12800 (30%)]	Loss: 1.943919	Class Loss: 0.557468	Domain Loss: 1.386451
# [4416/12800 (34%)]	Loss: 1.929563	Class Loss: 0.560181	Domain Loss: 1.369382
# [5056/12800 (40%)]	Loss: 1.783849	Class Loss: 0.402449	Domain Loss: 1.381401
# [5696/12800 (44%)]	Loss: 1.915854	Class Loss: 0.548095	Domain Loss: 1.367759
# [6336/12800 (50%)]	Loss: 1.739672	Class Loss: 0.374009	Domain Loss: 1.365663
#
# Source Accuracy: 2636.0/3200 (82.3750%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2381.0/4800 (49.6042%)
#
# Epoch: 44
# [576/12800 (4%)]	Loss: 1.825966	Class Loss: 0.437975	Domain Loss: 1.387991
# [1216/12800 (10%)]	Loss: 1.907637	Class Loss: 0.515479	Domain Loss: 1.392159
# [1856/12800 (14%)]	Loss: 1.800522	Class Loss: 0.419666	Domain Loss: 1.380856
# [2496/12800 (20%)]	Loss: 1.906790	Class Loss: 0.508310	Domain Loss: 1.398480
# [3136/12800 (24%)]	Loss: 1.785244	Class Loss: 0.406770	Domain Loss: 1.378474
# [3776/12800 (30%)]	Loss: 1.777975	Class Loss: 0.408587	Domain Loss: 1.369389
# [4416/12800 (34%)]	Loss: 2.002874	Class Loss: 0.580260	Domain Loss: 1.422614
# [5056/12800 (40%)]	Loss: 1.773873	Class Loss: 0.382368	Domain Loss: 1.391505
# [5696/12800 (44%)]	Loss: 1.790297	Class Loss: 0.412246	Domain Loss: 1.378051
# [6336/12800 (50%)]	Loss: 1.969194	Class Loss: 0.581996	Domain Loss: 1.387198
#
# Source Accuracy: 2638.0/3200 (82.4375%)
# Target Accuracy: 1245.0/1600 (77.8125%)
# Domain Accuracy: 2688.0/4800 (56.0000%)
#
# Epoch: 45
# [576/12800 (4%)]	Loss: 1.790722	Class Loss: 0.404541	Domain Loss: 1.386181
# [1216/12800 (10%)]	Loss: 1.875422	Class Loss: 0.500910	Domain Loss: 1.374512
# [1856/12800 (14%)]	Loss: 1.984547	Class Loss: 0.598013	Domain Loss: 1.386534
# [2496/12800 (20%)]	Loss: 1.850840	Class Loss: 0.460552	Domain Loss: 1.390288
# [3136/12800 (24%)]	Loss: 1.923278	Class Loss: 0.522279	Domain Loss: 1.400999
# [3776/12800 (30%)]	Loss: 1.779382	Class Loss: 0.408165	Domain Loss: 1.371217
# [4416/12800 (34%)]	Loss: 1.797717	Class Loss: 0.412746	Domain Loss: 1.384970
# [5056/12800 (40%)]	Loss: 1.829483	Class Loss: 0.446598	Domain Loss: 1.382885
# [5696/12800 (44%)]	Loss: 1.882180	Class Loss: 0.511715	Domain Loss: 1.370465
# [6336/12800 (50%)]	Loss: 2.012733	Class Loss: 0.627170	Domain Loss: 1.385563
#
# Source Accuracy: 2653.0/3200 (82.9062%)
# Target Accuracy: 1242.0/1600 (77.6250%)
# Domain Accuracy: 2511.0/4800 (52.3125%)
#
# Epoch: 46
# [576/12800 (4%)]	Loss: 1.750249	Class Loss: 0.338399	Domain Loss: 1.411850
# [1216/12800 (10%)]	Loss: 1.826003	Class Loss: 0.441919	Domain Loss: 1.384084
# [1856/12800 (14%)]	Loss: 1.790596	Class Loss: 0.415227	Domain Loss: 1.375369
# [2496/12800 (20%)]	Loss: 1.827728	Class Loss: 0.438352	Domain Loss: 1.389377
# [3136/12800 (24%)]	Loss: 1.840810	Class Loss: 0.446383	Domain Loss: 1.394427
# [3776/12800 (30%)]	Loss: 1.823529	Class Loss: 0.445976	Domain Loss: 1.377553
# [4416/12800 (34%)]	Loss: 1.963663	Class Loss: 0.574213	Domain Loss: 1.389450
# [5056/12800 (40%)]	Loss: 1.906669	Class Loss: 0.534935	Domain Loss: 1.371733
# [5696/12800 (44%)]	Loss: 1.806028	Class Loss: 0.407757	Domain Loss: 1.398270
# [6336/12800 (50%)]	Loss: 1.851961	Class Loss: 0.470131	Domain Loss: 1.381830
#
# Source Accuracy: 2640.0/3200 (82.5000%)
# Target Accuracy: 1246.0/1600 (77.8750%)
# Domain Accuracy: 2597.0/4800 (54.1042%)
#
# Epoch: 47
# [576/12800 (4%)]	Loss: 1.924894	Class Loss: 0.540759	Domain Loss: 1.384135
# [1216/12800 (10%)]	Loss: 1.911596	Class Loss: 0.523116	Domain Loss: 1.388480
# [1856/12800 (14%)]	Loss: 2.015025	Class Loss: 0.631135	Domain Loss: 1.383891
# [2496/12800 (20%)]	Loss: 1.843957	Class Loss: 0.459174	Domain Loss: 1.384783
# [3136/12800 (24%)]	Loss: 1.842872	Class Loss: 0.472752	Domain Loss: 1.370120
# [3776/12800 (30%)]	Loss: 1.776587	Class Loss: 0.390940	Domain Loss: 1.385647
# [4416/12800 (34%)]	Loss: 1.747743	Class Loss: 0.372464	Domain Loss: 1.375278
# [5056/12800 (40%)]	Loss: 1.846637	Class Loss: 0.450878	Domain Loss: 1.395759
# [5696/12800 (44%)]	Loss: 1.943526	Class Loss: 0.556964	Domain Loss: 1.386561
# [6336/12800 (50%)]	Loss: 1.915912	Class Loss: 0.508375	Domain Loss: 1.407537
#
# Source Accuracy: 2641.0/3200 (82.5312%)
# Target Accuracy: 1245.0/1600 (77.8125%)
# Domain Accuracy: 2389.0/4800 (49.7708%)
#
# Epoch: 48
# [576/12800 (4%)]	Loss: 1.812576	Class Loss: 0.417375	Domain Loss: 1.395201
# [1216/12800 (10%)]	Loss: 1.970604	Class Loss: 0.559423	Domain Loss: 1.411180
# [1856/12800 (14%)]	Loss: 1.806050	Class Loss: 0.396392	Domain Loss: 1.409657
# [2496/12800 (20%)]	Loss: 1.747331	Class Loss: 0.357165	Domain Loss: 1.390166
# [3136/12800 (24%)]	Loss: 1.810165	Class Loss: 0.427775	Domain Loss: 1.382390
# [3776/12800 (30%)]	Loss: 1.856292	Class Loss: 0.458273	Domain Loss: 1.398020
# [4416/12800 (34%)]	Loss: 1.778255	Class Loss: 0.409115	Domain Loss: 1.369141
# [5056/12800 (40%)]	Loss: 1.852417	Class Loss: 0.469166	Domain Loss: 1.383251
# [5696/12800 (44%)]	Loss: 1.703984	Class Loss: 0.329426	Domain Loss: 1.374558
# [6336/12800 (50%)]	Loss: 2.115869	Class Loss: 0.697405	Domain Loss: 1.418463
#
# Source Accuracy: 2645.0/3200 (82.6562%)
# Target Accuracy: 1247.0/1600 (77.9375%)
# Domain Accuracy: 2654.0/4800 (55.2917%)
#
# Epoch: 49
# [576/12800 (4%)]	Loss: 1.865892	Class Loss: 0.494926	Domain Loss: 1.370966
# [1216/12800 (10%)]	Loss: 1.947812	Class Loss: 0.565326	Domain Loss: 1.382486
# [1856/12800 (14%)]	Loss: 1.853486	Class Loss: 0.468231	Domain Loss: 1.385255
# [2496/12800 (20%)]	Loss: 1.879456	Class Loss: 0.472869	Domain Loss: 1.406587
# [3136/12800 (24%)]	Loss: 1.892987	Class Loss: 0.506902	Domain Loss: 1.386084
# [3776/12800 (30%)]	Loss: 1.764249	Class Loss: 0.378513	Domain Loss: 1.385736
# [4416/12800 (34%)]	Loss: 1.838173	Class Loss: 0.435718	Domain Loss: 1.402454
# [5056/12800 (40%)]	Loss: 1.769385	Class Loss: 0.382719	Domain Loss: 1.386666
# [5696/12800 (44%)]	Loss: 1.875800	Class Loss: 0.479059	Domain Loss: 1.396741
# [6336/12800 (50%)]	Loss: 1.796011	Class Loss: 0.412661	Domain Loss: 1.383351
#
# Source Accuracy: 2654.0/3200 (82.9375%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2594.0/4800 (54.0417%)
#
# Epoch: 50
# [576/12800 (4%)]	Loss: 1.847530	Class Loss: 0.441762	Domain Loss: 1.405768
# [1216/12800 (10%)]	Loss: 1.869092	Class Loss: 0.478007	Domain Loss: 1.391085
# [1856/12800 (14%)]	Loss: 1.897009	Class Loss: 0.490913	Domain Loss: 1.406096
# [2496/12800 (20%)]	Loss: 1.798061	Class Loss: 0.419415	Domain Loss: 1.378647
# [3136/12800 (24%)]	Loss: 1.814230	Class Loss: 0.423986	Domain Loss: 1.390244
# [3776/12800 (30%)]	Loss: 1.836156	Class Loss: 0.450375	Domain Loss: 1.385781
# [4416/12800 (34%)]	Loss: 1.831455	Class Loss: 0.440603	Domain Loss: 1.390852
# [5056/12800 (40%)]	Loss: 1.780957	Class Loss: 0.411115	Domain Loss: 1.369843
# [5696/12800 (44%)]	Loss: 1.915091	Class Loss: 0.550081	Domain Loss: 1.365010
# [6336/12800 (50%)]	Loss: 1.820255	Class Loss: 0.452416	Domain Loss: 1.367839
#
# Source Accuracy: 2642.0/3200 (82.5625%)
# Target Accuracy: 1246.0/1600 (77.8750%)
# Domain Accuracy: 2747.0/4800 (57.2292%)
#
# Epoch: 51
# [576/12800 (4%)]	Loss: 1.831142	Class Loss: 0.443744	Domain Loss: 1.387397
# [1216/12800 (10%)]	Loss: 1.839074	Class Loss: 0.457340	Domain Loss: 1.381733
# [1856/12800 (14%)]	Loss: 1.929487	Class Loss: 0.490373	Domain Loss: 1.439115
# [2496/12800 (20%)]	Loss: 1.779946	Class Loss: 0.389048	Domain Loss: 1.390898
# [3136/12800 (24%)]	Loss: 1.850151	Class Loss: 0.459813	Domain Loss: 1.390338
# [3776/12800 (30%)]	Loss: 1.796964	Class Loss: 0.410233	Domain Loss: 1.386731
# [4416/12800 (34%)]	Loss: 1.839005	Class Loss: 0.444735	Domain Loss: 1.394269
# [5056/12800 (40%)]	Loss: 1.811668	Class Loss: 0.414465	Domain Loss: 1.397203
# [5696/12800 (44%)]	Loss: 1.770357	Class Loss: 0.390026	Domain Loss: 1.380331
# [6336/12800 (50%)]	Loss: 1.814741	Class Loss: 0.417604	Domain Loss: 1.397137
#
# Source Accuracy: 2644.0/3200 (82.6250%)
# Target Accuracy: 1251.0/1600 (78.1875%)
# Domain Accuracy: 2690.0/4800 (56.0417%)
#
# Epoch: 52
# [576/12800 (4%)]	Loss: 1.934100	Class Loss: 0.545735	Domain Loss: 1.388365
# [1216/12800 (10%)]	Loss: 1.825000	Class Loss: 0.435845	Domain Loss: 1.389155
# [1856/12800 (14%)]	Loss: 1.712026	Class Loss: 0.341799	Domain Loss: 1.370227
# [2496/12800 (20%)]	Loss: 1.795696	Class Loss: 0.430210	Domain Loss: 1.365486
# [3136/12800 (24%)]	Loss: 1.971446	Class Loss: 0.590028	Domain Loss: 1.381418
# [3776/12800 (30%)]	Loss: 1.929247	Class Loss: 0.546196	Domain Loss: 1.383051
# [4416/12800 (34%)]	Loss: 2.059275	Class Loss: 0.666886	Domain Loss: 1.392389
# [5056/12800 (40%)]	Loss: 1.746879	Class Loss: 0.357755	Domain Loss: 1.389124
# [5696/12800 (44%)]	Loss: 1.924602	Class Loss: 0.532849	Domain Loss: 1.391752
# [6336/12800 (50%)]	Loss: 1.925404	Class Loss: 0.503754	Domain Loss: 1.421650
#
# Source Accuracy: 2654.0/3200 (82.9375%)
# Target Accuracy: 1240.0/1600 (77.5000%)
# Domain Accuracy: 1950.0/4800 (40.6250%)
#
# Epoch: 53
# [576/12800 (4%)]	Loss: 1.886697	Class Loss: 0.459113	Domain Loss: 1.427584
# [1216/12800 (10%)]	Loss: 1.881490	Class Loss: 0.478165	Domain Loss: 1.403325
# [1856/12800 (14%)]	Loss: 1.818261	Class Loss: 0.412912	Domain Loss: 1.405350
# ...
# [3136/12800 (24%)]	Loss: 1.850581	Class Loss: 0.461879	Domain Loss: 1.388703
# [3776/12800 (30%)]	Loss: 1.739587	Class Loss: 0.360432	Domain Loss: 1.379155
# [4416/12800 (34%)]	Loss: 1.910612	Class Loss: 0.529907	Domain Loss: 1.380705
# [5056/12800 (40%)]	Loss: 1.889763	Class Loss: 0.509504	Domain Loss: 1.380258
# [5696/12800 (44%)]	Loss: 1.808746	Class Loss: 0.436983	Domain Loss: 1.371763
# [6336/12800 (50%)]	Loss: 1.906492	Class Loss: 0.515236	Domain Loss: 1.391257
#
# Source Accuracy: 2659.0/3200 (83.0938%)
# Target Accuracy: 1246.0/1600 (77.8750%)
# Domain Accuracy: 2915.0/4800 (60.7292%)
#
# Epoch: 83
# [576/12800 (4%)]	Loss: 1.680958	Class Loss: 0.300170	Domain Loss: 1.380789
# [1216/12800 (10%)]	Loss: 1.838694	Class Loss: 0.447375	Domain Loss: 1.391320
# [1856/12800 (14%)]	Loss: 1.786018	Class Loss: 0.408984	Domain Loss: 1.377034
# [2496/12800 (20%)]	Loss: 1.917691	Class Loss: 0.529634	Domain Loss: 1.388057
# [3136/12800 (24%)]	Loss: 1.824466	Class Loss: 0.414644	Domain Loss: 1.409822
# [3776/12800 (30%)]	Loss: 1.805240	Class Loss: 0.420873	Domain Loss: 1.384367
# [4416/12800 (34%)]	Loss: 1.880032	Class Loss: 0.493637	Domain Loss: 1.386395
# [5056/12800 (40%)]	Loss: 1.847089	Class Loss: 0.464909	Domain Loss: 1.382180
# [5696/12800 (44%)]	Loss: 1.744074	Class Loss: 0.360786	Domain Loss: 1.383288
# [6336/12800 (50%)]	Loss: 1.901339	Class Loss: 0.523266	Domain Loss: 1.378073
#
# Source Accuracy: 2659.0/3200 (83.0938%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2873.0/4800 (59.8542%)
#
# Epoch: 84
# [576/12800 (4%)]	Loss: 1.667612	Class Loss: 0.294863	Domain Loss: 1.372749
# [1216/12800 (10%)]	Loss: 2.052183	Class Loss: 0.673449	Domain Loss: 1.378734
# [1856/12800 (14%)]	Loss: 1.798764	Class Loss: 0.425996	Domain Loss: 1.372768
# [2496/12800 (20%)]	Loss: 1.900280	Class Loss: 0.495477	Domain Loss: 1.404803
# [3136/12800 (24%)]	Loss: 1.874665	Class Loss: 0.490235	Domain Loss: 1.384429
# [3776/12800 (30%)]	Loss: 1.713001	Class Loss: 0.332416	Domain Loss: 1.380585
# [4416/12800 (34%)]	Loss: 1.791728	Class Loss: 0.414111	Domain Loss: 1.377617
# [5056/12800 (40%)]	Loss: 1.820447	Class Loss: 0.444049	Domain Loss: 1.376398
# [5696/12800 (44%)]	Loss: 1.954526	Class Loss: 0.566398	Domain Loss: 1.388129
# [6336/12800 (50%)]	Loss: 1.837339	Class Loss: 0.446654	Domain Loss: 1.390685
#
# Source Accuracy: 2662.0/3200 (83.1875%)
# Target Accuracy: 1244.0/1600 (77.7500%)
# Domain Accuracy: 2471.0/4800 (51.4792%)
#
# Epoch: 85
# [576/12800 (4%)]	Loss: 1.802394	Class Loss: 0.431132	Domain Loss: 1.371262
# [1216/12800 (10%)]	Loss: 1.837732	Class Loss: 0.471746	Domain Loss: 1.365986
# [1856/12800 (14%)]	Loss: 1.828355	Class Loss: 0.442878	Domain Loss: 1.385477
# [2496/12800 (20%)]	Loss: 1.896770	Class Loss: 0.515462	Domain Loss: 1.381309
# [3136/12800 (24%)]	Loss: 1.765777	Class Loss: 0.392938	Domain Loss: 1.372839
# [3776/12800 (30%)]	Loss: 1.782899	Class Loss: 0.394541	Domain Loss: 1.388358
# [4416/12800 (34%)]	Loss: 1.838333	Class Loss: 0.452702	Domain Loss: 1.385631
# [5056/12800 (40%)]	Loss: 1.863024	Class Loss: 0.473508	Domain Loss: 1.389516
# [5696/12800 (44%)]	Loss: 1.834899	Class Loss: 0.455341	Domain Loss: 1.379558
# [6336/12800 (50%)]	Loss: 1.773056	Class Loss: 0.389590	Domain Loss: 1.383466
#
# Source Accuracy: 2673.0/3200 (83.5312%)
# Target Accuracy: 1236.0/1600 (77.2500%)
# Domain Accuracy: 2457.0/4800 (51.1875%)
#
# Epoch: 86
# [576/12800 (4%)]	Loss: 1.853527	Class Loss: 0.473099	Domain Loss: 1.380428
# [1216/12800 (10%)]	Loss: 1.928379	Class Loss: 0.538235	Domain Loss: 1.390144
# [1856/12800 (14%)]	Loss: 1.938508	Class Loss: 0.543692	Domain Loss: 1.394815
# [2496/12800 (20%)]	Loss: 1.792323	Class Loss: 0.402617	Domain Loss: 1.389706
# [3136/12800 (24%)]	Loss: 1.794764	Class Loss: 0.422516	Domain Loss: 1.372248
# [3776/12800 (30%)]	Loss: 1.762371	Class Loss: 0.374850	Domain Loss: 1.387521
# [4416/12800 (34%)]	Loss: 1.733150	Class Loss: 0.357398	Domain Loss: 1.375753
# [5056/12800 (40%)]	Loss: 1.768475	Class Loss: 0.384536	Domain Loss: 1.383939
# [5696/12800 (44%)]	Loss: 1.787086	Class Loss: 0.401583	Domain Loss: 1.385502
# [6336/12800 (50%)]	Loss: 1.864722	Class Loss: 0.477023	Domain Loss: 1.387699
#
# Source Accuracy: 2670.0/3200 (83.4375%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2850.0/4800 (59.3750%)
#
# Epoch: 87
# [576/12800 (4%)]	Loss: 1.760174	Class Loss: 0.354374	Domain Loss: 1.405799
# [1216/12800 (10%)]	Loss: 1.808228	Class Loss: 0.435446	Domain Loss: 1.372782
# [1856/12800 (14%)]	Loss: 1.813230	Class Loss: 0.420233	Domain Loss: 1.392997
# [2496/12800 (20%)]	Loss: 1.744733	Class Loss: 0.362712	Domain Loss: 1.382021
# [3136/12800 (24%)]	Loss: 1.834130	Class Loss: 0.439493	Domain Loss: 1.394637
# [3776/12800 (30%)]	Loss: 1.935847	Class Loss: 0.552674	Domain Loss: 1.383173
# [4416/12800 (34%)]	Loss: 1.781194	Class Loss: 0.393857	Domain Loss: 1.387336
# [5056/12800 (40%)]	Loss: 1.774944	Class Loss: 0.382530	Domain Loss: 1.392414
# [5696/12800 (44%)]	Loss: 1.873749	Class Loss: 0.462329	Domain Loss: 1.411420
# [6336/12800 (50%)]	Loss: 1.810380	Class Loss: 0.421663	Domain Loss: 1.388717
#
# Source Accuracy: 2659.0/3200 (83.0938%)
# Target Accuracy: 1243.0/1600 (77.6875%)
# Domain Accuracy: 2481.0/4800 (51.6875%)
#
# Epoch: 88
# [576/12800 (4%)]	Loss: 1.872921	Class Loss: 0.489696	Domain Loss: 1.383225
# [1216/12800 (10%)]	Loss: 1.895252	Class Loss: 0.514967	Domain Loss: 1.380285
# [1856/12800 (14%)]	Loss: 1.986976	Class Loss: 0.595288	Domain Loss: 1.391688
# [2496/12800 (20%)]	Loss: 1.861257	Class Loss: 0.475355	Domain Loss: 1.385901
# [3136/12800 (24%)]	Loss: 1.995926	Class Loss: 0.594053	Domain Loss: 1.401873
# [3776/12800 (30%)]	Loss: 1.820016	Class Loss: 0.425882	Domain Loss: 1.394134
# [4416/12800 (34%)]	Loss: 1.775734	Class Loss: 0.386478	Domain Loss: 1.389256
# [5056/12800 (40%)]	Loss: 1.690062	Class Loss: 0.298093	Domain Loss: 1.391968
# [5696/12800 (44%)]	Loss: 1.795379	Class Loss: 0.408521	Domain Loss: 1.386858
# [6336/12800 (50%)]	Loss: 1.913131	Class Loss: 0.526706	Domain Loss: 1.386425
#
# Source Accuracy: 2660.0/3200 (83.1250%)
# Target Accuracy: 1250.0/1600 (78.1250%)
# Domain Accuracy: 2589.0/4800 (53.9375%)
#
# Epoch: 89
# [576/12800 (4%)]	Loss: 1.920969	Class Loss: 0.529629	Domain Loss: 1.391340
# [1216/12800 (10%)]	Loss: 1.874596	Class Loss: 0.484742	Domain Loss: 1.389855
# [1856/12800 (14%)]	Loss: 1.703997	Class Loss: 0.318526	Domain Loss: 1.385472
# [2496/12800 (20%)]	Loss: 1.910594	Class Loss: 0.531038	Domain Loss: 1.379555
# [3136/12800 (24%)]	Loss: 1.849888	Class Loss: 0.491002	Domain Loss: 1.358886
# [3776/12800 (30%)]	Loss: 1.855354	Class Loss: 0.471475	Domain Loss: 1.383878
# [4416/12800 (34%)]	Loss: 1.893823	Class Loss: 0.505921	Domain Loss: 1.387902
# [5056/12800 (40%)]	Loss: 1.878685	Class Loss: 0.493848	Domain Loss: 1.384837
# [5696/12800 (44%)]	Loss: 1.927655	Class Loss: 0.548329	Domain Loss: 1.379325
# [6336/12800 (50%)]	Loss: 1.905572	Class Loss: 0.512169	Domain Loss: 1.393403
#
# Source Accuracy: 2670.0/3200 (83.4375%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2427.0/4800 (50.5625%)
#
# Epoch: 90
# [576/12800 (4%)]	Loss: 1.741767	Class Loss: 0.359265	Domain Loss: 1.382502
# [1216/12800 (10%)]	Loss: 1.775223	Class Loss: 0.383386	Domain Loss: 1.391837
# [1856/12800 (14%)]	Loss: 1.878008	Class Loss: 0.484323	Domain Loss: 1.393686
# [2496/12800 (20%)]	Loss: 1.952094	Class Loss: 0.552010	Domain Loss: 1.400083
# [3136/12800 (24%)]	Loss: 1.898229	Class Loss: 0.498111	Domain Loss: 1.400119
# [3776/12800 (30%)]	Loss: 1.784187	Class Loss: 0.413423	Domain Loss: 1.370764
# [4416/12800 (34%)]	Loss: 1.783903	Class Loss: 0.402587	Domain Loss: 1.381316
# [5056/12800 (40%)]	Loss: 1.787510	Class Loss: 0.401602	Domain Loss: 1.385908
# [5696/12800 (44%)]	Loss: 1.915277	Class Loss: 0.528343	Domain Loss: 1.386934
# [6336/12800 (50%)]	Loss: 1.863570	Class Loss: 0.468072	Domain Loss: 1.395498
#
# Source Accuracy: 2663.0/3200 (83.2188%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2634.0/4800 (54.8750%)
#
# Epoch: 91
# [576/12800 (4%)]	Loss: 1.910236	Class Loss: 0.524494	Domain Loss: 1.385741
# [1216/12800 (10%)]	Loss: 1.823903	Class Loss: 0.429602	Domain Loss: 1.394301
# [1856/12800 (14%)]	Loss: 1.907184	Class Loss: 0.517800	Domain Loss: 1.389384
# [2496/12800 (20%)]	Loss: 1.866302	Class Loss: 0.474330	Domain Loss: 1.391972
# [3136/12800 (24%)]	Loss: 1.746365	Class Loss: 0.373682	Domain Loss: 1.372683
# [3776/12800 (30%)]	Loss: 1.956969	Class Loss: 0.582365	Domain Loss: 1.374605
# [4416/12800 (34%)]	Loss: 1.902215	Class Loss: 0.507240	Domain Loss: 1.394975
# [5056/12800 (40%)]	Loss: 1.812595	Class Loss: 0.413746	Domain Loss: 1.398850
# [5696/12800 (44%)]	Loss: 1.902337	Class Loss: 0.508555	Domain Loss: 1.393782
# [6336/12800 (50%)]	Loss: 1.842791	Class Loss: 0.453897	Domain Loss: 1.388893
#
# Source Accuracy: 2666.0/3200 (83.3125%)
# Target Accuracy: 1248.0/1600 (78.0000%)
# Domain Accuracy: 2539.0/4800 (52.8958%)
#
# Epoch: 92
# [576/12800 (4%)]	Loss: 1.882966	Class Loss: 0.497611	Domain Loss: 1.385354
# [1216/12800 (10%)]	Loss: 1.853381	Class Loss: 0.482643	Domain Loss: 1.370738
# [1856/12800 (14%)]	Loss: 1.889198	Class Loss: 0.494383	Domain Loss: 1.394815
# [2496/12800 (20%)]	Loss: 1.931545	Class Loss: 0.544320	Domain Loss: 1.387225
# [3136/12800 (24%)]	Loss: 1.748521	Class Loss: 0.369517	Domain Loss: 1.379004
# [3776/12800 (30%)]	Loss: 1.857660	Class Loss: 0.463581	Domain Loss: 1.394079
# [4416/12800 (34%)]	Loss: 1.871594	Class Loss: 0.474655	Domain Loss: 1.396939
# [5056/12800 (40%)]	Loss: 1.766256	Class Loss: 0.381357	Domain Loss: 1.384900
# [5696/12800 (44%)]	Loss: 1.851761	Class Loss: 0.463518	Domain Loss: 1.388243
# [6336/12800 (50%)]	Loss: 1.813649	Class Loss: 0.429368	Domain Loss: 1.384281
#
# Source Accuracy: 2672.0/3200 (83.5000%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2366.0/4800 (49.2917%)
#
# Epoch: 93
# [576/12800 (4%)]	Loss: 1.815412	Class Loss: 0.423755	Domain Loss: 1.391657
# [1216/12800 (10%)]	Loss: 1.774975	Class Loss: 0.417727	Domain Loss: 1.357249
# [1856/12800 (14%)]	Loss: 1.701257	Class Loss: 0.312524	Domain Loss: 1.388733
# [2496/12800 (20%)]	Loss: 1.833022	Class Loss: 0.443758	Domain Loss: 1.389264
# [3136/12800 (24%)]	Loss: 1.825376	Class Loss: 0.431576	Domain Loss: 1.393800
# [3776/12800 (30%)]	Loss: 1.814927	Class Loss: 0.420961	Domain Loss: 1.393965
# [4416/12800 (34%)]	Loss: 1.893379	Class Loss: 0.507987	Domain Loss: 1.385392
# [5056/12800 (40%)]	Loss: 1.779646	Class Loss: 0.386737	Domain Loss: 1.392909
# [5696/12800 (44%)]	Loss: 1.789887	Class Loss: 0.404365	Domain Loss: 1.385522
# [6336/12800 (50%)]	Loss: 1.896796	Class Loss: 0.496564	Domain Loss: 1.400233
#
# Source Accuracy: 2674.0/3200 (83.5625%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2641.0/4800 (55.0208%)
#
# Epoch: 94
# [576/12800 (4%)]	Loss: 1.730862	Class Loss: 0.340379	Domain Loss: 1.390483
# [1216/12800 (10%)]	Loss: 2.113123	Class Loss: 0.719106	Domain Loss: 1.394017
# [1856/12800 (14%)]	Loss: 1.860777	Class Loss: 0.477582	Domain Loss: 1.383196
# [2496/12800 (20%)]	Loss: 1.779896	Class Loss: 0.388682	Domain Loss: 1.391214
# [3136/12800 (24%)]	Loss: 1.863102	Class Loss: 0.464151	Domain Loss: 1.398951
# [3776/12800 (30%)]	Loss: 1.856350	Class Loss: 0.478421	Domain Loss: 1.377929
# [4416/12800 (34%)]	Loss: 1.894191	Class Loss: 0.505619	Domain Loss: 1.388572
# [5056/12800 (40%)]	Loss: 1.904241	Class Loss: 0.515015	Domain Loss: 1.389226
# [5696/12800 (44%)]	Loss: 1.926495	Class Loss: 0.549983	Domain Loss: 1.376512
# [6336/12800 (50%)]	Loss: 1.819177	Class Loss: 0.423788	Domain Loss: 1.395389
#
# Source Accuracy: 2668.0/3200 (83.3750%)
# Target Accuracy: 1237.0/1600 (77.3125%)
# Domain Accuracy: 2548.0/4800 (53.0833%)
#
# Epoch: 95
# [576/12800 (4%)]	Loss: 1.926864	Class Loss: 0.538448	Domain Loss: 1.388416
# [1216/12800 (10%)]	Loss: 1.879493	Class Loss: 0.505056	Domain Loss: 1.374437
# [1856/12800 (14%)]	Loss: 1.822885	Class Loss: 0.431331	Domain Loss: 1.391555
# [2496/12800 (20%)]	Loss: 1.732446	Class Loss: 0.351625	Domain Loss: 1.380821
# [3136/12800 (24%)]	Loss: 1.816853	Class Loss: 0.439139	Domain Loss: 1.377714
# [3776/12800 (30%)]	Loss: 1.882399	Class Loss: 0.499654	Domain Loss: 1.382745
# [4416/12800 (34%)]	Loss: 1.742558	Class Loss: 0.354687	Domain Loss: 1.387871
# [5056/12800 (40%)]	Loss: 1.877283	Class Loss: 0.489254	Domain Loss: 1.388029
# [5696/12800 (44%)]	Loss: 1.877958	Class Loss: 0.477041	Domain Loss: 1.400917
# [6336/12800 (50%)]	Loss: 1.763157	Class Loss: 0.369264	Domain Loss: 1.393893
#
# Source Accuracy: 2668.0/3200 (83.3750%)
# Target Accuracy: 1239.0/1600 (77.4375%)
# Domain Accuracy: 2876.0/4800 (59.9167%)
#
# Epoch: 96
# [576/12800 (4%)]	Loss: 1.848650	Class Loss: 0.448428	Domain Loss: 1.400222
# [1216/12800 (10%)]	Loss: 1.909254	Class Loss: 0.518907	Domain Loss: 1.390347
# [1856/12800 (14%)]	Loss: 1.818869	Class Loss: 0.442073	Domain Loss: 1.376796
# [2496/12800 (20%)]	Loss: 1.822853	Class Loss: 0.435055	Domain Loss: 1.387798
# [3136/12800 (24%)]	Loss: 1.951499	Class Loss: 0.572161	Domain Loss: 1.379338
# [3776/12800 (30%)]	Loss: 1.774692	Class Loss: 0.385109	Domain Loss: 1.389583
# [4416/12800 (34%)]	Loss: 1.951745	Class Loss: 0.571404	Domain Loss: 1.380341
# [5056/12800 (40%)]	Loss: 1.773779	Class Loss: 0.392725	Domain Loss: 1.381054
# [5696/12800 (44%)]	Loss: 1.845846	Class Loss: 0.467617	Domain Loss: 1.378229
# [6336/12800 (50%)]	Loss: 1.814266	Class Loss: 0.433976	Domain Loss: 1.380290
#
# Source Accuracy: 2673.0/3200 (83.5312%)
# Target Accuracy: 1239.0/1600 (77.4375%)
# Domain Accuracy: 2533.0/4800 (52.7708%)
#
# Epoch: 97
# [576/12800 (4%)]	Loss: 1.868798	Class Loss: 0.485997	Domain Loss: 1.382801
# [1216/12800 (10%)]	Loss: 1.915496	Class Loss: 0.532645	Domain Loss: 1.382851
# [1856/12800 (14%)]	Loss: 1.744028	Class Loss: 0.351111	Domain Loss: 1.392917
# [2496/12800 (20%)]	Loss: 1.806979	Class Loss: 0.425170	Domain Loss: 1.381809
# [3136/12800 (24%)]	Loss: 1.823016	Class Loss: 0.435864	Domain Loss: 1.387152
# [3776/12800 (30%)]	Loss: 1.661111	Class Loss: 0.253297	Domain Loss: 1.407814
# [4416/12800 (34%)]	Loss: 1.845805	Class Loss: 0.454903	Domain Loss: 1.390902
# [5056/12800 (40%)]	Loss: 1.795078	Class Loss: 0.419563	Domain Loss: 1.375515
# [5696/12800 (44%)]	Loss: 1.812683	Class Loss: 0.461756	Domain Loss: 1.350928
# [6336/12800 (50%)]	Loss: 1.759114	Class Loss: 0.372762	Domain Loss: 1.386352
#
# Source Accuracy: 2673.0/3200 (83.5312%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2781.0/4800 (57.9375%)
#
# Epoch: 98
# [576/12800 (4%)]	Loss: 1.818199	Class Loss: 0.435140	Domain Loss: 1.383059
# [1216/12800 (10%)]	Loss: 1.913097	Class Loss: 0.514094	Domain Loss: 1.399003
# [1856/12800 (14%)]	Loss: 1.827559	Class Loss: 0.442363	Domain Loss: 1.385196
# [2496/12800 (20%)]	Loss: 1.790380	Class Loss: 0.407409	Domain Loss: 1.382971
# [3136/12800 (24%)]	Loss: 1.830882	Class Loss: 0.442753	Domain Loss: 1.388129
# [3776/12800 (30%)]	Loss: 1.995511	Class Loss: 0.625875	Domain Loss: 1.369636
# [4416/12800 (34%)]	Loss: 1.850817	Class Loss: 0.464556	Domain Loss: 1.386261
# [5056/12800 (40%)]	Loss: 1.777991	Class Loss: 0.389078	Domain Loss: 1.388913
# [5696/12800 (44%)]	Loss: 1.809970	Class Loss: 0.419775	Domain Loss: 1.390195
# [6336/12800 (50%)]	Loss: 1.909912	Class Loss: 0.532277	Domain Loss: 1.377635
#
# Source Accuracy: 2676.0/3200 (83.6250%)
# Target Accuracy: 1238.0/1600 (77.3750%)
# Domain Accuracy: 2455.0/4800 (51.1458%)
#
# Epoch: 99
# [576/12800 (4%)]	Loss: 1.731578	Class Loss: 0.328089	Domain Loss: 1.403489
# [1216/12800 (10%)]	Loss: 1.987507	Class Loss: 0.599533	Domain Loss: 1.387975
# [1856/12800 (14%)]	Loss: 1.922079	Class Loss: 0.528627	Domain Loss: 1.393451
# [2496/12800 (20%)]	Loss: 1.759515	Class Loss: 0.383158	Domain Loss: 1.376357
# [3136/12800 (24%)]	Loss: 1.907775	Class Loss: 0.515881	Domain Loss: 1.391894
# [3776/12800 (30%)]	Loss: 1.759727	Class Loss: 0.366093	Domain Loss: 1.393634
# [4416/12800 (34%)]	Loss: 1.879775	Class Loss: 0.489397	Domain Loss: 1.390378
# [5056/12800 (40%)]	Loss: 1.952656	Class Loss: 0.555095	Domain Loss: 1.397561
# [5696/12800 (44%)]	Loss: 1.816596	Class Loss: 0.431212	Domain Loss: 1.385384
# [6336/12800 (50%)]	Loss: 1.879354	Class Loss: 0.484439	Domain Loss: 1.394915
#
# Source Accuracy: 2667.0/3200 (83.3438%)
# Target Accuracy: 1243.0/1600 (77.6875%)
# Domain Accuracy: 2817.0/4800 (58.6875%)
#
# total run time: (min) 1.1551141063372294

# %%
plt.plot(range(len(total_loss)),total_loss,c='r',label='total_loss')
plt.plot(d_loss,c='b',label='domain_loss')
plt.plot(c_loss,c='y',label='clf_loss')
plt.title('traing')
plt.legend(loc='best')
plt.show()

# %%
print('max target accuracy: ',max(acc_list3))
plt.plot(range(len(acc_list1)),acc_list1,c='r',label='source1(F+W)_acc')
# plt.plot(acc_list2,c='b',label='source2(forum)_acc')
plt.plot(acc_list3,c='g',label='target(T)_acc')
plt.plot(acc_list4,c='y',label='domain_acc')
plt.axhline(max(acc_list3),c='b',linestyle='--')
plt.title('testing')
plt.legend(loc='best')
plt.show()
# Out:
# max target accuracy:  78.75
