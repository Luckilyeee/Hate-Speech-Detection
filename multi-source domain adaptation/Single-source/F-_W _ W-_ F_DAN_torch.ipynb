# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import torchvision
import torch.optim as optim

import numpy as np
from sklearn.manifold import TSNE

import argparse, sys, os

import torch
from torchtext import data, datasets
import random
torch.backends.cudnn.deterministic = True

import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import time
from collections import Counter
import matplotlib.pyplot as plt

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('stopwords')


forum = pd.read_csv("Forum.csv")
wiki = pd.read_csv("Wiki.csv")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# remove puctunations, https
import re
def  clean_text(df, text_field):
    df[text_field] = df[text_field].str.lower()
    df[text_field] = df[text_field].apply(lambda elem: re.sub(r"(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    return df
forum = clean_text(forum, 'text')
wiki = clean_text(wiki, 'text')

stopwords = nltk.corpus.stopwords.words('english')
forum['text'] = forum['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
wiki['text'] = wiki['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
forum['domain'] = 1
wiki['domain'] = 0

# %%
forum = forum[['text', 'label', 'domain']]
wiki = wiki[['text', 'label', 'domain']]

# %%
forum.to_csv('F.csv', index=False)
wiki.to_csv('W.csv', index=False)

# %% [markdown]
# #tokenize

# %%
SEED = 1234
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
TEXT = data.Field(tokenize = 'spacy', batch_first=True)
LABEL = data.LabelField(dtype=torch.float)
DOMAIN = data.LabelField(dtype=torch.float)

# %%
#loading custom dataset
W =data.TabularDataset(path = 'W.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(W.examples[0]))
# Out:
# {'text': ['right', 'fine', 'did', 'nt', 'even', 'start', 'discussion', 'joined', 'every', 'time', 'someone', 'tries', 'get', 'article', 'neutral', 'bullheaded', 'evolutionist', 'jumps', 'throat', 'stupid', 'evolution', 'proven', 'you', 're', 'idiot'], 'label': '1.0', 'domain': '0'}

# %%
#loading custom dataset
forum =data.TabularDataset(path = 'F.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(forum.examples[0]))
# Out:
# {'text': ['watch', 'video', 'minutes', 'see', 'eventually', 'biracial', 'minority', 'butchered'], 'label': '1.0', 'domain': '1'}

# %% [markdown]
# #split train, test, val

# %%
def split(train_size, dataset):
  train, test = dataset.split([6000, 2000], random_state = random.seed(SEED))
  train, other = train.split([train_size, 6000-train_size], random_state = random.seed(SEED))
  # train, val = train.split(random_state = random.seed(SEED))
  return train, test

train_size = 1000
W_train_data, W_test_data = split(train_size, W)
F_train_data, F_test_data = split(train_size, forum)

# %% [markdown]
# #convert texts into integer sequences.

# %% [markdown]
# build vocabulary

# %%
#initialize glove embeddings
MAX_VOCAB_SIZE = 25_000

TEXT.build_vocab(F_train_data, W_train_data, 
                 max_size = MAX_VOCAB_SIZE, 
                 vectors = "glove.6B.100d", 
                 unk_init = torch.Tensor.normal_) 
LABEL.build_vocab(F_train_data, W_train_data)
DOMAIN.build_vocab(F_train_data, W_train_data)

# %% [markdown]
# creat iterators

# %%
#set batch size
BATCH_SIZE = 64

#check whether cuda is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  

F_train_iterator, F_test_iterator = data.BucketIterator.splits(
    (F_train_data, F_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

W_train_iterator, W_test_iterator = data.BucketIterator.splits(
    (W_train_data, W_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

# %%
class GradReverse(torch.autograd.Function):
    """
    Extension of grad reverse layer
    """
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        grad_output = grad_output.neg() * ctx.constant
        return grad_output, None

    def grad_reverse(x, constant):
        return GradReverse.apply(x, constant)

class Extractor(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, 
                 dropout, pad_idx, pretrained_embeddings):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        self.embedding.weight.data.copy_(pretrained_embeddings)
        self.conv_0 = nn.Conv2d(in_channels = 1, 
                                out_channels = n_filters, 
                                kernel_size = (filter_sizes, embedding_dim))
        
        
        
        self.fc = nn.Linear(n_filters, output_dim)
        
        self.dropout = nn.Dropout(dropout)

        # self.relu = nn.ReLU(inplace=True)
        # self.max_pool1d = nn.MaxPool1d(2,2)
        
    def forward(self, text):
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)
                
        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved_0 = F.relu(self.conv_0(embedded).squeeze(3))
            
        #conved_n = [batch size, n_filters, sent len - filter_sizes[n] + 1]
        
        pooled_0 = F.max_pool1d(conved_0, conved_0.shape[2]).squeeze(2)
        
        #pooled_n = [batch size, n_filters]
        x = self.dropout(pooled_0)
        #x = [batch size, n_filters * len(filter_sizes)]
            
        return x

class Class_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Class_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input):
        x = self.fc(input)
        return x

class Domain_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Domain_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input, constant):
        input = GradReverse.grad_reverse(input, constant)
        return self.fc(input)

# %%
def optimizer_scheduler(optimizer, p):
    """
    Adjust the learning rate of optimizer
    :param optimizer: optimizer for updating parameters
    :param p: a variable for adjusting learning rate
    :return: optimizer
    """
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75

    return optimizer

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 100
FILTER_SIZES = 1
OUTPUT_DIM = 1
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]
pretrained_embeddings = TEXT.vocab.vectors

extractor = Extractor(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT, PAD_IDX,pretrained_embeddings )
class_classifier = Class_classifier(N_FILTERS, OUTPUT_DIM)
domain_classifier = Domain_classifier(N_FILTERS, OUTPUT_DIM)

# %% [markdown]
# check the number of parameters

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(extractor) + count_parameters(class_classifier) + count_parameters(domain_classifier):,} trainable parameters')
# Out:
# The model has 1,018,303 trainable parameters

# %% [markdown]
# zero the initial weights of the unknown and padding tokens

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]

extractor.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
extractor.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

# %%
criterion = nn.BCEWithLogitsLoss()

extractor = extractor.to(device)
class_classifier = class_classifier.to(device)
domain_classifier = domain_classifier.to(device)

criterion = criterion.to(device)

# %% [markdown]
# define function to calculate the correct predictions

# %%
def train(training_mode, extractor, class_classifier, domain_classifier, criterion,
          source_data, target_data, optimizer, epoch):
  
    epoch_loss = 0
    epoch_acc = 0

    # setup models
    extractor.train()
    class_classifier.train()
    domain_classifier.train()

    # steps
    start_steps = epoch * len(source_data)
    total_steps = 10 * len(source_data)

    for batch_idx,(sdata, tdata) in enumerate(zip(source_data, target_data)):
        if training_mode == 'dann':
            # setup hyperparameters
            p = float(batch_idx + start_steps) / total_steps
            constant = 2. / (1. + np.exp(-gamma * p)) - 1

            # prepare the data
            input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
            input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
    
            # setup optimizer
            optimizer = optimizer_scheduler(optimizer, p)
            optimizer.zero_grad()

            # compute the output of source domain and target domain
            src_feature = extractor(input1)
            tgt_feature = extractor(input3)

            # compute the class loss of src_feature
            class_pred = class_classifier(src_feature).squeeze(1)
            
            class_loss = criterion(class_pred, label1)
  

            # compute the domain loss of src_feature and target_feature
            tgt_preds = domain_classifier(tgt_feature, constant).squeeze(1)
            src_pred = domain_classifier(src_feature, constant).squeeze(1)
            
            tgt_loss = criterion(tgt_preds, domain3)
            src_loss = criterion(src_pred, domain1)
            
            
            domain_loss = tgt_loss + src_loss

            loss = class_loss + theta * domain_loss

            loss.backward()
            optimizer.step()

            # print loss

            if (batch_idx + 1) % 10 == 0:
                print('[{}/{} ({:.0f}%)]\tLoss: {:.6f}\tClass Loss: {:.6f}\tDomain Loss: {:.6f}'.format(
                    batch_idx * len(input1), len(F_train_data),
                    100. * batch_idx / len(source_data), loss.item(), class_loss.item(),
                    domain_loss.item()
                ))
                
            total_loss.append(loss.item())
            c_loss.append( class_loss.item())
            d_loss.append(domain_loss.item())

# %%
def test(extractor, class_classifier, domain_classifier, source_data, target_data):
 
    # setup the network
    extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()
    source_correct = 0.0
    target_correct = 0.0
    domain_correct = 0.0
    tgt_correct = 0.0
    src_correct = 0.0
    
    for batch_idx, sdata in enumerate(source_data):
        # setup hyperparameters
        p = float(batch_idx) / len(source_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1.

        input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
        
        output1 = class_classifier(extractor(input1)).squeeze(1)
        output1 = torch.round(torch.sigmoid(output1))
        source_correct += (output1 == label1).cpu().sum()

        src_preds = domain_classifier(extractor(input1), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        src_correct += (src_preds == domain1).cpu().sum()

    for batch_idx, tdata in enumerate(target_data):
        # setup hyperparameters
        p = float(batch_idx) / len(target_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1

        input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
        
        output3 = class_classifier(extractor(input3)).squeeze(1)
        output3 = torch.round(torch.sigmoid(output3))
        target_correct += (output3 == label3).cpu().sum()

        src_preds = domain_classifier(extractor(input3), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        tgt_correct += (src_preds == domain3).cpu().sum()


    domain_correct = tgt_correct + src_correct

    print('\nSource Accuracy: {}/{} ({:.4f}%)\nTarget Accuracy: {}/{} ({:.4f}%)\n'
          'Domain Accuracy: {}/{} ({:.4f}%)\n'.
        format(
        source_correct, len(F_test_data), 100. * float(source_correct) / len(F_test_data),
        target_correct, len(W_test_data), 100. * float(target_correct) / len(W_test_data),
        domain_correct, len(F_test_data) + len(W_test_data),
        100. * float(domain_correct) / (len(F_test_data) + len(W_test_data))
    ))
    acc_list1.append(100. * float(source_correct) / len(F_test_data))
    acc_list3.append(100. * float(target_correct) / len(W_test_data))
    acc_list4.append(100. * float(domain_correct) / (len(F_test_data) + len(W_test_data)))

# %%
def main():

    # prepare the source data and target data
    src_train_data = W_train_iterator
    src_test_data = W_test_iterator
    
    tgt_train_data = F_train_iterator
    tgt_test_data = F_test_iterator

    optimizer = optim.SGD([
            {'params': extractor.parameters()},
                            {'params': class_classifier.parameters()},
                            {'params': domain_classifier.parameters()}
    ], lr= 0.01, momentum= 0.9)


    for epoch in range(100):
    
        print('Epoch: {}'.format(epoch))
        train('dann', extractor, class_classifier, domain_classifier, criterion,
                    src_train_data, tgt_train_data, optimizer, epoch)
        test(extractor, class_classifier, domain_classifier, src_test_data, tgt_test_data)
        
total_loss, d_loss, c_loss = [],[],[]
acc_list1, acc_list3, acc_list4 = [],[],[]
if __name__ == '__main__':
    gamma = 10
    theta = 1
    time_start=time.time()
    main()
    time_end=time.time()
    print('total run time: (min)',(time_end-time_start)/60.)
# Out:
# Epoch: 0
# [576/1000 (56%)]	Loss: 2.192596	Class Loss: 0.815774	Domain Loss: 1.376822
#
# Source Accuracy: 1076.0/2000 (53.8000%)
# Target Accuracy: 958.0/2000 (47.9000%)
# Domain Accuracy: 2421.0/4000 (60.5250%)
#
# Epoch: 1
# [576/1000 (56%)]	Loss: 2.026086	Class Loss: 0.678597	Domain Loss: 1.347489
#
# Source Accuracy: 1364.0/2000 (68.2000%)
# Target Accuracy: 990.0/2000 (49.5000%)
# Domain Accuracy: 2699.0/4000 (67.4750%)
#
# Epoch: 2
# [576/1000 (56%)]	Loss: 1.941461	Class Loss: 0.683311	Domain Loss: 1.258150
#
# Source Accuracy: 1539.0/2000 (76.9500%)
# Target Accuracy: 1155.0/2000 (57.7500%)
# Domain Accuracy: 2682.0/4000 (67.0500%)
#
# Epoch: 3
# [576/1000 (56%)]	Loss: 1.977956	Class Loss: 0.701368	Domain Loss: 1.276588
#
# Source Accuracy: 1467.0/2000 (73.3500%)
# Target Accuracy: 1011.0/2000 (50.5500%)
# Domain Accuracy: 2585.0/4000 (64.6250%)
#
# Epoch: 4
# [360/1000 (56%)]	Loss: 2.087074	Class Loss: 0.621195	Domain Loss: 1.465878
#
# Source Accuracy: 1575.0/2000 (78.7500%)
# Target Accuracy: 1134.0/2000 (56.7000%)
# Domain Accuracy: 2401.0/4000 (60.0250%)
#
# Epoch: 5
# [576/1000 (56%)]	Loss: 2.099997	Class Loss: 0.673524	Domain Loss: 1.426472
#
# Source Accuracy: 1618.0/2000 (80.9000%)
# Target Accuracy: 1115.0/2000 (55.7500%)
# Domain Accuracy: 2256.0/4000 (56.4000%)
#
# Epoch: 6
# [576/1000 (56%)]	Loss: 2.034755	Class Loss: 0.661072	Domain Loss: 1.373683
#
# Source Accuracy: 1576.0/2000 (78.8000%)
# Target Accuracy: 1064.0/2000 (53.2000%)
# Domain Accuracy: 2145.0/4000 (53.6250%)
#
# Epoch: 7
# [576/1000 (56%)]	Loss: 2.059753	Class Loss: 0.624087	Domain Loss: 1.435667
#
# Source Accuracy: 1578.0/2000 (78.9000%)
# Target Accuracy: 1143.0/2000 (57.1500%)
# Domain Accuracy: 2077.0/4000 (51.9250%)
#
# Epoch: 8
# [576/1000 (56%)]	Loss: 2.035626	Class Loss: 0.647259	Domain Loss: 1.388367
#
# Source Accuracy: 1606.0/2000 (80.3000%)
# Target Accuracy: 1099.0/2000 (54.9500%)
# Domain Accuracy: 2055.0/4000 (51.3750%)
#
# Epoch: 9
# [576/1000 (56%)]	Loss: 2.024147	Class Loss: 0.596247	Domain Loss: 1.427900
#
# Source Accuracy: 1626.0/2000 (81.3000%)
# Target Accuracy: 1145.0/2000 (57.2500%)
# Domain Accuracy: 2099.0/4000 (52.4750%)
#
# Epoch: 10
# [576/1000 (56%)]	Loss: 1.904165	Class Loss: 0.548224	Domain Loss: 1.355941
#
# Source Accuracy: 1624.0/2000 (81.2000%)
# Target Accuracy: 1151.0/2000 (57.5500%)
# Domain Accuracy: 2167.0/4000 (54.1750%)
#
# Epoch: 11
# [576/1000 (56%)]	Loss: 2.031012	Class Loss: 0.682559	Domain Loss: 1.348453
#
# Source Accuracy: 1625.0/2000 (81.2500%)
# Target Accuracy: 1153.0/2000 (57.6500%)
# Domain Accuracy: 2220.0/4000 (55.5000%)
#
# Epoch: 12
# [576/1000 (56%)]	Loss: 1.898558	Class Loss: 0.648443	Domain Loss: 1.250115
#
# Source Accuracy: 1635.0/2000 (81.7500%)
# Target Accuracy: 1152.0/2000 (57.6000%)
# Domain Accuracy: 2312.0/4000 (57.8000%)
#
# Epoch: 13
# [576/1000 (56%)]	Loss: 1.879631	Class Loss: 0.541526	Domain Loss: 1.338105
#
# Source Accuracy: 1638.0/2000 (81.9000%)
# Target Accuracy: 1162.0/2000 (58.1000%)
# Domain Accuracy: 2360.0/4000 (59.0000%)
#
# Epoch: 14
# [576/1000 (56%)]	Loss: 2.021103	Class Loss: 0.655207	Domain Loss: 1.365897
#
# Source Accuracy: 1640.0/2000 (82.0000%)
# Target Accuracy: 1135.0/2000 (56.7500%)
# Domain Accuracy: 2440.0/4000 (61.0000%)
#
# Epoch: 15
# [576/1000 (56%)]	Loss: 1.872806	Class Loss: 0.621186	Domain Loss: 1.251621
#
# Source Accuracy: 1647.0/2000 (82.3500%)
# Target Accuracy: 1170.0/2000 (58.5000%)
# Domain Accuracy: 2484.0/4000 (62.1000%)
#
# Epoch: 16
# [360/1000 (56%)]	Loss: 2.134902	Class Loss: 0.673862	Domain Loss: 1.461040
#
# Source Accuracy: 1655.0/2000 (82.7500%)
# Target Accuracy: 1178.0/2000 (58.9000%)
# Domain Accuracy: 2540.0/4000 (63.5000%)
#
# Epoch: 17
# [576/1000 (56%)]	Loss: 1.858567	Class Loss: 0.576010	Domain Loss: 1.282557
#
# Source Accuracy: 1656.0/2000 (82.8000%)
# Target Accuracy: 1179.0/2000 (58.9500%)
# Domain Accuracy: 2585.0/4000 (64.6250%)
#
# Epoch: 18
# [576/1000 (56%)]	Loss: 1.862695	Class Loss: 0.536671	Domain Loss: 1.326024
#
# Source Accuracy: 1661.0/2000 (83.0500%)
# Target Accuracy: 1195.0/2000 (59.7500%)
# Domain Accuracy: 2488.0/4000 (62.2000%)
#
# Epoch: 19
# [576/1000 (56%)]	Loss: 1.861445	Class Loss: 0.638128	Domain Loss: 1.223318
#
# Source Accuracy: 1674.0/2000 (83.7000%)
# Target Accuracy: 1203.0/2000 (60.1500%)
# Domain Accuracy: 2695.0/4000 (67.3750%)
#
# Epoch: 20
# [576/1000 (56%)]	Loss: 1.881109	Class Loss: 0.644098	Domain Loss: 1.237011
#
# Source Accuracy: 1676.0/2000 (83.8000%)
# Target Accuracy: 1209.0/2000 (60.4500%)
# Domain Accuracy: 2632.0/4000 (65.8000%)
#
# Epoch: 21
# [576/1000 (56%)]	Loss: 1.958873	Class Loss: 0.702640	Domain Loss: 1.256234
#
# Source Accuracy: 1672.0/2000 (83.6000%)
# Target Accuracy: 1178.0/2000 (58.9000%)
# Domain Accuracy: 2688.0/4000 (67.2000%)
#
# Epoch: 22
# [576/1000 (56%)]	Loss: 1.909400	Class Loss: 0.588206	Domain Loss: 1.321194
#
# Source Accuracy: 1676.0/2000 (83.8000%)
# Target Accuracy: 1222.0/2000 (61.1000%)
# Domain Accuracy: 2600.0/4000 (65.0000%)
#
# Epoch: 23
# [576/1000 (56%)]	Loss: 1.824227	Class Loss: 0.561471	Domain Loss: 1.262757
#
# Source Accuracy: 1676.0/2000 (83.8000%)
# Target Accuracy: 1193.0/2000 (59.6500%)
# Domain Accuracy: 2717.0/4000 (67.9250%)
#
# Epoch: 24
# [360/1000 (56%)]	Loss: 1.912613	Class Loss: 0.504129	Domain Loss: 1.408484
#
# Source Accuracy: 1684.0/2000 (84.2000%)
# Target Accuracy: 1223.0/2000 (61.1500%)
# Domain Accuracy: 2673.0/4000 (66.8250%)
#
# Epoch: 25
# [576/1000 (56%)]	Loss: 1.924985	Class Loss: 0.708572	Domain Loss: 1.216413
#
# Source Accuracy: 1684.0/2000 (84.2000%)
# Target Accuracy: 1218.0/2000 (60.9000%)
# Domain Accuracy: 2700.0/4000 (67.5000%)
#
# Epoch: 26
# [576/1000 (56%)]	Loss: 1.878634	Class Loss: 0.544088	Domain Loss: 1.334546
#
# Source Accuracy: 1686.0/2000 (84.3000%)
# Target Accuracy: 1216.0/2000 (60.8000%)
# Domain Accuracy: 2645.0/4000 (66.1250%)
#
# Epoch: 27
# [576/1000 (56%)]	Loss: 1.842966	Class Loss: 0.614552	Domain Loss: 1.228413
#
# Source Accuracy: 1687.0/2000 (84.3500%)
# Target Accuracy: 1219.0/2000 (60.9500%)
# Domain Accuracy: 2690.0/4000 (67.2500%)
#
# Epoch: 28
# [576/1000 (56%)]	Loss: 1.861538	Class Loss: 0.548953	Domain Loss: 1.312586
#
# Source Accuracy: 1687.0/2000 (84.3500%)
# Target Accuracy: 1241.0/2000 (62.0500%)
# Domain Accuracy: 2630.0/4000 (65.7500%)
#
# Epoch: 29
# [576/1000 (56%)]	Loss: 1.831826	Class Loss: 0.580616	Domain Loss: 1.251209
#
# Source Accuracy: 1689.0/2000 (84.4500%)
# Target Accuracy: 1224.0/2000 (61.2000%)
# Domain Accuracy: 2556.0/4000 (63.9000%)
#
# Epoch: 30
# [576/1000 (56%)]	Loss: 1.778106	Class Loss: 0.527026	Domain Loss: 1.251079
#
# Source Accuracy: 1682.0/2000 (84.1000%)
# Target Accuracy: 1232.0/2000 (61.6000%)
# Domain Accuracy: 2541.0/4000 (63.5250%)
#
# Epoch: 31
# [576/1000 (56%)]	Loss: 1.782765	Class Loss: 0.496339	Domain Loss: 1.286425
#
# Source Accuracy: 1688.0/2000 (84.4000%)
# Target Accuracy: 1241.0/2000 (62.0500%)
# Domain Accuracy: 2521.0/4000 (63.0250%)
#
# Epoch: 32
# [360/1000 (56%)]	Loss: 1.936560	Class Loss: 0.537706	Domain Loss: 1.398854
#
# Source Accuracy: 1686.0/2000 (84.3000%)
# Target Accuracy: 1232.0/2000 (61.6000%)
# Domain Accuracy: 2561.0/4000 (64.0250%)
#
# Epoch: 33
# [576/1000 (56%)]	Loss: 1.959067	Class Loss: 0.630248	Domain Loss: 1.328819
#
# Source Accuracy: 1684.0/2000 (84.2000%)
# Target Accuracy: 1217.0/2000 (60.8500%)
# Domain Accuracy: 2558.0/4000 (63.9500%)
#
# Epoch: 34
# [576/1000 (56%)]	Loss: 1.841552	Class Loss: 0.510086	Domain Loss: 1.331466
#
# Source Accuracy: 1681.0/2000 (84.0500%)
# Target Accuracy: 1223.0/2000 (61.1500%)
# Domain Accuracy: 2488.0/4000 (62.2000%)
#
# Epoch: 35
# [360/1000 (56%)]	Loss: 1.886738	Class Loss: 0.547769	Domain Loss: 1.338969
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1243.0/2000 (62.1500%)
# Domain Accuracy: 2521.0/4000 (63.0250%)
#
# Epoch: 36
# [576/1000 (56%)]	Loss: 1.988590	Class Loss: 0.641251	Domain Loss: 1.347338
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1252.0/2000 (62.6000%)
# Domain Accuracy: 2510.0/4000 (62.7500%)
#
# Epoch: 37
# [576/1000 (56%)]	Loss: 1.910229	Class Loss: 0.629526	Domain Loss: 1.280703
#
# Source Accuracy: 1692.0/2000 (84.6000%)
# Target Accuracy: 1250.0/2000 (62.5000%)
# Domain Accuracy: 2495.0/4000 (62.3750%)
#
# Epoch: 38
# [576/1000 (56%)]	Loss: 1.882955	Class Loss: 0.579140	Domain Loss: 1.303816
#
# Source Accuracy: 1692.0/2000 (84.6000%)
# Target Accuracy: 1252.0/2000 (62.6000%)
# Domain Accuracy: 2479.0/4000 (61.9750%)
#
# Epoch: 39
# [360/1000 (56%)]	Loss: 1.989864	Class Loss: 0.614171	Domain Loss: 1.375692
#
# Source Accuracy: 1692.0/2000 (84.6000%)
# Target Accuracy: 1246.0/2000 (62.3000%)
# Domain Accuracy: 2472.0/4000 (61.8000%)
#
# Epoch: 40
# [576/1000 (56%)]	Loss: 1.900689	Class Loss: 0.574741	Domain Loss: 1.325949
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1255.0/2000 (62.7500%)
# Domain Accuracy: 2490.0/4000 (62.2500%)
#
# Epoch: 41
# [576/1000 (56%)]	Loss: 1.926812	Class Loss: 0.624076	Domain Loss: 1.302735
#
# Source Accuracy: 1688.0/2000 (84.4000%)
# Target Accuracy: 1247.0/2000 (62.3500%)
# Domain Accuracy: 2481.0/4000 (62.0250%)
#
# Epoch: 42
# [576/1000 (56%)]	Loss: 1.714215	Class Loss: 0.464515	Domain Loss: 1.249700
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1254.0/2000 (62.7000%)
# Domain Accuracy: 2463.0/4000 (61.5750%)
#
# Epoch: 43
# [576/1000 (56%)]	Loss: 1.806238	Class Loss: 0.502057	Domain Loss: 1.304181
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1265.0/2000 (63.2500%)
# Domain Accuracy: 2469.0/4000 (61.7250%)
#
# Epoch: 44
# [576/1000 (56%)]	Loss: 1.899683	Class Loss: 0.549108	Domain Loss: 1.350575
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1271.0/2000 (63.5500%)
# Domain Accuracy: 2465.0/4000 (61.6250%)
#
# Epoch: 45
# [576/1000 (56%)]	Loss: 1.773172	Class Loss: 0.521630	Domain Loss: 1.251542
#
# Source Accuracy: 1704.0/2000 (85.2000%)
# Target Accuracy: 1276.0/2000 (63.8000%)
# Domain Accuracy: 2466.0/4000 (61.6500%)
#
# Epoch: 46
# [576/1000 (56%)]	Loss: 1.831627	Class Loss: 0.525656	Domain Loss: 1.305971
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1275.0/2000 (63.7500%)
# Domain Accuracy: 2455.0/4000 (61.3750%)
#
# Epoch: 47
# [576/1000 (56%)]	Loss: 1.805842	Class Loss: 0.485000	Domain Loss: 1.320842
#
# Source Accuracy: 1703.0/2000 (85.1500%)
# Target Accuracy: 1277.0/2000 (63.8500%)
# Domain Accuracy: 2456.0/4000 (61.4000%)
#
# Epoch: 48
# [576/1000 (56%)]	Loss: 1.868051	Class Loss: 0.499705	Domain Loss: 1.368346
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1274.0/2000 (63.7000%)
# Domain Accuracy: 2465.0/4000 (61.6250%)
#
# Epoch: 49
# [576/1000 (56%)]	Loss: 1.694301	Class Loss: 0.439111	Domain Loss: 1.255189
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1280.0/2000 (64.0000%)
# Domain Accuracy: 2461.0/4000 (61.5250%)
#
# Epoch: 50
# [576/1000 (56%)]	Loss: 1.885851	Class Loss: 0.531299	Domain Loss: 1.354551
#
# Source Accuracy: 1699.0/2000 (84.9500%)
# Target Accuracy: 1285.0/2000 (64.2500%)
# Domain Accuracy: 2427.0/4000 (60.6750%)
#
# Epoch: 51
# [576/1000 (56%)]	Loss: 1.913247	Class Loss: 0.567826	Domain Loss: 1.345422
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1273.0/2000 (63.6500%)
# Domain Accuracy: 2392.0/4000 (59.8000%)
#
# Epoch: 52
# [576/1000 (56%)]	Loss: 1.775770	Class Loss: 0.440626	Domain Loss: 1.335144
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1275.0/2000 (63.7500%)
# Domain Accuracy: 2401.0/4000 (60.0250%)
#
# Epoch: 53
# [360/1000 (56%)]	Loss: 1.799432	Class Loss: 0.511855	Domain Loss: 1.287577
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1288.0/2000 (64.4000%)
# Domain Accuracy: 2404.0/4000 (60.1000%)
#
# Epoch: 54
# [576/1000 (56%)]	Loss: 1.873728	Class Loss: 0.571581	Domain Loss: 1.302147
#
# Source Accuracy: 1701.0/2000 (85.0500%)
# Target Accuracy: 1293.0/2000 (64.6500%)
# Domain Accuracy: 2372.0/4000 (59.3000%)
#
# Epoch: 55
# [576/1000 (56%)]	Loss: 1.805550	Class Loss: 0.529322	Domain Loss: 1.276229
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1285.0/2000 (64.2500%)
# Domain Accuracy: 2387.0/4000 (59.6750%)
#
# Epoch: 56
# [576/1000 (56%)]	Loss: 1.811682	Class Loss: 0.588373	Domain Loss: 1.223308
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1285.0/2000 (64.2500%)
# Domain Accuracy: 2377.0/4000 (59.4250%)
#
# Epoch: 57
# [576/1000 (56%)]	Loss: 1.819047	Class Loss: 0.494845	Domain Loss: 1.324202
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1286.0/2000 (64.3000%)
# Domain Accuracy: 2334.0/4000 (58.3500%)
#
# Epoch: 58
# [576/1000 (56%)]	Loss: 1.969020	Class Loss: 0.597357	Domain Loss: 1.371664
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1288.0/2000 (64.4000%)
# Domain Accuracy: 2330.0/4000 (58.2500%)
#
# Epoch: 59
# [576/1000 (56%)]	Loss: 1.902287	Class Loss: 0.542037	Domain Loss: 1.360249
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1290.0/2000 (64.5000%)
# Domain Accuracy: 2324.0/4000 (58.1000%)
#
# Epoch: 60
# [576/1000 (56%)]	Loss: 1.841322	Class Loss: 0.515326	Domain Loss: 1.325996
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1289.0/2000 (64.4500%)
# Domain Accuracy: 2332.0/4000 (58.3000%)
#
# Epoch: 61
# [576/1000 (56%)]	Loss: 1.894240	Class Loss: 0.626873	Domain Loss: 1.267367
#
# Source Accuracy: 1700.0/2000 (85.0000%)
# Target Accuracy: 1292.0/2000 (64.6000%)
# Domain Accuracy: 2300.0/4000 (57.5000%)
#
# Epoch: 62
# [576/1000 (56%)]	Loss: 1.823849	Class Loss: 0.457952	Domain Loss: 1.365897
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1292.0/2000 (64.6000%)
# Domain Accuracy: 2317.0/4000 (57.9250%)
#
# Epoch: 63
# [360/1000 (56%)]	Loss: 1.886766	Class Loss: 0.536170	Domain Loss: 1.350597
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1292.0/2000 (64.6000%)
# Domain Accuracy: 2318.0/4000 (57.9500%)
#
# Epoch: 64
# [576/1000 (56%)]	Loss: 1.845992	Class Loss: 0.543329	Domain Loss: 1.302662
#
# Source Accuracy: 1702.0/2000 (85.1000%)
# Target Accuracy: 1296.0/2000 (64.8000%)
# Domain Accuracy: 2307.0/4000 (57.6750%)
#
# Epoch: 65
# [576/1000 (56%)]	Loss: 1.899531	Class Loss: 0.594559	Domain Loss: 1.304972
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1294.0/2000 (64.7000%)
# Domain Accuracy: 2292.0/4000 (57.3000%)
#
# Epoch: 66
# [576/1000 (56%)]	Loss: 1.882063	Class Loss: 0.604126	Domain Loss: 1.277937
#
# Source Accuracy: 1701.0/2000 (85.0500%)
# Target Accuracy: 1296.0/2000 (64.8000%)
# Domain Accuracy: 2278.0/4000 (56.9500%)
#
# Epoch: 67
# [576/1000 (56%)]	Loss: 1.864362	Class Loss: 0.498493	Domain Loss: 1.365869
#
# Source Accuracy: 1687.0/2000 (84.3500%)
# Target Accuracy: 1286.0/2000 (64.3000%)
# Domain Accuracy: 2275.0/4000 (56.8750%)
#
# Epoch: 68
# [360/1000 (56%)]	Loss: 1.918632	Class Loss: 0.514393	Domain Loss: 1.404239
#
# Source Accuracy: 1690.0/2000 (84.5000%)
# Target Accuracy: 1295.0/2000 (64.7500%)
# Domain Accuracy: 2279.0/4000 (56.9750%)
#
# Epoch: 69
# [576/1000 (56%)]	Loss: 1.937695	Class Loss: 0.597740	Domain Loss: 1.339955
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1296.0/2000 (64.8000%)
# Domain Accuracy: 2276.0/4000 (56.9000%)
#
# Epoch: 70
# [360/1000 (56%)]	Loss: 1.841441	Class Loss: 0.471714	Domain Loss: 1.369727
#
# Source Accuracy: 1702.0/2000 (85.1000%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2272.0/4000 (56.8000%)
#
# Epoch: 71
# [360/1000 (56%)]	Loss: 1.795716	Class Loss: 0.478772	Domain Loss: 1.316944
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1298.0/2000 (64.9000%)
# Domain Accuracy: 2279.0/4000 (56.9750%)
#
# Epoch: 72
# [576/1000 (56%)]	Loss: 1.786683	Class Loss: 0.460204	Domain Loss: 1.326479
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1296.0/2000 (64.8000%)
# Domain Accuracy: 2276.0/4000 (56.9000%)
#
# Epoch: 73
# [360/1000 (56%)]	Loss: 1.919003	Class Loss: 0.506333	Domain Loss: 1.412670
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1297.0/2000 (64.8500%)
# Domain Accuracy: 2270.0/4000 (56.7500%)
#
# Epoch: 74
# [576/1000 (56%)]	Loss: 1.797200	Class Loss: 0.452680	Domain Loss: 1.344520
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1297.0/2000 (64.8500%)
# Domain Accuracy: 2272.0/4000 (56.8000%)
#
# Epoch: 75
# [576/1000 (56%)]	Loss: 1.917225	Class Loss: 0.594655	Domain Loss: 1.322571
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1309.0/2000 (65.4500%)
# Domain Accuracy: 2271.0/4000 (56.7750%)
#
# Epoch: 76
# [576/1000 (56%)]	Loss: 1.823572	Class Loss: 0.481387	Domain Loss: 1.342185
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1308.0/2000 (65.4000%)
# Domain Accuracy: 2272.0/4000 (56.8000%)
#
# Epoch: 77
# [576/1000 (56%)]	Loss: 1.903992	Class Loss: 0.561335	Domain Loss: 1.342657
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1309.0/2000 (65.4500%)
# Domain Accuracy: 2269.0/4000 (56.7250%)
#
# Epoch: 78
# [576/1000 (56%)]	Loss: 1.807302	Class Loss: 0.439202	Domain Loss: 1.368100
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1309.0/2000 (65.4500%)
# Domain Accuracy: 2268.0/4000 (56.7000%)
#
# Epoch: 79
# [576/1000 (56%)]	Loss: 1.778415	Class Loss: 0.443106	Domain Loss: 1.335310
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1312.0/2000 (65.6000%)
# Domain Accuracy: 2268.0/4000 (56.7000%)
#
# Epoch: 80
# [576/1000 (56%)]	Loss: 1.847149	Class Loss: 0.530992	Domain Loss: 1.316157
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1304.0/2000 (65.2000%)
# Domain Accuracy: 2269.0/4000 (56.7250%)
#
# Epoch: 81
# [576/1000 (56%)]	Loss: 1.902574	Class Loss: 0.542819	Domain Loss: 1.359756
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1314.0/2000 (65.7000%)
# Domain Accuracy: 2272.0/4000 (56.8000%)
#
# Epoch: 82
# [576/1000 (56%)]	Loss: 1.898807	Class Loss: 0.526633	Domain Loss: 1.372174
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1306.0/2000 (65.3000%)
# Domain Accuracy: 2276.0/4000 (56.9000%)
#
# Epoch: 83
# [576/1000 (56%)]	Loss: 1.899879	Class Loss: 0.546233	Domain Loss: 1.353645
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2269.0/4000 (56.7250%)
#
# Epoch: 84
# [576/1000 (56%)]	Loss: 1.815833	Class Loss: 0.486800	Domain Loss: 1.329032
#
# Source Accuracy: 1695.0/2000 (84.7500%)
# Target Accuracy: 1313.0/2000 (65.6500%)
# Domain Accuracy: 2271.0/4000 (56.7750%)
#
# Epoch: 85
# [576/1000 (56%)]	Loss: 1.836925	Class Loss: 0.443291	Domain Loss: 1.393635
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1306.0/2000 (65.3000%)
# Domain Accuracy: 2280.0/4000 (57.0000%)
#
# Epoch: 86
# [576/1000 (56%)]	Loss: 1.773929	Class Loss: 0.421452	Domain Loss: 1.352478
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1313.0/2000 (65.6500%)
# Domain Accuracy: 2275.0/4000 (56.8750%)
#
# Epoch: 87
# [576/1000 (56%)]	Loss: 1.845032	Class Loss: 0.537909	Domain Loss: 1.307123
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1313.0/2000 (65.6500%)
# Domain Accuracy: 2270.0/4000 (56.7500%)
#
# Epoch: 88
# [576/1000 (56%)]	Loss: 1.731717	Class Loss: 0.433028	Domain Loss: 1.298688
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1312.0/2000 (65.6000%)
# Domain Accuracy: 2274.0/4000 (56.8500%)
#
# Epoch: 89
# [576/1000 (56%)]	Loss: 1.755266	Class Loss: 0.440685	Domain Loss: 1.314581
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2293.0/4000 (57.3250%)
#
# Epoch: 90
# [360/1000 (56%)]	Loss: 1.810067	Class Loss: 0.474175	Domain Loss: 1.335891
#
# Source Accuracy: 1694.0/2000 (84.7000%)
# Target Accuracy: 1301.0/2000 (65.0500%)
# Domain Accuracy: 2294.0/4000 (57.3500%)
#
# Epoch: 91
# [576/1000 (56%)]	Loss: 1.904393	Class Loss: 0.528686	Domain Loss: 1.375707
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2299.0/4000 (57.4750%)
#
# Epoch: 92
# [576/1000 (56%)]	Loss: 1.720085	Class Loss: 0.452490	Domain Loss: 1.267595
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1312.0/2000 (65.6000%)
# Domain Accuracy: 2298.0/4000 (57.4500%)
#
# Epoch: 93
# [576/1000 (56%)]	Loss: 1.922863	Class Loss: 0.574582	Domain Loss: 1.348281
#
# Source Accuracy: 1693.0/2000 (84.6500%)
# Target Accuracy: 1306.0/2000 (65.3000%)
# Domain Accuracy: 2304.0/4000 (57.6000%)
#
# Epoch: 94
# [576/1000 (56%)]	Loss: 1.933844	Class Loss: 0.605906	Domain Loss: 1.327939
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2299.0/4000 (57.4750%)
#
# Epoch: 95
# [576/1000 (56%)]	Loss: 1.737756	Class Loss: 0.461444	Domain Loss: 1.276312
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1308.0/2000 (65.4000%)
# Domain Accuracy: 2303.0/4000 (57.5750%)
#
# Epoch: 96
# [576/1000 (56%)]	Loss: 1.829115	Class Loss: 0.487760	Domain Loss: 1.341355
#
# Source Accuracy: 1697.0/2000 (84.8500%)
# Target Accuracy: 1307.0/2000 (65.3500%)
# Domain Accuracy: 2292.0/4000 (57.3000%)
#
# Epoch: 97
# [576/1000 (56%)]	Loss: 1.866535	Class Loss: 0.523440	Domain Loss: 1.343095
#
# Source Accuracy: 1693.0/2000 (84.6500%)
# Target Accuracy: 1302.0/2000 (65.1000%)
# Domain Accuracy: 2307.0/4000 (57.6750%)
#
# Epoch: 98
# [576/1000 (56%)]	Loss: 1.757701	Class Loss: 0.455140	Domain Loss: 1.302561
#
# Source Accuracy: 1696.0/2000 (84.8000%)
# Target Accuracy: 1303.0/2000 (65.1500%)
# Domain Accuracy: 2304.0/4000 (57.6000%)
#
# Epoch: 99
# [576/1000 (56%)]	Loss: 1.935849	Class Loss: 0.580287	Domain Loss: 1.355562
#
# Source Accuracy: 1698.0/2000 (84.9000%)
# Target Accuracy: 1305.0/2000 (65.2500%)
# Domain Accuracy: 2304.0/4000 (57.6000%)
#
# total run time: (min) 0.4024177352587382

# %%
plt.plot(range(len(total_loss)),total_loss,c='r',label='total_loss')
plt.plot(d_loss,c='b',label='domain_loss')
plt.plot(c_loss,c='y',label='clf_loss')
plt.title('traing')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # res

# %%
print('max target accuracy: ',max(acc_list3))
plt.plot(range(len(acc_list1)),acc_list1,c='r',label='source1(twitter)_acc')
# plt.plot(acc_list2,c='b',label='source2(forum)_acc')
plt.plot(acc_list3,c='g',label='target(wiki)_acc')
plt.plot(acc_list4,c='y',label='domain_acc')
plt.axhline(max(acc_list3),c='b',linestyle='--')
plt.title('testing')
plt.legend(loc='best')
plt.show()
# Out:
# max target accuracy:  65.7

# %% [markdown]
# 1.   F->W: [58.60, 53.55, 58.40, 62.50, 59.55]
# 2.   W->F: [53.75, 61.10, 57.80, 63.60, 65.70]
