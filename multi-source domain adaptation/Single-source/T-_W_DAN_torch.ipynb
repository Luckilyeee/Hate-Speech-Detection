# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import torchvision
import torch.optim as optim

import numpy as np
from sklearn.manifold import TSNE

import argparse, sys, os

import torch
from torchtext import data, datasets
import random
torch.backends.cudnn.deterministic = True

import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import time
from collections import Counter
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-440e2cf5-50f1-4f62-a8e8-a69589fb8aa2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-440e2cf5-50f1-4f62-a8e8-a69589fb8aa2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('stopwords')


wiki = pd.read_csv("Wiki_4000.csv")
twitter = pd.read_csv("twitter_4000.csv")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# remove puctunations, https
import re
def  clean_text(df, text_field):
    df[text_field] = df[text_field].str.lower()
    df[text_field] = df[text_field].apply(lambda elem: re.sub(r"(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    return df
wiki = clean_text(wiki, 'text')
twitter = clean_text(twitter, 'text')

stopwords = nltk.corpus.stopwords.words('english')
wiki['text'] = wiki['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
twitter['text'] = twitter['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
wiki['domain'] = 1
twitter['domain'] = 0

# %%
wiki = wiki[['text', 'label', 'domain']]
twitter = twitter[['text', 'label', 'domain']]

# %%
twitter.to_csv('T.csv', index=False)
wiki.to_csv('W.csv', index=False)

# %% [markdown]
# #tokenize

# %%
SEED = 1234
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
TEXT = data.Field(tokenize = 'spacy', batch_first=True)
LABEL = data.LabelField(dtype=torch.float)
DOMAIN = data.LabelField(dtype=torch.float)

# %%
#loading custom dataset
T =data.TabularDataset(path = 'T.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(T.examples[0]))
# Out:
# {'text': ['ssoul', 'y', 'all', 'defense', 'trash'], 'label': '0.0', 'domain': '0'}

# %%
#loading custom dataset
W =data.TabularDataset(path = 'W.csv',format = 'csv',fields = [('text', TEXT),('label',LABEL),('domain',DOMAIN)],skip_header = True)

#print preprocessed text
print(vars(W.examples[0]))
# Out:
# {'text': ['pussy', 'bet', 'u', 'wo', 'nt', 'get', 'none', 'u', 'stupid', 'ass', 'virgin'], 'label': '1.0', 'domain': '1'}

# %% [markdown]
# split train, test, val

# %%
W_train_data, W_test_data = W.split(split_ratio=0.8, random_state = random.seed(SEED))
T_train_data, T_test_data = T.split(split_ratio=0.8, random_state = random.seed(SEED))

# %% [markdown]
# #convert texts into integer sequences.

# %% [markdown]
# build vocabulary

# %%
#initialize glove embeddings
MAX_VOCAB_SIZE = 25_000

TEXT.build_vocab(W_train_data, T_train_data, 
                 max_size = MAX_VOCAB_SIZE, 
                 vectors = "glove.6B.100d", 
                 unk_init = torch.Tensor.normal_) 
LABEL.build_vocab(W_train_data, T_train_data)
DOMAIN.build_vocab(W_train_data, T_train_data)

# %% [markdown]
# creat iterators

# %%
#set batch size
BATCH_SIZE = 64

#check whether cuda is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  

W_train_iterator, W_test_iterator = data.BucketIterator.splits(
    (W_train_data, W_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

T_train_iterator, T_test_iterator = data.BucketIterator.splits(
    (T_train_data, T_test_data), 
    batch_size = BATCH_SIZE, 
    sort_key = lambda x: len(x.text),
    sort_within_batch=True,
    device = device)

# %%
class GradReverse(torch.autograd.Function):
    """
    Extension of grad reverse layer
    """
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        grad_output = grad_output.neg() * ctx.constant
        return grad_output, None

    def grad_reverse(x, constant):
        return GradReverse.apply(x, constant)

class Extractor(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, 
                 dropout, pad_idx, pretrained_embeddings):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        self.embedding.weight.data.copy_(pretrained_embeddings)
        self.conv_0 = nn.Conv2d(in_channels = 1, 
                                out_channels = n_filters, 
                                kernel_size = (filter_sizes, embedding_dim))
        
        
        
        self.fc = nn.Linear(n_filters, output_dim)
        
        self.dropout = nn.Dropout(dropout)

        # self.relu = nn.ReLU(inplace=True)
        # self.max_pool1d = nn.MaxPool1d(2,2)
        
    def forward(self, text):
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)
                
        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved_0 = F.relu(self.conv_0(embedded).squeeze(3))
            
        #conved_n = [batch size, n_filters, sent len - filter_sizes[n] + 1]
        
        pooled_0 = F.max_pool1d(conved_0, conved_0.shape[2]).squeeze(2)
        
        #pooled_n = [batch size, n_filters]
        x = self.dropout(pooled_0)
        #x = [batch size, n_filters * len(filter_sizes)]
            
        return x

class Class_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Class_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input):
        x = self.fc(input)
        return x

class Domain_classifier(nn.Module):

    def __init__(self, n_filters, output_dim):
        super(Domain_classifier, self).__init__()
        self.fc = nn.Linear(n_filters, output_dim)

    def forward(self, input, constant):
        input = GradReverse.grad_reverse(input, constant)
        return self.fc(input)

# %%
def optimizer_scheduler(optimizer, p):
    """
    Adjust the learning rate of optimizer
    :param optimizer: optimizer for updating parameters
    :param p: a variable for adjusting learning rate
    :return: optimizer
    """
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75

    return optimizer

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 100
FILTER_SIZES = 1
OUTPUT_DIM = 1
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]
pretrained_embeddings = TEXT.vocab.vectors

extractor = Extractor(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT, PAD_IDX,pretrained_embeddings )
class_classifier = Class_classifier(N_FILTERS, OUTPUT_DIM)
domain_classifier = Domain_classifier(N_FILTERS, OUTPUT_DIM)

# %% [markdown]
# check the number of parameters

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(extractor) + count_parameters(class_classifier) + count_parameters(domain_classifier):,} trainable parameters')
# Out:
# The model has 2,239,403 trainable parameters

# %% [markdown]
# zero the initial weights of the unknown and padding tokens

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]

extractor.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
extractor.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

# %%
criterion = nn.BCEWithLogitsLoss()

extractor = extractor.to(device)
class_classifier = class_classifier.to(device)
domain_classifier = domain_classifier.to(device)

criterion = criterion.to(device)

# %% [markdown]
# define function to calculate the correct predictions

# %%
def train(training_mode, extractor, class_classifier, domain_classifier, criterion,
          source_data, target_data, optimizer, epoch):
  
    epoch_loss = 0
    epoch_acc = 0

    # setup models
    extractor.train()
    class_classifier.train()
    domain_classifier.train()

    # steps
    start_steps = epoch * len(source_data)
    total_steps = 10 * len(source_data)

    for batch_idx,(sdata, tdata) in enumerate(zip(source_data, target_data)):
        if training_mode == 'dann':
            # setup hyperparameters
            p = float(batch_idx + start_steps) / total_steps
            constant = 2. / (1. + np.exp(-gamma * p)) - 1

            # prepare the data
            input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
            input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
    
            # setup optimizer
            optimizer = optimizer_scheduler(optimizer, p)
            optimizer.zero_grad()

            # compute the output of source domain and target domain
            src_feature = extractor(input1)
            tgt_feature = extractor(input3)

            # compute the class loss of src_feature
            class_pred = class_classifier(src_feature).squeeze(1)
            
            class_loss = criterion(class_pred, label1)
  

            # compute the domain loss of src_feature and target_feature
            tgt_preds = domain_classifier(tgt_feature, constant).squeeze(1)
            src_pred = domain_classifier(src_feature, constant).squeeze(1)
            
            tgt_loss = criterion(tgt_preds, domain3)
            src_loss = criterion(src_pred, domain1)
            
            
            domain_loss = tgt_loss + src_loss

            loss = class_loss + theta * domain_loss

            loss.backward()
            optimizer.step()

            # print loss

            if (batch_idx + 1) % 10 == 0:
                print('[{}/{} ({:.0f}%)]\tLoss: {:.6f}\tClass Loss: {:.6f}\tDomain Loss: {:.6f}'.format(
                    batch_idx * len(input1), len(T_train_data),
                    100. * batch_idx / len(source_data), loss.item(), class_loss.item(),
                    domain_loss.item()
                ))
                
            total_loss.append(loss.item())
            c_loss.append( class_loss.item())
            d_loss.append(domain_loss.item())

# %%
def test(extractor, class_classifier, domain_classifier, source_data, target_data):
 
    # setup the network
    extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()
    source_correct = 0.0
    target_correct = 0.0
    domain_correct = 0.0
    tgt_correct = 0.0
    src_correct = 0.0
    
    for batch_idx, sdata in enumerate(source_data):
        # setup hyperparameters
        p = float(batch_idx) / len(source_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1.

        input1, label1, domain1 = sdata.text, sdata.label, sdata.domain
        
        output1 = class_classifier(extractor(input1)).squeeze(1)
        output1 = torch.round(torch.sigmoid(output1))
        source_correct += (output1 == label1).cpu().sum()

        src_preds = domain_classifier(extractor(input1), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        src_correct += (src_preds == domain1).cpu().sum()

    for batch_idx, tdata in enumerate(target_data):
        # setup hyperparameters
        p = float(batch_idx) / len(target_data)
        constant = 2. / (1. + np.exp(-10 * p)) - 1

        input3, label3, domain3 = tdata.text, tdata.label, tdata.domain
        
        output3 = class_classifier(extractor(input3)).squeeze(1)
        output3 = torch.round(torch.sigmoid(output3))
        target_correct += (output3 == label3).cpu().sum()

        src_preds = domain_classifier(extractor(input3), constant).squeeze(1)
        src_preds = torch.round(torch.sigmoid(src_preds))
        tgt_correct += (src_preds == domain3).cpu().sum()


    domain_correct = tgt_correct + src_correct

    print('\nSource Accuracy: {}/{} ({:.4f}%)\nTarget Accuracy: {}/{} ({:.4f}%)\n'
          'Domain Accuracy: {}/{} ({:.4f}%)\n'.
        format(
        source_correct, len(T_test_data), 100. * float(source_correct) / len(T_test_data),
        target_correct, len(W_test_data), 100. * float(target_correct) / len(W_test_data),
        domain_correct, len(T_test_data) + len(W_test_data),
        100. * float(domain_correct) / (len(T_test_data) + len(W_test_data))
    ))
    acc_list1.append(100. * float(source_correct) / len(T_test_data))
    acc_list3.append(100. * float(target_correct) / len(W_test_data))
    acc_list4.append(100. * float(domain_correct) / (len(T_test_data) + len(W_test_data)))

# %%
def main():

    # prepare the source data and target data
    src_train_data = T_train_iterator
    src_test_data = T_test_iterator
    
    tgt_train_data = W_train_iterator
    tgt_test_data = W_test_iterator

    optimizer = optim.SGD([
            {'params': extractor.parameters()},
                            {'params': class_classifier.parameters()},
                            {'params': domain_classifier.parameters()}
    ], lr= 0.01, momentum= 0.9)


    for epoch in range(100):
    
        print('Epoch: {}'.format(epoch))
        train('dann', extractor, class_classifier, domain_classifier, criterion,
                    src_train_data, tgt_train_data, optimizer, epoch)
        test(extractor, class_classifier, domain_classifier, src_test_data, tgt_test_data)
        
total_loss, d_loss, c_loss = [],[],[]
acc_list1, acc_list3, acc_list4 = [],[],[]
if __name__ == '__main__':
    gamma = 10
    theta = 1
    time_start=time.time()
    main()
    time_end=time.time()
    print('total run time: (min)',(time_end-time_start)/60.)
# Out:
# Epoch: 0
# [576/3200 (18%)]	Loss: 2.097725	Class Loss: 0.735575	Domain Loss: 1.362151
# [1216/3200 (38%)]	Loss: 2.036348	Class Loss: 0.676239	Domain Loss: 1.360109
# [1856/3200 (58%)]	Loss: 2.013729	Class Loss: 0.664845	Domain Loss: 1.348885
# [2496/3200 (78%)]	Loss: 2.064664	Class Loss: 0.714909	Domain Loss: 1.349755
# [3136/3200 (98%)]	Loss: 1.975061	Class Loss: 0.680646	Domain Loss: 1.294415
#
# Source Accuracy: 628.0/800 (78.5000%)
# Target Accuracy: 560.0/800 (70.0000%)
# Domain Accuracy: 1122.0/1600 (70.1250%)
#
# Epoch: 1
# [576/3200 (18%)]	Loss: 1.972206	Class Loss: 0.606569	Domain Loss: 1.365637
# [1216/3200 (38%)]	Loss: 1.944835	Class Loss: 0.588571	Domain Loss: 1.356264
# [1856/3200 (58%)]	Loss: 1.876233	Class Loss: 0.647991	Domain Loss: 1.228242
# [2496/3200 (78%)]	Loss: 1.991888	Class Loss: 0.638476	Domain Loss: 1.353412
# [3136/3200 (98%)]	Loss: 1.957853	Class Loss: 0.582507	Domain Loss: 1.375346
#
# Source Accuracy: 674.0/800 (84.2500%)
# Target Accuracy: 589.0/800 (73.6250%)
# Domain Accuracy: 1056.0/1600 (66.0000%)
#
# Epoch: 2
# [576/3200 (18%)]	Loss: 1.978105	Class Loss: 0.632159	Domain Loss: 1.345946
# [1216/3200 (38%)]	Loss: 1.889703	Class Loss: 0.572573	Domain Loss: 1.317130
# [1856/3200 (58%)]	Loss: 1.938737	Class Loss: 0.576614	Domain Loss: 1.362123
# [2496/3200 (78%)]	Loss: 1.947392	Class Loss: 0.580899	Domain Loss: 1.366492
# [3136/3200 (98%)]	Loss: 1.861667	Class Loss: 0.463920	Domain Loss: 1.397747
#
# Source Accuracy: 691.0/800 (86.3750%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 970.0/1600 (60.6250%)
#
# Epoch: 3
# [576/3200 (18%)]	Loss: 1.867774	Class Loss: 0.489227	Domain Loss: 1.378548
# [1216/3200 (38%)]	Loss: 1.892793	Class Loss: 0.503630	Domain Loss: 1.389163
# [1856/3200 (58%)]	Loss: 1.826730	Class Loss: 0.456711	Domain Loss: 1.370019
# [2496/3200 (78%)]	Loss: 1.783770	Class Loss: 0.401633	Domain Loss: 1.382137
# [3136/3200 (98%)]	Loss: 1.757577	Class Loss: 0.381656	Domain Loss: 1.375921
#
# Source Accuracy: 698.0/800 (87.2500%)
# Target Accuracy: 609.0/800 (76.1250%)
# Domain Accuracy: 951.0/1600 (59.4375%)
#
# Epoch: 4
# [576/3200 (18%)]	Loss: 1.813627	Class Loss: 0.498976	Domain Loss: 1.314651
# [1216/3200 (38%)]	Loss: 1.874695	Class Loss: 0.539604	Domain Loss: 1.335091
# [1856/3200 (58%)]	Loss: 1.696189	Class Loss: 0.367197	Domain Loss: 1.328992
# [2496/3200 (78%)]	Loss: 1.726609	Class Loss: 0.428081	Domain Loss: 1.298528
# [3136/3200 (98%)]	Loss: 1.886435	Class Loss: 0.486552	Domain Loss: 1.399883
#
# Source Accuracy: 705.0/800 (88.1250%)
# Target Accuracy: 609.0/800 (76.1250%)
# Domain Accuracy: 976.0/1600 (61.0000%)
#
# Epoch: 5
# [576/3200 (18%)]	Loss: 1.802868	Class Loss: 0.478491	Domain Loss: 1.324377
# [1216/3200 (38%)]	Loss: 1.797693	Class Loss: 0.419861	Domain Loss: 1.377832
# [1856/3200 (58%)]	Loss: 1.789029	Class Loss: 0.422970	Domain Loss: 1.366059
# [2496/3200 (78%)]	Loss: 1.745716	Class Loss: 0.457229	Domain Loss: 1.288487
# [3136/3200 (98%)]	Loss: 1.855242	Class Loss: 0.516587	Domain Loss: 1.338656
#
# Source Accuracy: 712.0/800 (89.0000%)
# Target Accuracy: 610.0/800 (76.2500%)
# Domain Accuracy: 964.0/1600 (60.2500%)
#
# Epoch: 6
# [576/3200 (18%)]	Loss: 1.795688	Class Loss: 0.443639	Domain Loss: 1.352049
# [1216/3200 (38%)]	Loss: 1.817222	Class Loss: 0.392466	Domain Loss: 1.424756
# [1856/3200 (58%)]	Loss: 1.881293	Class Loss: 0.510608	Domain Loss: 1.370686
# [2496/3200 (78%)]	Loss: 1.783017	Class Loss: 0.421143	Domain Loss: 1.361874
# [3136/3200 (98%)]	Loss: 1.756381	Class Loss: 0.381617	Domain Loss: 1.374764
#
# Source Accuracy: 713.0/800 (89.1250%)
# Target Accuracy: 608.0/800 (76.0000%)
# Domain Accuracy: 951.0/1600 (59.4375%)
#
# Epoch: 7
# [576/3200 (18%)]	Loss: 1.749664	Class Loss: 0.404159	Domain Loss: 1.345505
# [1216/3200 (38%)]	Loss: 1.868290	Class Loss: 0.567148	Domain Loss: 1.301143
# [1856/3200 (58%)]	Loss: 1.670158	Class Loss: 0.343123	Domain Loss: 1.327035
# [2496/3200 (78%)]	Loss: 1.740243	Class Loss: 0.378626	Domain Loss: 1.361617
# [3136/3200 (98%)]	Loss: 1.818040	Class Loss: 0.477920	Domain Loss: 1.340121
#
# Source Accuracy: 720.0/800 (90.0000%)
# Target Accuracy: 602.0/800 (75.2500%)
# Domain Accuracy: 940.0/1600 (58.7500%)
#
# Epoch: 8
# [576/3200 (18%)]	Loss: 1.672198	Class Loss: 0.320075	Domain Loss: 1.352123
# [1216/3200 (38%)]	Loss: 1.828583	Class Loss: 0.501437	Domain Loss: 1.327146
# [1856/3200 (58%)]	Loss: 1.672572	Class Loss: 0.331916	Domain Loss: 1.340657
# [2496/3200 (78%)]	Loss: 1.788842	Class Loss: 0.398522	Domain Loss: 1.390319
# [3136/3200 (98%)]	Loss: 1.725967	Class Loss: 0.402215	Domain Loss: 1.323752
#
# Source Accuracy: 724.0/800 (90.5000%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 948.0/1600 (59.2500%)
#
# Epoch: 9
# [576/3200 (18%)]	Loss: 1.877015	Class Loss: 0.474987	Domain Loss: 1.402028
# [1216/3200 (38%)]	Loss: 1.826769	Class Loss: 0.521536	Domain Loss: 1.305233
# [1856/3200 (58%)]	Loss: 1.657353	Class Loss: 0.345339	Domain Loss: 1.312014
# [2496/3200 (78%)]	Loss: 1.776780	Class Loss: 0.412517	Domain Loss: 1.364262
# [3136/3200 (98%)]	Loss: 1.769880	Class Loss: 0.423333	Domain Loss: 1.346546
#
# Source Accuracy: 722.0/800 (90.2500%)
# Target Accuracy: 603.0/800 (75.3750%)
# Domain Accuracy: 945.0/1600 (59.0625%)
#
# Epoch: 10
# [576/3200 (18%)]	Loss: 1.718778	Class Loss: 0.334394	Domain Loss: 1.384384
# [1216/3200 (38%)]	Loss: 1.825623	Class Loss: 0.446700	Domain Loss: 1.378923
# [1856/3200 (58%)]	Loss: 1.858432	Class Loss: 0.530880	Domain Loss: 1.327551
# [2496/3200 (78%)]	Loss: 1.702431	Class Loss: 0.347343	Domain Loss: 1.355088
# [3136/3200 (98%)]	Loss: 1.749344	Class Loss: 0.493909	Domain Loss: 1.255435
#
# Source Accuracy: 725.0/800 (90.6250%)
# Target Accuracy: 605.0/800 (75.6250%)
# Domain Accuracy: 941.0/1600 (58.8125%)
#
# Epoch: 11
# [576/3200 (18%)]	Loss: 1.642050	Class Loss: 0.259967	Domain Loss: 1.382083
# [1216/3200 (38%)]	Loss: 1.712610	Class Loss: 0.323119	Domain Loss: 1.389491
# [1856/3200 (58%)]	Loss: 1.683481	Class Loss: 0.394446	Domain Loss: 1.289035
# [2496/3200 (78%)]	Loss: 1.762218	Class Loss: 0.443090	Domain Loss: 1.319129
# [3136/3200 (98%)]	Loss: 1.599686	Class Loss: 0.246150	Domain Loss: 1.353536
#
# Source Accuracy: 730.0/800 (91.2500%)
# Target Accuracy: 603.0/800 (75.3750%)
# Domain Accuracy: 918.0/1600 (57.3750%)
#
# Epoch: 12
# [576/3200 (18%)]	Loss: 1.724691	Class Loss: 0.304177	Domain Loss: 1.420514
# [1216/3200 (38%)]	Loss: 1.779164	Class Loss: 0.327271	Domain Loss: 1.451894
# [1856/3200 (58%)]	Loss: 1.735732	Class Loss: 0.351731	Domain Loss: 1.384001
# [2496/3200 (78%)]	Loss: 1.661083	Class Loss: 0.301848	Domain Loss: 1.359236
# [3136/3200 (98%)]	Loss: 1.619295	Class Loss: 0.274100	Domain Loss: 1.345195
#
# Source Accuracy: 731.0/800 (91.3750%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 907.0/1600 (56.6875%)
#
# Epoch: 13
# [576/3200 (18%)]	Loss: 1.564421	Class Loss: 0.211730	Domain Loss: 1.352691
# [1216/3200 (38%)]	Loss: 1.686459	Class Loss: 0.317295	Domain Loss: 1.369163
# [1856/3200 (58%)]	Loss: 1.730692	Class Loss: 0.332299	Domain Loss: 1.398393
# [2496/3200 (78%)]	Loss: 1.606740	Class Loss: 0.255235	Domain Loss: 1.351505
# [3136/3200 (98%)]	Loss: 1.658471	Class Loss: 0.336998	Domain Loss: 1.321473
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 592.0/800 (74.0000%)
# Domain Accuracy: 899.0/1600 (56.1875%)
#
# Epoch: 14
# [576/3200 (18%)]	Loss: 1.597491	Class Loss: 0.268750	Domain Loss: 1.328741
# [1216/3200 (38%)]	Loss: 1.801797	Class Loss: 0.416541	Domain Loss: 1.385256
# [1856/3200 (58%)]	Loss: 1.820042	Class Loss: 0.431825	Domain Loss: 1.388216
# [2496/3200 (78%)]	Loss: 1.655797	Class Loss: 0.282399	Domain Loss: 1.373398
# [3136/3200 (98%)]	Loss: 1.687156	Class Loss: 0.286629	Domain Loss: 1.400527
#
# Source Accuracy: 731.0/800 (91.3750%)
# Target Accuracy: 600.0/800 (75.0000%)
# Domain Accuracy: 900.0/1600 (56.2500%)
#
# Epoch: 15
# [576/3200 (18%)]	Loss: 1.680999	Class Loss: 0.373939	Domain Loss: 1.307060
# [1216/3200 (38%)]	Loss: 1.714602	Class Loss: 0.280289	Domain Loss: 1.434314
# [1856/3200 (58%)]	Loss: 1.755858	Class Loss: 0.375911	Domain Loss: 1.379947
# [2496/3200 (78%)]	Loss: 1.763435	Class Loss: 0.352823	Domain Loss: 1.410612
# [3136/3200 (98%)]	Loss: 1.740921	Class Loss: 0.323584	Domain Loss: 1.417337
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 893.0/1600 (55.8125%)
#
# Epoch: 16
# [576/3200 (18%)]	Loss: 1.682371	Class Loss: 0.326129	Domain Loss: 1.356242
# [1216/3200 (38%)]	Loss: 1.653316	Class Loss: 0.324688	Domain Loss: 1.328628
# [1856/3200 (58%)]	Loss: 1.653163	Class Loss: 0.286455	Domain Loss: 1.366709
# [2496/3200 (78%)]	Loss: 1.736950	Class Loss: 0.348837	Domain Loss: 1.388113
# [3136/3200 (98%)]	Loss: 1.700097	Class Loss: 0.354673	Domain Loss: 1.345424
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 890.0/1600 (55.6250%)
#
# Epoch: 17
# [576/3200 (18%)]	Loss: 1.704730	Class Loss: 0.330172	Domain Loss: 1.374558
# [1216/3200 (38%)]	Loss: 1.635924	Class Loss: 0.239286	Domain Loss: 1.396638
# [1856/3200 (58%)]	Loss: 1.651475	Class Loss: 0.298901	Domain Loss: 1.352574
# [2496/3200 (78%)]	Loss: 1.788894	Class Loss: 0.478095	Domain Loss: 1.310799
# [3136/3200 (98%)]	Loss: 1.708717	Class Loss: 0.355234	Domain Loss: 1.353483
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 600.0/800 (75.0000%)
# Domain Accuracy: 877.0/1600 (54.8125%)
#
# Epoch: 18
# [576/3200 (18%)]	Loss: 1.631343	Class Loss: 0.313451	Domain Loss: 1.317892
# [1216/3200 (38%)]	Loss: 1.720033	Class Loss: 0.401932	Domain Loss: 1.318100
# [1856/3200 (58%)]	Loss: 1.658870	Class Loss: 0.345705	Domain Loss: 1.313164
# [2496/3200 (78%)]	Loss: 1.625587	Class Loss: 0.251063	Domain Loss: 1.374524
# [3136/3200 (98%)]	Loss: 1.742319	Class Loss: 0.317641	Domain Loss: 1.424677
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 886.0/1600 (55.3750%)
#
# Epoch: 19
# [576/3200 (18%)]	Loss: 1.632256	Class Loss: 0.306880	Domain Loss: 1.325376
# [1216/3200 (38%)]	Loss: 1.754699	Class Loss: 0.363449	Domain Loss: 1.391250
# [1856/3200 (58%)]	Loss: 1.698520	Class Loss: 0.346205	Domain Loss: 1.352315
# [2496/3200 (78%)]	Loss: 1.788467	Class Loss: 0.394935	Domain Loss: 1.393532
# [3136/3200 (98%)]	Loss: 1.562440	Class Loss: 0.186577	Domain Loss: 1.375864
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 870.0/1600 (54.3750%)
#
# Epoch: 20
# [576/3200 (18%)]	Loss: 1.736967	Class Loss: 0.372788	Domain Loss: 1.364179
# [1216/3200 (38%)]	Loss: 1.681188	Class Loss: 0.317813	Domain Loss: 1.363376
# [1856/3200 (58%)]	Loss: 1.671537	Class Loss: 0.278549	Domain Loss: 1.392988
# [2496/3200 (78%)]	Loss: 1.753206	Class Loss: 0.432943	Domain Loss: 1.320263
# [3136/3200 (98%)]	Loss: 1.819504	Class Loss: 0.392087	Domain Loss: 1.427416
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 874.0/1600 (54.6250%)
#
# Epoch: 21
# [576/3200 (18%)]	Loss: 1.728910	Class Loss: 0.340209	Domain Loss: 1.388701
# [1216/3200 (38%)]	Loss: 1.672585	Class Loss: 0.328609	Domain Loss: 1.343976
# [1856/3200 (58%)]	Loss: 1.711715	Class Loss: 0.339010	Domain Loss: 1.372705
# [2496/3200 (78%)]	Loss: 1.767213	Class Loss: 0.393455	Domain Loss: 1.373758
# [3136/3200 (98%)]	Loss: 1.816658	Class Loss: 0.465710	Domain Loss: 1.350948
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 600.0/800 (75.0000%)
# Domain Accuracy: 874.0/1600 (54.6250%)
#
# Epoch: 22
# [576/3200 (18%)]	Loss: 1.734489	Class Loss: 0.313228	Domain Loss: 1.421261
# [1216/3200 (38%)]	Loss: 1.691463	Class Loss: 0.336316	Domain Loss: 1.355147
# [1856/3200 (58%)]	Loss: 1.696855	Class Loss: 0.297335	Domain Loss: 1.399519
# [2496/3200 (78%)]	Loss: 1.858157	Class Loss: 0.474684	Domain Loss: 1.383472
# [3136/3200 (98%)]	Loss: 1.820838	Class Loss: 0.485967	Domain Loss: 1.334871
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 866.0/1600 (54.1250%)
#
# Epoch: 23
# [576/3200 (18%)]	Loss: 1.684110	Class Loss: 0.325242	Domain Loss: 1.358868
# [1216/3200 (38%)]	Loss: 1.683738	Class Loss: 0.265506	Domain Loss: 1.418232
# [1856/3200 (58%)]	Loss: 1.688807	Class Loss: 0.322213	Domain Loss: 1.366594
# [2496/3200 (78%)]	Loss: 1.715127	Class Loss: 0.369909	Domain Loss: 1.345217
# [3136/3200 (98%)]	Loss: 1.586146	Class Loss: 0.212540	Domain Loss: 1.373606
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 862.0/1600 (53.8750%)
#
# Epoch: 24
# [576/3200 (18%)]	Loss: 1.642100	Class Loss: 0.267981	Domain Loss: 1.374119
# [1216/3200 (38%)]	Loss: 1.665663	Class Loss: 0.252977	Domain Loss: 1.412686
# [1856/3200 (58%)]	Loss: 1.601221	Class Loss: 0.205638	Domain Loss: 1.395584
# [2496/3200 (78%)]	Loss: 1.679185	Class Loss: 0.376828	Domain Loss: 1.302356
# [3136/3200 (98%)]	Loss: 1.847787	Class Loss: 0.493402	Domain Loss: 1.354385
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 864.0/1600 (54.0000%)
#
# Epoch: 25
# [576/3200 (18%)]	Loss: 1.735389	Class Loss: 0.355142	Domain Loss: 1.380247
# [1216/3200 (38%)]	Loss: 1.786964	Class Loss: 0.426490	Domain Loss: 1.360475
# [1856/3200 (58%)]	Loss: 1.658520	Class Loss: 0.222415	Domain Loss: 1.436105
# [2496/3200 (78%)]	Loss: 1.797959	Class Loss: 0.473545	Domain Loss: 1.324413
# [3136/3200 (98%)]	Loss: 1.762208	Class Loss: 0.392184	Domain Loss: 1.370024
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 859.0/1600 (53.6875%)
#
# Epoch: 26
# [576/3200 (18%)]	Loss: 1.675702	Class Loss: 0.347124	Domain Loss: 1.328578
# [1216/3200 (38%)]	Loss: 1.633517	Class Loss: 0.312622	Domain Loss: 1.320895
# [1856/3200 (58%)]	Loss: 1.710248	Class Loss: 0.308089	Domain Loss: 1.402160
# [2496/3200 (78%)]	Loss: 1.604525	Class Loss: 0.270402	Domain Loss: 1.334123
# [3136/3200 (98%)]	Loss: 1.689436	Class Loss: 0.308821	Domain Loss: 1.380615
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 592.0/800 (74.0000%)
# Domain Accuracy: 853.0/1600 (53.3125%)
#
# Epoch: 27
# [576/3200 (18%)]	Loss: 1.662120	Class Loss: 0.293516	Domain Loss: 1.368604
# [1216/3200 (38%)]	Loss: 1.646821	Class Loss: 0.312021	Domain Loss: 1.334800
# [1856/3200 (58%)]	Loss: 1.667306	Class Loss: 0.290872	Domain Loss: 1.376435
# [2496/3200 (78%)]	Loss: 1.671847	Class Loss: 0.273505	Domain Loss: 1.398343
# [3136/3200 (98%)]	Loss: 1.604767	Class Loss: 0.230167	Domain Loss: 1.374599
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 843.0/1600 (52.6875%)
#
# Epoch: 28
# [576/3200 (18%)]	Loss: 1.737483	Class Loss: 0.354613	Domain Loss: 1.382870
# [1216/3200 (38%)]	Loss: 1.686981	Class Loss: 0.278264	Domain Loss: 1.408718
# [1856/3200 (58%)]	Loss: 1.710899	Class Loss: 0.335614	Domain Loss: 1.375285
# [2496/3200 (78%)]	Loss: 1.722324	Class Loss: 0.322633	Domain Loss: 1.399691
# [3136/3200 (98%)]	Loss: 1.618524	Class Loss: 0.300837	Domain Loss: 1.317688
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 849.0/1600 (53.0625%)
#
# Epoch: 29
# [576/3200 (18%)]	Loss: 1.702529	Class Loss: 0.306507	Domain Loss: 1.396022
# [1216/3200 (38%)]	Loss: 1.613503	Class Loss: 0.236075	Domain Loss: 1.377428
# [1856/3200 (58%)]	Loss: 1.643325	Class Loss: 0.206308	Domain Loss: 1.437017
# [2496/3200 (78%)]	Loss: 1.568192	Class Loss: 0.229727	Domain Loss: 1.338465
# [3136/3200 (98%)]	Loss: 1.637972	Class Loss: 0.251023	Domain Loss: 1.386949
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 842.0/1600 (52.6250%)
#
# Epoch: 30
# [576/3200 (18%)]	Loss: 1.802772	Class Loss: 0.445367	Domain Loss: 1.357405
# [1216/3200 (38%)]	Loss: 1.731426	Class Loss: 0.373345	Domain Loss: 1.358081
# [1856/3200 (58%)]	Loss: 1.628979	Class Loss: 0.272150	Domain Loss: 1.356828
# [2496/3200 (78%)]	Loss: 1.660303	Class Loss: 0.256301	Domain Loss: 1.404002
# [3136/3200 (98%)]	Loss: 1.624465	Class Loss: 0.247652	Domain Loss: 1.376814
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 838.0/1600 (52.3750%)
#
# Epoch: 31
# [576/3200 (18%)]	Loss: 1.610475	Class Loss: 0.281174	Domain Loss: 1.329300
# [1216/3200 (38%)]	Loss: 1.749736	Class Loss: 0.316065	Domain Loss: 1.433671
# [1856/3200 (58%)]	Loss: 1.636561	Class Loss: 0.232089	Domain Loss: 1.404471
# [2496/3200 (78%)]	Loss: 1.673146	Class Loss: 0.281666	Domain Loss: 1.391480
# [3136/3200 (98%)]	Loss: 1.607500	Class Loss: 0.195600	Domain Loss: 1.411900
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 595.0/800 (74.3750%)
# Domain Accuracy: 842.0/1600 (52.6250%)
#
# Epoch: 32
# [576/3200 (18%)]	Loss: 1.654332	Class Loss: 0.252403	Domain Loss: 1.401929
# [1216/3200 (38%)]	Loss: 1.859148	Class Loss: 0.396981	Domain Loss: 1.462167
# [1856/3200 (58%)]	Loss: 1.695978	Class Loss: 0.277001	Domain Loss: 1.418978
# [2496/3200 (78%)]	Loss: 1.705538	Class Loss: 0.302740	Domain Loss: 1.402797
# [3136/3200 (98%)]	Loss: 1.673657	Class Loss: 0.323641	Domain Loss: 1.350017
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 595.0/800 (74.3750%)
# Domain Accuracy: 838.0/1600 (52.3750%)
#
# Epoch: 33
# [576/3200 (18%)]	Loss: 1.757732	Class Loss: 0.375450	Domain Loss: 1.382282
# [1216/3200 (38%)]	Loss: 1.898508	Class Loss: 0.547976	Domain Loss: 1.350531
# [1856/3200 (58%)]	Loss: 1.654376	Class Loss: 0.245482	Domain Loss: 1.408893
# [2496/3200 (78%)]	Loss: 1.602887	Class Loss: 0.232306	Domain Loss: 1.370581
# [3136/3200 (98%)]	Loss: 1.657658	Class Loss: 0.311011	Domain Loss: 1.346647
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 828.0/1600 (51.7500%)
#
# Epoch: 34
# [576/3200 (18%)]	Loss: 1.592419	Class Loss: 0.229472	Domain Loss: 1.362947
# [1216/3200 (38%)]	Loss: 1.639672	Class Loss: 0.211370	Domain Loss: 1.428302
# [1856/3200 (58%)]	Loss: 1.658974	Class Loss: 0.267475	Domain Loss: 1.391499
# [2496/3200 (78%)]	Loss: 1.841562	Class Loss: 0.441375	Domain Loss: 1.400187
# [3136/3200 (98%)]	Loss: 1.730721	Class Loss: 0.360650	Domain Loss: 1.370071
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 836.0/1600 (52.2500%)
#
# Epoch: 35
# [576/3200 (18%)]	Loss: 1.798283	Class Loss: 0.421274	Domain Loss: 1.377008
# [1216/3200 (38%)]	Loss: 1.678149	Class Loss: 0.332279	Domain Loss: 1.345870
# [1856/3200 (58%)]	Loss: 1.633900	Class Loss: 0.256899	Domain Loss: 1.377000
# [2496/3200 (78%)]	Loss: 1.607292	Class Loss: 0.196387	Domain Loss: 1.410904
# [3136/3200 (98%)]	Loss: 1.622584	Class Loss: 0.219008	Domain Loss: 1.403575
#
# Source Accuracy: 732.0/800 (91.5000%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 829.0/1600 (51.8125%)
#
# Epoch: 36
# [576/3200 (18%)]	Loss: 1.649430	Class Loss: 0.264577	Domain Loss: 1.384854
# [1216/3200 (38%)]	Loss: 1.641211	Class Loss: 0.303379	Domain Loss: 1.337832
# [1856/3200 (58%)]	Loss: 1.693485	Class Loss: 0.317401	Domain Loss: 1.376084
# [2496/3200 (78%)]	Loss: 1.627874	Class Loss: 0.200447	Domain Loss: 1.427428
# [3136/3200 (98%)]	Loss: 1.735611	Class Loss: 0.349732	Domain Loss: 1.385879
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 833.0/1600 (52.0625%)
#
# Epoch: 37
# [576/3200 (18%)]	Loss: 1.737810	Class Loss: 0.340595	Domain Loss: 1.397215
# [1216/3200 (38%)]	Loss: 1.663315	Class Loss: 0.222142	Domain Loss: 1.441174
# [1856/3200 (58%)]	Loss: 1.716350	Class Loss: 0.336159	Domain Loss: 1.380190
# [2496/3200 (78%)]	Loss: 1.623610	Class Loss: 0.256821	Domain Loss: 1.366789
# [3136/3200 (98%)]	Loss: 1.595120	Class Loss: 0.242663	Domain Loss: 1.352457
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 824.0/1600 (51.5000%)
#
# Epoch: 38
# [576/3200 (18%)]	Loss: 1.718285	Class Loss: 0.286292	Domain Loss: 1.431993
# [1216/3200 (38%)]	Loss: 1.679832	Class Loss: 0.279947	Domain Loss: 1.399884
# [1856/3200 (58%)]	Loss: 1.618866	Class Loss: 0.240391	Domain Loss: 1.378475
# [2496/3200 (78%)]	Loss: 1.726443	Class Loss: 0.404603	Domain Loss: 1.321839
# [3136/3200 (98%)]	Loss: 1.603847	Class Loss: 0.211736	Domain Loss: 1.392111
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 595.0/800 (74.3750%)
# Domain Accuracy: 820.0/1600 (51.2500%)
#
# Epoch: 39
# [576/3200 (18%)]	Loss: 1.731774	Class Loss: 0.365565	Domain Loss: 1.366210
# [1216/3200 (38%)]	Loss: 1.689033	Class Loss: 0.319652	Domain Loss: 1.369381
# [1856/3200 (58%)]	Loss: 1.704229	Class Loss: 0.351961	Domain Loss: 1.352268
# [2496/3200 (78%)]	Loss: 1.709042	Class Loss: 0.318450	Domain Loss: 1.390592
# [3136/3200 (98%)]	Loss: 1.792128	Class Loss: 0.448364	Domain Loss: 1.343764
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 824.0/1600 (51.5000%)
#
# Epoch: 40
# [576/3200 (18%)]	Loss: 1.716651	Class Loss: 0.310526	Domain Loss: 1.406126
# [1216/3200 (38%)]	Loss: 1.666744	Class Loss: 0.301602	Domain Loss: 1.365142
# [1856/3200 (58%)]	Loss: 1.793557	Class Loss: 0.380144	Domain Loss: 1.413413
# [2496/3200 (78%)]	Loss: 1.552561	Class Loss: 0.187707	Domain Loss: 1.364854
# [3136/3200 (98%)]	Loss: 1.687057	Class Loss: 0.290082	Domain Loss: 1.396975
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 595.0/800 (74.3750%)
# Domain Accuracy: 822.0/1600 (51.3750%)
#
# Epoch: 41
# [576/3200 (18%)]	Loss: 1.633892	Class Loss: 0.239857	Domain Loss: 1.394035
# [1216/3200 (38%)]	Loss: 1.714258	Class Loss: 0.343984	Domain Loss: 1.370274
# [1856/3200 (58%)]	Loss: 1.661652	Class Loss: 0.277140	Domain Loss: 1.384512
# [2496/3200 (78%)]	Loss: 1.648342	Class Loss: 0.228431	Domain Loss: 1.419911
# [3136/3200 (98%)]	Loss: 1.669342	Class Loss: 0.294837	Domain Loss: 1.374505
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 811.0/1600 (50.6875%)
#
# Epoch: 42
# [576/3200 (18%)]	Loss: 1.708417	Class Loss: 0.346560	Domain Loss: 1.361857
# [1216/3200 (38%)]	Loss: 1.610733	Class Loss: 0.267873	Domain Loss: 1.342860
# [1856/3200 (58%)]	Loss: 1.673730	Class Loss: 0.297981	Domain Loss: 1.375749
# [2496/3200 (78%)]	Loss: 1.623115	Class Loss: 0.236399	Domain Loss: 1.386716
# [3136/3200 (98%)]	Loss: 1.647683	Class Loss: 0.232505	Domain Loss: 1.415177
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 822.0/1600 (51.3750%)
#
# Epoch: 43
# [576/3200 (18%)]	Loss: 1.649238	Class Loss: 0.286171	Domain Loss: 1.363067
# [1216/3200 (38%)]	Loss: 1.588582	Class Loss: 0.159145	Domain Loss: 1.429437
# [1856/3200 (58%)]	Loss: 1.661759	Class Loss: 0.229589	Domain Loss: 1.432171
# [2496/3200 (78%)]	Loss: 1.672989	Class Loss: 0.294038	Domain Loss: 1.378951
# [3136/3200 (98%)]	Loss: 1.819793	Class Loss: 0.421124	Domain Loss: 1.398669
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 593.0/800 (74.1250%)
# Domain Accuracy: 806.0/1600 (50.3750%)
#
# Epoch: 44
# [576/3200 (18%)]	Loss: 1.611186	Class Loss: 0.201504	Domain Loss: 1.409682
# [1216/3200 (38%)]	Loss: 1.662887	Class Loss: 0.214276	Domain Loss: 1.448611
# [1856/3200 (58%)]	Loss: 1.656029	Class Loss: 0.252375	Domain Loss: 1.403654
# [2496/3200 (78%)]	Loss: 1.701308	Class Loss: 0.285783	Domain Loss: 1.415525
# [3136/3200 (98%)]	Loss: 1.701291	Class Loss: 0.296422	Domain Loss: 1.404869
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 809.0/1600 (50.5625%)
#
# Epoch: 45
# [576/3200 (18%)]	Loss: 1.701584	Class Loss: 0.326180	Domain Loss: 1.375404
# [1216/3200 (38%)]	Loss: 1.706014	Class Loss: 0.298710	Domain Loss: 1.407304
# [1856/3200 (58%)]	Loss: 1.534253	Class Loss: 0.137258	Domain Loss: 1.396995
# [2496/3200 (78%)]	Loss: 1.702176	Class Loss: 0.349272	Domain Loss: 1.352904
# [3136/3200 (98%)]	Loss: 1.638220	Class Loss: 0.264398	Domain Loss: 1.373822
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 805.0/1600 (50.3125%)
#
# Epoch: 46
# [576/3200 (18%)]	Loss: 1.687045	Class Loss: 0.275463	Domain Loss: 1.411581
# [1216/3200 (38%)]	Loss: 1.777062	Class Loss: 0.369175	Domain Loss: 1.407887
# [1856/3200 (58%)]	Loss: 1.623968	Class Loss: 0.250094	Domain Loss: 1.373874
# [2496/3200 (78%)]	Loss: 1.689412	Class Loss: 0.296818	Domain Loss: 1.392593
# [3136/3200 (98%)]	Loss: 1.705086	Class Loss: 0.336680	Domain Loss: 1.368406
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 796.0/1600 (49.7500%)
#
# Epoch: 47
# [576/3200 (18%)]	Loss: 1.628539	Class Loss: 0.226905	Domain Loss: 1.401634
# [1216/3200 (38%)]	Loss: 1.579743	Class Loss: 0.262721	Domain Loss: 1.317021
# [1856/3200 (58%)]	Loss: 1.655779	Class Loss: 0.241777	Domain Loss: 1.414002
# [2496/3200 (78%)]	Loss: 1.670421	Class Loss: 0.240919	Domain Loss: 1.429502
# [3136/3200 (98%)]	Loss: 1.707997	Class Loss: 0.355089	Domain Loss: 1.352908
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 595.0/800 (74.3750%)
# Domain Accuracy: 796.0/1600 (49.7500%)
#
# Epoch: 48
# [576/3200 (18%)]	Loss: 1.772347	Class Loss: 0.397602	Domain Loss: 1.374744
# [1216/3200 (38%)]	Loss: 1.698532	Class Loss: 0.256396	Domain Loss: 1.442135
# [1856/3200 (58%)]	Loss: 1.645789	Class Loss: 0.250240	Domain Loss: 1.395548
# [2496/3200 (78%)]	Loss: 1.659336	Class Loss: 0.304162	Domain Loss: 1.355174
# [3136/3200 (98%)]	Loss: 1.759598	Class Loss: 0.361630	Domain Loss: 1.397968
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 797.0/1600 (49.8125%)
#
# Epoch: 49
# [576/3200 (18%)]	Loss: 1.773558	Class Loss: 0.358609	Domain Loss: 1.414949
# [1216/3200 (38%)]	Loss: 1.731608	Class Loss: 0.301954	Domain Loss: 1.429654
# [1856/3200 (58%)]	Loss: 1.634028	Class Loss: 0.236678	Domain Loss: 1.397350
# [2496/3200 (78%)]	Loss: 1.652570	Class Loss: 0.230742	Domain Loss: 1.421828
# [3136/3200 (98%)]	Loss: 1.638789	Class Loss: 0.196907	Domain Loss: 1.441882
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 801.0/1600 (50.0625%)
#
# Epoch: 50
# [576/3200 (18%)]	Loss: 1.665146	Class Loss: 0.247522	Domain Loss: 1.417624
# [1216/3200 (38%)]	Loss: 1.681436	Class Loss: 0.263431	Domain Loss: 1.418005
# [1856/3200 (58%)]	Loss: 1.722982	Class Loss: 0.320861	Domain Loss: 1.402121
# [2496/3200 (78%)]	Loss: 1.699849	Class Loss: 0.309377	Domain Loss: 1.390472
# [3136/3200 (98%)]	Loss: 1.640706	Class Loss: 0.227962	Domain Loss: 1.412744
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 790.0/1600 (49.3750%)
#
# Epoch: 51
# [576/3200 (18%)]	Loss: 1.705958	Class Loss: 0.299370	Domain Loss: 1.406588
# [1216/3200 (38%)]	Loss: 1.593058	Class Loss: 0.214831	Domain Loss: 1.378227
# [1856/3200 (58%)]	Loss: 1.657425	Class Loss: 0.258781	Domain Loss: 1.398644
# [2496/3200 (78%)]	Loss: 1.712659	Class Loss: 0.335093	Domain Loss: 1.377566
# [3136/3200 (98%)]	Loss: 1.585582	Class Loss: 0.184861	Domain Loss: 1.400722
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 594.0/800 (74.2500%)
# Domain Accuracy: 799.0/1600 (49.9375%)
#
# Epoch: 52
# [576/3200 (18%)]	Loss: 1.769789	Class Loss: 0.346644	Domain Loss: 1.423144
# [1216/3200 (38%)]	Loss: 1.760261	Class Loss: 0.390328	Domain Loss: 1.369933
# [1856/3200 (58%)]	Loss: 1.605755	Class Loss: 0.248784	Domain Loss: 1.356971
# [2496/3200 (78%)]	Loss: 1.654817	Class Loss: 0.248427	Domain Loss: 1.406391
# [3136/3200 (98%)]	Loss: 1.672395	Class Loss: 0.303029	Domain Loss: 1.369366
#
# Source Accuracy: 735.0/800 (91.8750%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 789.0/1600 (49.3125%)
#
# Epoch: 53
# [576/3200 (18%)]	Loss: 1.636493	Class Loss: 0.233481	Domain Loss: 1.403013
# [1216/3200 (38%)]	Loss: 1.669960	Class Loss: 0.243342	Domain Loss: 1.426618
# [1856/3200 (58%)]	Loss: 1.624751	Class Loss: 0.202867	Domain Loss: 1.421884
# [2496/3200 (78%)]	Loss: 1.698367	Class Loss: 0.293372	Domain Loss: 1.404995
# [3136/3200 (98%)]	Loss: 1.604278	Class Loss: 0.256201	Domain Loss: 1.348077
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 791.0/1600 (49.4375%)
#
# Epoch: 54
# [576/3200 (18%)]	Loss: 1.776606	Class Loss: 0.356765	Domain Loss: 1.419842
# [1216/3200 (38%)]	Loss: 1.688191	Class Loss: 0.253155	Domain Loss: 1.435036
# [1856/3200 (58%)]	Loss: 1.595825	Class Loss: 0.197602	Domain Loss: 1.398223
# [2496/3200 (78%)]	Loss: 1.559639	Class Loss: 0.231549	Domain Loss: 1.328091
# [3136/3200 (98%)]	Loss: 1.569781	Class Loss: 0.188938	Domain Loss: 1.380843
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 792.0/1600 (49.5000%)
#
# Epoch: 55
# [576/3200 (18%)]	Loss: 1.671975	Class Loss: 0.305238	Domain Loss: 1.366737
# [1216/3200 (38%)]	Loss: 1.624287	Class Loss: 0.233918	Domain Loss: 1.390369
# [1856/3200 (58%)]	Loss: 1.687176	Class Loss: 0.332095	Domain Loss: 1.355082
# [2496/3200 (78%)]	Loss: 1.672389	Class Loss: 0.299810	Domain Loss: 1.372579
# [3136/3200 (98%)]	Loss: 1.842902	Class Loss: 0.423868	Domain Loss: 1.419034
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 787.0/1600 (49.1875%)
#
# Epoch: 56
# [576/3200 (18%)]	Loss: 1.674219	Class Loss: 0.275571	Domain Loss: 1.398648
# [1216/3200 (38%)]	Loss: 1.604904	Class Loss: 0.262882	Domain Loss: 1.342022
# [1856/3200 (58%)]	Loss: 1.673253	Class Loss: 0.262959	Domain Loss: 1.410295
# [2496/3200 (78%)]	Loss: 1.660494	Class Loss: 0.270810	Domain Loss: 1.389683
# [3136/3200 (98%)]	Loss: 1.592126	Class Loss: 0.251104	Domain Loss: 1.341022
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 787.0/1600 (49.1875%)
#
# Epoch: 57
# [576/3200 (18%)]	Loss: 1.628118	Class Loss: 0.235856	Domain Loss: 1.392262
# [1216/3200 (38%)]	Loss: 1.631656	Class Loss: 0.230282	Domain Loss: 1.401374
# [1856/3200 (58%)]	Loss: 1.643064	Class Loss: 0.236447	Domain Loss: 1.406618
# [2496/3200 (78%)]	Loss: 1.821462	Class Loss: 0.404697	Domain Loss: 1.416765
# [3136/3200 (98%)]	Loss: 1.708399	Class Loss: 0.300929	Domain Loss: 1.407469
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 777.0/1600 (48.5625%)
#
# Epoch: 58
# [576/3200 (18%)]	Loss: 1.546453	Class Loss: 0.181136	Domain Loss: 1.365317
# [1216/3200 (38%)]	Loss: 1.731381	Class Loss: 0.312023	Domain Loss: 1.419359
# [1856/3200 (58%)]	Loss: 1.629189	Class Loss: 0.213911	Domain Loss: 1.415278
# [2496/3200 (78%)]	Loss: 1.738374	Class Loss: 0.356210	Domain Loss: 1.382164
# [3136/3200 (98%)]	Loss: 1.630142	Class Loss: 0.228187	Domain Loss: 1.401955
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 783.0/1600 (48.9375%)
#
# Epoch: 59
# [576/3200 (18%)]	Loss: 1.619011	Class Loss: 0.197171	Domain Loss: 1.421839
# [1216/3200 (38%)]	Loss: 1.541602	Class Loss: 0.166515	Domain Loss: 1.375087
# [1856/3200 (58%)]	Loss: 1.649706	Class Loss: 0.230604	Domain Loss: 1.419102
# [2496/3200 (78%)]	Loss: 1.565058	Class Loss: 0.181395	Domain Loss: 1.383663
# [3136/3200 (98%)]	Loss: 1.900150	Class Loss: 0.502635	Domain Loss: 1.397515
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 781.0/1600 (48.8125%)
#
# Epoch: 60
# [576/3200 (18%)]	Loss: 1.721839	Class Loss: 0.302478	Domain Loss: 1.419361
# [1216/3200 (38%)]	Loss: 1.694038	Class Loss: 0.275131	Domain Loss: 1.418907
# [1856/3200 (58%)]	Loss: 1.651067	Class Loss: 0.273424	Domain Loss: 1.377643
# [2496/3200 (78%)]	Loss: 1.687015	Class Loss: 0.265351	Domain Loss: 1.421664
# [3136/3200 (98%)]	Loss: 1.602379	Class Loss: 0.237104	Domain Loss: 1.365275
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 788.0/1600 (49.2500%)
#
# Epoch: 61
# [576/3200 (18%)]	Loss: 1.649772	Class Loss: 0.291887	Domain Loss: 1.357885
# [1216/3200 (38%)]	Loss: 1.672417	Class Loss: 0.296694	Domain Loss: 1.375723
# [1856/3200 (58%)]	Loss: 1.622480	Class Loss: 0.225801	Domain Loss: 1.396679
# [2496/3200 (78%)]	Loss: 1.550068	Class Loss: 0.199025	Domain Loss: 1.351043
# [3136/3200 (98%)]	Loss: 1.637005	Class Loss: 0.250609	Domain Loss: 1.386397
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 779.0/1600 (48.6875%)
#
# Epoch: 62
# [576/3200 (18%)]	Loss: 1.607143	Class Loss: 0.246075	Domain Loss: 1.361068
# [1216/3200 (38%)]	Loss: 1.709264	Class Loss: 0.322111	Domain Loss: 1.387152
# [1856/3200 (58%)]	Loss: 1.756748	Class Loss: 0.346464	Domain Loss: 1.410284
# [2496/3200 (78%)]	Loss: 1.582734	Class Loss: 0.210500	Domain Loss: 1.372234
# [3136/3200 (98%)]	Loss: 1.596972	Class Loss: 0.163687	Domain Loss: 1.433285
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 776.0/1600 (48.5000%)
#
# Epoch: 63
# [576/3200 (18%)]	Loss: 1.690089	Class Loss: 0.287083	Domain Loss: 1.403006
# [1216/3200 (38%)]	Loss: 1.708602	Class Loss: 0.299386	Domain Loss: 1.409216
# [1856/3200 (58%)]	Loss: 1.731374	Class Loss: 0.307772	Domain Loss: 1.423602
# [2496/3200 (78%)]	Loss: 1.817138	Class Loss: 0.424860	Domain Loss: 1.392277
# [3136/3200 (98%)]	Loss: 1.758652	Class Loss: 0.387929	Domain Loss: 1.370723
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 783.0/1600 (48.9375%)
#
# Epoch: 64
# [576/3200 (18%)]	Loss: 1.805427	Class Loss: 0.414245	Domain Loss: 1.391182
# [1216/3200 (38%)]	Loss: 1.739699	Class Loss: 0.341361	Domain Loss: 1.398338
# [1856/3200 (58%)]	Loss: 1.650485	Class Loss: 0.238421	Domain Loss: 1.412064
# [2496/3200 (78%)]	Loss: 1.593682	Class Loss: 0.207936	Domain Loss: 1.385746
# [3136/3200 (98%)]	Loss: 1.709492	Class Loss: 0.358050	Domain Loss: 1.351443
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 766.0/1600 (47.8750%)
#
# Epoch: 65
# [576/3200 (18%)]	Loss: 1.686445	Class Loss: 0.255469	Domain Loss: 1.430977
# [1216/3200 (38%)]	Loss: 1.682391	Class Loss: 0.305771	Domain Loss: 1.376620
# [1856/3200 (58%)]	Loss: 1.626601	Class Loss: 0.248853	Domain Loss: 1.377749
# [2496/3200 (78%)]	Loss: 1.718546	Class Loss: 0.341264	Domain Loss: 1.377282
# [3136/3200 (98%)]	Loss: 1.594932	Class Loss: 0.227199	Domain Loss: 1.367733
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 776.0/1600 (48.5000%)
#
# Epoch: 66
# [576/3200 (18%)]	Loss: 1.675227	Class Loss: 0.321596	Domain Loss: 1.353631
# [1216/3200 (38%)]	Loss: 1.898484	Class Loss: 0.479016	Domain Loss: 1.419468
# [1856/3200 (58%)]	Loss: 1.684120	Class Loss: 0.289287	Domain Loss: 1.394833
# [2496/3200 (78%)]	Loss: 1.813960	Class Loss: 0.393096	Domain Loss: 1.420865
# [3136/3200 (98%)]	Loss: 1.698766	Class Loss: 0.330143	Domain Loss: 1.368624
#
# Source Accuracy: 734.0/800 (91.7500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 767.0/1600 (47.9375%)
#
# Epoch: 67
# [576/3200 (18%)]	Loss: 1.713696	Class Loss: 0.348413	Domain Loss: 1.365283
# [1216/3200 (38%)]	Loss: 1.615378	Class Loss: 0.241342	Domain Loss: 1.374037
# [1856/3200 (58%)]	Loss: 1.570990	Class Loss: 0.223801	Domain Loss: 1.347189
# [2496/3200 (78%)]	Loss: 1.636235	Class Loss: 0.298843	Domain Loss: 1.337392
# [3136/3200 (98%)]	Loss: 1.662668	Class Loss: 0.276648	Domain Loss: 1.386020
#
# Source Accuracy: 733.0/800 (91.6250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 782.0/1600 (48.8750%)
#
# Epoch: 68
# [576/3200 (18%)]	Loss: 1.830220	Class Loss: 0.458893	Domain Loss: 1.371327
# [1216/3200 (38%)]	Loss: 1.701629	Class Loss: 0.300129	Domain Loss: 1.401501
# [1856/3200 (58%)]	Loss: 1.849437	Class Loss: 0.413444	Domain Loss: 1.435992
# [2496/3200 (78%)]	Loss: 1.746350	Class Loss: 0.343423	Domain Loss: 1.402927
# [3136/3200 (98%)]	Loss: 1.648793	Class Loss: 0.233767	Domain Loss: 1.415025
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 774.0/1600 (48.3750%)
#
# Epoch: 69
# [576/3200 (18%)]	Loss: 1.625781	Class Loss: 0.212920	Domain Loss: 1.412861
# [1216/3200 (38%)]	Loss: 1.594575	Class Loss: 0.225329	Domain Loss: 1.369245
# [1856/3200 (58%)]	Loss: 1.598985	Class Loss: 0.230698	Domain Loss: 1.368287
# [2496/3200 (78%)]	Loss: 1.675810	Class Loss: 0.256652	Domain Loss: 1.419158
# [3136/3200 (98%)]	Loss: 1.701895	Class Loss: 0.293907	Domain Loss: 1.407988
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 782.0/1600 (48.8750%)
#
# Epoch: 70
# [576/3200 (18%)]	Loss: 1.664844	Class Loss: 0.257941	Domain Loss: 1.406903
# [1216/3200 (38%)]	Loss: 1.663285	Class Loss: 0.265020	Domain Loss: 1.398264
# [1856/3200 (58%)]	Loss: 1.609841	Class Loss: 0.225527	Domain Loss: 1.384314
# [2496/3200 (78%)]	Loss: 1.646087	Class Loss: 0.231090	Domain Loss: 1.414997
# [3136/3200 (98%)]	Loss: 1.698159	Class Loss: 0.334427	Domain Loss: 1.363732
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 777.0/1600 (48.5625%)
#
# Epoch: 71
# [576/3200 (18%)]	Loss: 1.663760	Class Loss: 0.268193	Domain Loss: 1.395567
# [1216/3200 (38%)]	Loss: 1.679491	Class Loss: 0.271990	Domain Loss: 1.407501
# [1856/3200 (58%)]	Loss: 1.680895	Class Loss: 0.283219	Domain Loss: 1.397676
# [2496/3200 (78%)]	Loss: 1.686809	Class Loss: 0.308978	Domain Loss: 1.377831
# [3136/3200 (98%)]	Loss: 1.557988	Class Loss: 0.157651	Domain Loss: 1.400337
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 782.0/1600 (48.8750%)
#
# Epoch: 72
# [576/3200 (18%)]	Loss: 1.698436	Class Loss: 0.275585	Domain Loss: 1.422851
# [1216/3200 (38%)]	Loss: 1.674225	Class Loss: 0.260072	Domain Loss: 1.414153
# [1856/3200 (58%)]	Loss: 1.815258	Class Loss: 0.384161	Domain Loss: 1.431097
# [2496/3200 (78%)]	Loss: 1.597596	Class Loss: 0.177348	Domain Loss: 1.420248
# [3136/3200 (98%)]	Loss: 1.637676	Class Loss: 0.234320	Domain Loss: 1.403356
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 768.0/1600 (48.0000%)
#
# Epoch: 73
# [576/3200 (18%)]	Loss: 1.572959	Class Loss: 0.226397	Domain Loss: 1.346562
# [1216/3200 (38%)]	Loss: 1.555840	Class Loss: 0.178155	Domain Loss: 1.377685
# [1856/3200 (58%)]	Loss: 1.562482	Class Loss: 0.159862	Domain Loss: 1.402621
# [2496/3200 (78%)]	Loss: 1.679505	Class Loss: 0.310840	Domain Loss: 1.368664
# [3136/3200 (98%)]	Loss: 1.590417	Class Loss: 0.214833	Domain Loss: 1.375583
#
# Source Accuracy: 736.0/800 (92.0000%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 774.0/1600 (48.3750%)
#
# Epoch: 74
# [576/3200 (18%)]	Loss: 1.687903	Class Loss: 0.340879	Domain Loss: 1.347024
# [1216/3200 (38%)]	Loss: 1.639500	Class Loss: 0.234853	Domain Loss: 1.404647
# [1856/3200 (58%)]	Loss: 1.768665	Class Loss: 0.447829	Domain Loss: 1.320836
# [2496/3200 (78%)]	Loss: 1.611094	Class Loss: 0.202584	Domain Loss: 1.408510
# [3136/3200 (98%)]	Loss: 1.753830	Class Loss: 0.389669	Domain Loss: 1.364161
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 767.0/1600 (47.9375%)
#
# Epoch: 75
# [576/3200 (18%)]	Loss: 1.632615	Class Loss: 0.248825	Domain Loss: 1.383790
# [1216/3200 (38%)]	Loss: 1.602989	Class Loss: 0.190585	Domain Loss: 1.412404
# [1856/3200 (58%)]	Loss: 1.666811	Class Loss: 0.280655	Domain Loss: 1.386156
# [2496/3200 (78%)]	Loss: 1.659631	Class Loss: 0.281705	Domain Loss: 1.377926
# [3136/3200 (98%)]	Loss: 1.664467	Class Loss: 0.243043	Domain Loss: 1.421423
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 775.0/1600 (48.4375%)
#
# Epoch: 76
# [576/3200 (18%)]	Loss: 1.622976	Class Loss: 0.217116	Domain Loss: 1.405859
# [1216/3200 (38%)]	Loss: 1.720114	Class Loss: 0.293041	Domain Loss: 1.427073
# [1856/3200 (58%)]	Loss: 1.695595	Class Loss: 0.303381	Domain Loss: 1.392213
# [2496/3200 (78%)]	Loss: 1.621250	Class Loss: 0.251344	Domain Loss: 1.369905
# [3136/3200 (98%)]	Loss: 1.731068	Class Loss: 0.337332	Domain Loss: 1.393736
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 761.0/1600 (47.5625%)
#
# Epoch: 77
# [576/3200 (18%)]	Loss: 1.638906	Class Loss: 0.256066	Domain Loss: 1.382840
# [1216/3200 (38%)]	Loss: 1.666402	Class Loss: 0.262178	Domain Loss: 1.404225
# [1856/3200 (58%)]	Loss: 1.565808	Class Loss: 0.179035	Domain Loss: 1.386773
# [2496/3200 (78%)]	Loss: 1.688112	Class Loss: 0.318639	Domain Loss: 1.369473
# [3136/3200 (98%)]	Loss: 1.688404	Class Loss: 0.244001	Domain Loss: 1.444403
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 762.0/1600 (47.6250%)
#
# Epoch: 78
# [576/3200 (18%)]	Loss: 1.613134	Class Loss: 0.255013	Domain Loss: 1.358121
# [1216/3200 (38%)]	Loss: 1.594833	Class Loss: 0.193242	Domain Loss: 1.401591
# [1856/3200 (58%)]	Loss: 1.604055	Class Loss: 0.195297	Domain Loss: 1.408758
# [2496/3200 (78%)]	Loss: 1.642634	Class Loss: 0.237975	Domain Loss: 1.404659
# [3136/3200 (98%)]	Loss: 1.646058	Class Loss: 0.231687	Domain Loss: 1.414371
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 596.0/800 (74.5000%)
# Domain Accuracy: 771.0/1600 (48.1875%)
#
# Epoch: 79
# [576/3200 (18%)]	Loss: 1.630555	Class Loss: 0.267752	Domain Loss: 1.362803
# [1216/3200 (38%)]	Loss: 1.733204	Class Loss: 0.344028	Domain Loss: 1.389176
# [1856/3200 (58%)]	Loss: 1.692635	Class Loss: 0.314135	Domain Loss: 1.378500
# [2496/3200 (78%)]	Loss: 1.655217	Class Loss: 0.236449	Domain Loss: 1.418768
# [3136/3200 (98%)]	Loss: 1.635201	Class Loss: 0.232067	Domain Loss: 1.403134
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 597.0/800 (74.6250%)
# Domain Accuracy: 762.0/1600 (47.6250%)
#
# Epoch: 80
# [576/3200 (18%)]	Loss: 1.547473	Class Loss: 0.172178	Domain Loss: 1.375295
# [1216/3200 (38%)]	Loss: 1.661916	Class Loss: 0.275005	Domain Loss: 1.386912
# [1856/3200 (58%)]	Loss: 1.607055	Class Loss: 0.206999	Domain Loss: 1.400056
# [2496/3200 (78%)]	Loss: 1.581215	Class Loss: 0.187059	Domain Loss: 1.394156
# [3136/3200 (98%)]	Loss: 1.632240	Class Loss: 0.229991	Domain Loss: 1.402248
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 762.0/1600 (47.6250%)
#
# Epoch: 81
# [576/3200 (18%)]	Loss: 1.667415	Class Loss: 0.271384	Domain Loss: 1.396031
# [1216/3200 (38%)]	Loss: 1.637876	Class Loss: 0.288279	Domain Loss: 1.349597
# [1856/3200 (58%)]	Loss: 1.636178	Class Loss: 0.233129	Domain Loss: 1.403050
# [2496/3200 (78%)]	Loss: 1.737122	Class Loss: 0.362164	Domain Loss: 1.374958
# [3136/3200 (98%)]	Loss: 1.686287	Class Loss: 0.296018	Domain Loss: 1.390269
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 763.0/1600 (47.6875%)
#
# Epoch: 82
# [576/3200 (18%)]	Loss: 1.616290	Class Loss: 0.196811	Domain Loss: 1.419479
# [1216/3200 (38%)]	Loss: 1.554944	Class Loss: 0.137042	Domain Loss: 1.417901
# [1856/3200 (58%)]	Loss: 1.615760	Class Loss: 0.217530	Domain Loss: 1.398231
# [2496/3200 (78%)]	Loss: 1.639380	Class Loss: 0.295493	Domain Loss: 1.343888
# [3136/3200 (98%)]	Loss: 1.776428	Class Loss: 0.365197	Domain Loss: 1.411231
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 760.0/1600 (47.5000%)
#
# Epoch: 83
# [576/3200 (18%)]	Loss: 1.522195	Class Loss: 0.164233	Domain Loss: 1.357962
# [1216/3200 (38%)]	Loss: 1.759460	Class Loss: 0.395018	Domain Loss: 1.364442
# [1856/3200 (58%)]	Loss: 1.652851	Class Loss: 0.260431	Domain Loss: 1.392421
# [2496/3200 (78%)]	Loss: 1.632605	Class Loss: 0.236809	Domain Loss: 1.395795
# [3136/3200 (98%)]	Loss: 1.492550	Class Loss: 0.128600	Domain Loss: 1.363950
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 764.0/1600 (47.7500%)
#
# Epoch: 84
# [576/3200 (18%)]	Loss: 1.697545	Class Loss: 0.302982	Domain Loss: 1.394563
# [1216/3200 (38%)]	Loss: 1.559145	Class Loss: 0.155528	Domain Loss: 1.403618
# [1856/3200 (58%)]	Loss: 1.666479	Class Loss: 0.267247	Domain Loss: 1.399232
# [2496/3200 (78%)]	Loss: 1.590230	Class Loss: 0.222168	Domain Loss: 1.368062
# [3136/3200 (98%)]	Loss: 1.681249	Class Loss: 0.285010	Domain Loss: 1.396239
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 762.0/1600 (47.6250%)
#
# Epoch: 85
# [576/3200 (18%)]	Loss: 1.650031	Class Loss: 0.259716	Domain Loss: 1.390315
# [1216/3200 (38%)]	Loss: 1.562957	Class Loss: 0.221997	Domain Loss: 1.340959
# [1856/3200 (58%)]	Loss: 1.636495	Class Loss: 0.296071	Domain Loss: 1.340423
# [2496/3200 (78%)]	Loss: 1.841410	Class Loss: 0.440612	Domain Loss: 1.400798
# [3136/3200 (98%)]	Loss: 1.689042	Class Loss: 0.264467	Domain Loss: 1.424575
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 760.0/1600 (47.5000%)
#
# Epoch: 86
# [576/3200 (18%)]	Loss: 1.649868	Class Loss: 0.222916	Domain Loss: 1.426951
# [1216/3200 (38%)]	Loss: 1.722094	Class Loss: 0.358597	Domain Loss: 1.363497
# [1856/3200 (58%)]	Loss: 1.738438	Class Loss: 0.376907	Domain Loss: 1.361531
# [2496/3200 (78%)]	Loss: 1.539001	Class Loss: 0.124792	Domain Loss: 1.414209
# [3136/3200 (98%)]	Loss: 1.674309	Class Loss: 0.267613	Domain Loss: 1.406696
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 758.0/1600 (47.3750%)
#
# Epoch: 87
# [576/3200 (18%)]	Loss: 1.755146	Class Loss: 0.373107	Domain Loss: 1.382039
# [1216/3200 (38%)]	Loss: 1.701446	Class Loss: 0.298450	Domain Loss: 1.402996
# [1856/3200 (58%)]	Loss: 1.562961	Class Loss: 0.208995	Domain Loss: 1.353966
# [2496/3200 (78%)]	Loss: 1.692747	Class Loss: 0.339933	Domain Loss: 1.352814
# [3136/3200 (98%)]	Loss: 1.606537	Class Loss: 0.193623	Domain Loss: 1.412914
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 600.0/800 (75.0000%)
# Domain Accuracy: 764.0/1600 (47.7500%)
#
# Epoch: 88
# [576/3200 (18%)]	Loss: 1.562126	Class Loss: 0.151585	Domain Loss: 1.410541
# [1216/3200 (38%)]	Loss: 1.758458	Class Loss: 0.340758	Domain Loss: 1.417700
# [1856/3200 (58%)]	Loss: 1.621875	Class Loss: 0.208942	Domain Loss: 1.412933
# [2496/3200 (78%)]	Loss: 1.682708	Class Loss: 0.291424	Domain Loss: 1.391284
# [3136/3200 (98%)]	Loss: 1.597486	Class Loss: 0.202183	Domain Loss: 1.395302
#
# Source Accuracy: 737.0/800 (92.1250%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 761.0/1600 (47.5625%)
#
# Epoch: 89
# [576/3200 (18%)]	Loss: 1.568325	Class Loss: 0.199177	Domain Loss: 1.369148
# [1216/3200 (38%)]	Loss: 1.591864	Class Loss: 0.200456	Domain Loss: 1.391408
# [1856/3200 (58%)]	Loss: 1.608834	Class Loss: 0.204032	Domain Loss: 1.404802
# [2496/3200 (78%)]	Loss: 1.635950	Class Loss: 0.227501	Domain Loss: 1.408449
# [3136/3200 (98%)]	Loss: 1.771576	Class Loss: 0.349264	Domain Loss: 1.422312
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 752.0/1600 (47.0000%)
#
# Epoch: 90
# [576/3200 (18%)]	Loss: 1.614302	Class Loss: 0.193247	Domain Loss: 1.421055
# [1216/3200 (38%)]	Loss: 1.627656	Class Loss: 0.248360	Domain Loss: 1.379296
# [1856/3200 (58%)]	Loss: 1.605145	Class Loss: 0.212320	Domain Loss: 1.392825
# [2496/3200 (78%)]	Loss: 1.564379	Class Loss: 0.153046	Domain Loss: 1.411332
# [3136/3200 (98%)]	Loss: 1.716636	Class Loss: 0.321866	Domain Loss: 1.394770
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 756.0/1600 (47.2500%)
#
# Epoch: 91
# [576/3200 (18%)]	Loss: 1.647185	Class Loss: 0.249410	Domain Loss: 1.397776
# [1216/3200 (38%)]	Loss: 1.588347	Class Loss: 0.208776	Domain Loss: 1.379571
# [1856/3200 (58%)]	Loss: 1.542547	Class Loss: 0.147057	Domain Loss: 1.395490
# [2496/3200 (78%)]	Loss: 1.593169	Class Loss: 0.225616	Domain Loss: 1.367553
# [3136/3200 (98%)]	Loss: 1.604651	Class Loss: 0.209739	Domain Loss: 1.394912
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 747.0/1600 (46.6875%)
#
# Epoch: 92
# [576/3200 (18%)]	Loss: 1.649295	Class Loss: 0.248031	Domain Loss: 1.401264
# [1216/3200 (38%)]	Loss: 1.644733	Class Loss: 0.246465	Domain Loss: 1.398267
# [1856/3200 (58%)]	Loss: 1.631996	Class Loss: 0.238744	Domain Loss: 1.393252
# [2496/3200 (78%)]	Loss: 1.653967	Class Loss: 0.245899	Domain Loss: 1.408067
# [3136/3200 (98%)]	Loss: 1.715196	Class Loss: 0.328061	Domain Loss: 1.387135
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 756.0/1600 (47.2500%)
#
# Epoch: 93
# [576/3200 (18%)]	Loss: 1.673759	Class Loss: 0.248032	Domain Loss: 1.425727
# [1216/3200 (38%)]	Loss: 1.739824	Class Loss: 0.344659	Domain Loss: 1.395164
# [1856/3200 (58%)]	Loss: 1.643423	Class Loss: 0.245647	Domain Loss: 1.397776
# [2496/3200 (78%)]	Loss: 1.714362	Class Loss: 0.328394	Domain Loss: 1.385968
# [3136/3200 (98%)]	Loss: 1.664380	Class Loss: 0.259929	Domain Loss: 1.404451
#
# Source Accuracy: 739.0/800 (92.3750%)
# Target Accuracy: 598.0/800 (74.7500%)
# Domain Accuracy: 754.0/1600 (47.1250%)
#
# Epoch: 94
# [576/3200 (18%)]	Loss: 1.683215	Class Loss: 0.299780	Domain Loss: 1.383435
# [1216/3200 (38%)]	Loss: 1.632642	Class Loss: 0.212601	Domain Loss: 1.420041
# [1856/3200 (58%)]	Loss: 1.557962	Class Loss: 0.151526	Domain Loss: 1.406436
# [2496/3200 (78%)]	Loss: 1.596475	Class Loss: 0.243319	Domain Loss: 1.353155
# [3136/3200 (98%)]	Loss: 1.720984	Class Loss: 0.326193	Domain Loss: 1.394791
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 600.0/800 (75.0000%)
# Domain Accuracy: 755.0/1600 (47.1875%)
#
# Epoch: 95
# [576/3200 (18%)]	Loss: 1.656175	Class Loss: 0.250050	Domain Loss: 1.406125
# [1216/3200 (38%)]	Loss: 1.557368	Class Loss: 0.165781	Domain Loss: 1.391587
# [1856/3200 (58%)]	Loss: 1.630214	Class Loss: 0.221007	Domain Loss: 1.409207
# [2496/3200 (78%)]	Loss: 1.656171	Class Loss: 0.280114	Domain Loss: 1.376057
# [3136/3200 (98%)]	Loss: 1.623665	Class Loss: 0.219274	Domain Loss: 1.404391
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 757.0/1600 (47.3125%)
#
# Epoch: 96
# [576/3200 (18%)]	Loss: 1.651160	Class Loss: 0.260096	Domain Loss: 1.391064
# [1216/3200 (38%)]	Loss: 1.682873	Class Loss: 0.299910	Domain Loss: 1.382963
# [1856/3200 (58%)]	Loss: 1.655713	Class Loss: 0.243694	Domain Loss: 1.412018
# [2496/3200 (78%)]	Loss: 1.568465	Class Loss: 0.157255	Domain Loss: 1.411210
# [3136/3200 (98%)]	Loss: 1.748876	Class Loss: 0.343938	Domain Loss: 1.404937
#
# Source Accuracy: 739.0/800 (92.3750%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 740.0/1600 (46.2500%)
#
# Epoch: 97
# [576/3200 (18%)]	Loss: 1.598824	Class Loss: 0.204879	Domain Loss: 1.393944
# [1216/3200 (38%)]	Loss: 1.571326	Class Loss: 0.210702	Domain Loss: 1.360623
# [1856/3200 (58%)]	Loss: 1.711659	Class Loss: 0.334229	Domain Loss: 1.377429
# [2496/3200 (78%)]	Loss: 1.529728	Class Loss: 0.137875	Domain Loss: 1.391853
# [3136/3200 (98%)]	Loss: 1.556736	Class Loss: 0.169337	Domain Loss: 1.387399
#
# Source Accuracy: 739.0/800 (92.3750%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 744.0/1600 (46.5000%)
#
# Epoch: 98
# [576/3200 (18%)]	Loss: 1.632517	Class Loss: 0.219992	Domain Loss: 1.412525
# [1216/3200 (38%)]	Loss: 1.788092	Class Loss: 0.414273	Domain Loss: 1.373819
# [1856/3200 (58%)]	Loss: 1.632506	Class Loss: 0.246979	Domain Loss: 1.385526
# [2496/3200 (78%)]	Loss: 1.653829	Class Loss: 0.248769	Domain Loss: 1.405060
# [3136/3200 (98%)]	Loss: 1.631675	Class Loss: 0.257061	Domain Loss: 1.374614
#
# Source Accuracy: 739.0/800 (92.3750%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 744.0/1600 (46.5000%)
#
# Epoch: 99
# [576/3200 (18%)]	Loss: 1.583067	Class Loss: 0.197869	Domain Loss: 1.385199
# [1216/3200 (38%)]	Loss: 1.526599	Class Loss: 0.160478	Domain Loss: 1.366122
# [1856/3200 (58%)]	Loss: 1.739533	Class Loss: 0.368879	Domain Loss: 1.370654
# [2496/3200 (78%)]	Loss: 1.738012	Class Loss: 0.325003	Domain Loss: 1.413009
# [3136/3200 (98%)]	Loss: 1.716509	Class Loss: 0.310801	Domain Loss: 1.405708
#
# Source Accuracy: 738.0/800 (92.2500%)
# Target Accuracy: 599.0/800 (74.8750%)
# Domain Accuracy: 740.0/1600 (46.2500%)
#
# total run time: (min) 0.6267034610112509

# %%
plt.plot(range(len(total_loss)),total_loss,c='r',label='total_loss')
plt.plot(d_loss,c='b',label='domain_loss')
plt.plot(c_loss,c='y',label='clf_loss')
plt.title('traing')
plt.legend(loc='best')
plt.show()

# %%
print('max target accuracy: ',max(acc_list3))
plt.plot(range(len(acc_list1)),acc_list1,c='r',label='source_acc')
# plt.plot(acc_list2,c='b',label='source2(forum)_acc')
plt.plot(acc_list3,c='g',label='target_acc')
plt.plot(acc_list4,c='y',label='domain_acc')
plt.axhline(max(acc_list3),c='b',linestyle='--')
plt.title('testing')
plt.legend(loc='best')
plt.show()
# Out:
# max target accuracy:  76.25
