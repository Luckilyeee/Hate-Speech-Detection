# %%
# Dataset 1
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot([200, 400, 600, 800, 1000], [0.7651, 0.7960, 0.8003, 0.8428, 0.8310],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='SVM')
plt.plot([200, 400, 600, 800, 1000], [0.4540, 0.7138, 0.7722, 0.7610, 0.8304],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='CNN')
plt.plot([200, 400, 600, 800, 1000], [0.7316, 0.7799, 0.8602, 0.8729, 0.8992],marker='^', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='BERT')
plt.xlabel('Training size')
plt.ylabel('Macro avaraged F1 score')
axes = plt.gca()
axes.set_ylim([0.3,1.0])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
plt.savefig("Twitter of different training size.png", dpi = 216)

# %%
# Dataset 2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot([200, 400, 600, 800, 1000], [0.5246, 0.4976, 0.6006, 0.6171, 0.6411],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='SVM')
plt.plot([200, 400, 600, 800, 1000], [0.4704, 0.4948, 0.5099, 0.5676, 0.5788],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='CNN')
plt.plot([200, 400, 600, 800, 1000], [0.5770, 0.6689, 0.6512, 0.6941, 0.6950],marker='^', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='BERT')

plt.xlabel('Training size')
plt.ylabel('Macro avaraged F1 score')
axes = plt.gca()
axes.set_ylim([0.3,1.0])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
plt.savefig("Forum of different training size.png", dpi = 300)

# %%
# Dataset 3
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot([200, 400, 600, 800, 1000], [0.6465, 0.6744, 0.7115, 0.7285, 0.7428],marker='*', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='SVM')
plt.plot([200, 400, 600, 800, 1000], [0.4748, 0.6077, 0.6378, 0.6617, 0.6477],marker='o', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='CNN')
plt.plot([200, 400, 600, 800, 1000], [0.7351, 0.7932, 0.8211, 0.8325, 0.8330],marker='^', markerfacecolor='black', markersize=10, color='black', linewidth=1, label='BERT')

plt.xlabel('Training size')
plt.ylabel('Macro avaraged F1 score')
axes = plt.gca()
axes.set_ylim([0.3,1.0])
plt.xticks(np.arange(200, 1200, 200))
plt.legend()
plt.savefig("Wikipedia of different training size.png", dpi = 300)
